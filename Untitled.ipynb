# %%
# Walk through the directory tree
import os
for dirpath, dirnames, filenames in os.walk("./plot/"):
  for file in filenames:
    print(file)
    if file[-4:] == "json" or file[-8:] == "plot.txt":
      file_path = os.path.join(dirpath, file)
      try:
        os.remove(file_path)  # Delete the file
        print(f"Deleted: {file_path}")
      except Exception as e:
        print(f"Error deleting {file_path}: {e}")
# Out:
# 10_3-5_呼叫_行动后.txt
# 11_3-6_决定_行动前.txt
# 12_3-6_决定_行动后.txt
# 13_3-7_轰鸣_行动前.txt
# 14_3-7_轰鸣_行动后.txt
# 15_3-8_黄昏_行动前.txt
# 16_3-8_黄昏_行动后.txt
# 1_3-1_会合_行动前.txt
# 2_3-1_会合_行动后.txt
# 3_3-2_记忆_行动前.txt
# 4_3-2_记忆_行动后.txt
# 5_3-3_回旋_行动前.txt
# 6_3-3_回旋_行动后.txt
# 7_3-4_龟裂_行动前.txt
# 8_3-4_龟裂_行动后.txt
# 9_3-5_呼叫_行动前.txt
# 10_6-5_解决谁？_行动后.txt
# 11_6-6_别说过去的事.txt
# 12_6-7_断弦_行动前.txt
# 13_6-7_断弦_行动后.txt
# 14_6-8_只是从天而降！_行动前.txt
# 15_6-8_只是从天而降！_行动后.txt
# 16_6-9_换一个角度_行动前.txt
# 17_6-10_解开铃铛_行动后.txt
# 18_6-11_“这种事”_行动前.txt
# 19_6-11_“这种事”_行动后.txt
# 1_6-1_僵局_行动前.txt
# 20_6-12_冰原之雪_行动前.txt
# 21_6-13_没有火,没有光.txt
# 22_6-14_冰原之霜_行动后.txt
# 23_6-15_不错的回忆_行动前.txt
# 24_6-15_不错的回忆_行动后.txt
# 25_6-16_黑兔子,白兔子_行动前.txt
# 26_6-17_冬逝_行动后.txt
# 27_6-18_只有你知道.txt
# 2_6-1_僵局_行动后.txt
# 3_6-2_一些误会_行动前.txt
# 4_6-2_一些误会_行动后.txt
# 5_6-3_同时走失_行动前.txt
# 6_6-3_同时走失_行动后.txt
# 7_6-4_溃烂的疮疤_行动前.txt
# 8_6-4_溃烂的疮疤_行动后.txt
# 9_6-5_解决谁？_行动前.txt
# 10_2-5_高空坠物_行动后.txt
# 11_2-6_握紧扶手_行动前.txt
# 12_2-6_握紧扶手_行动后.txt
# 13_2-7_注意卫生_行动前.txt
# 14_2-7_注意卫生_行动后.txt
# 15_2-8_不做约定_行动前.txt
# 16_2-8_不做约定_行动后.txt
# 17_2-9_操作暗箱_行动前.txt
# 18_2-9_操作暗箱_行动后.txt
# 19_2-10_病入膏肓_行动前.txt
# 1_TR-11_战术阻滞_行动前.txt
# 20_2-10_病入膏肓_行动后.txt
# 2_2-1_龙门之行_行动后.txt
# 3_2-2_兵不接刃_行动前.txt
# 4_2-2_兵不接刃_行动后.txt
# 5_2-3_无罪推定_行动前.txt
# 6_2-3_无罪推定_行动后.txt
# 7_2-4_企鹅物流_行动前.txt
# 8_2-4_企鹅物流_行动后.txt
# 9_2-5_高空坠物_行动前.txt
# 10_R8-5_寒冷，来自知觉_行动前.txt
# 11_R8-5_寒冷，来自知觉_行动后.txt
# 12_M8-4_意志，片缕幻影.txt
# 13_R8-6_战场，蔓延不止_行动前.txt
# 14_R8-6_战场，蔓延不止_行动后.txt
# 15_M8-5_厄运，等候已久.txt
# 16_R8-8_人心，向背无常_行动前.txt
# 17_R8-8_人心，向背无常_行动后.txt
# 18_M8-6_再见，只为再见_行动前.txt
# 19_M8-6_再见，只为再见_行动后.txt
# 1_R8-1_昨日，谷壳将裂_行动前.txt
# 20_R8-9_相逢，总是离别_行动前.txt
# 21_R8-9_相逢，总是离别_行动后.txt
# 22_M8-7_恶言，报应不爽_行动前.txt
# 23_M8-7_恶言，报应不爽_行动后.txt
# 24_R8-11_落雪，浸黑国土_行动前.txt
# 25_R8-11_落雪，浸黑国土_行动后.txt
# 26_M8-8_苏醒，浮出梦乡_行动前.txt
# 27_M8-8_苏醒，浮出梦乡_行动后.txt
# 28_JT8-1_恨火，流向原野_行动前.txt
# 29_JT8-1_恨火，流向原野_行动后.txt
# 2_R8-1_昨日，谷壳将裂_行动后.txt
# 30_JT8-2_睁眼，便是日暮_行动前.txt
# 31_JT8-2_睁眼，便是日暮_行动后.txt
# 32_JT8-3_昂首，足践烈焰_行动前.txt
# 33_JT8-3_昂首，足践烈焰_行动后.txt
# 34_END8-1_尾声，抑或开始.txt
# 35_EG-1_燃烧的片段1.txt
# 36_EG-2_燃烧的片段2.txt
# 37_EG-3_燃烧的片段3.txt
# 38_EG-4_燃烧的片段4.txt
# 39_EG-5_燃烧的片段5.txt
# 3_M8-1_今日，血色满溢.txt
# 4_R8-3_麦秆，极易燃烧_行动前.txt
# 5_R8-3_麦秆，极易燃烧_行动后.txt
# 6_M8-2_失语，产自多言.txt
# 7_R8-4_火种，一触即灭_行动前.txt
# 8_R8-4_火种，一触即灭_行动后.txt
# 9_M8-3_死亡，召之即来.txt
# 10_4-5_官僚主义_行动后.txt
# 11_4-6_少见多怪_行动前.txt
# 12_4-6_少见多怪_行动后.txt
# 13_4-7_各取所需_行动前.txt
# 14_4-7_各取所需_行动后.txt
# 15_4-8_应激反应_行动前.txt
# 16_4-8_应激反应_行动后.txt
# 17_4-9_彻入骨髓_行动前.txt
# 18_4-9_彻入骨髓_行动后.txt
# 19_4-10_灯火将熄_行动前.txt
# 1_4-1_免费拥抱_行动前.txt
# 20_4-10_灯火将熄_行动后.txt
# 2_4-1_免费拥抱_行动后.txt
# 3_4-2_雨中漫步_行动前.txt
# 4_4-2_雨中漫步_行动后.txt
# 5_4-3_人工制冷_行动前.txt
# 6_4-3_人工制冷_行动后.txt
# 7_4-4_不要恐慌_行动前.txt
# 8_4-4_不要恐慌_行动后.txt
# 9_4-5_官僚主义_行动前.txt
# 10_13-6_典范之名_行动前.txt
# 11_13-6_典范之名_行动后.txt
# 12_TR-24_寻迹而行_行动前.txt
# 13_13-8_不虞之会_行动后.txt
# 14_13-9_窥冠冕者.txt
# 15_13-10_幻境迁流_行动后.txt
# 16_13-11_小镇翳云_行动前.txt
# 17_13-12_破碎温室_行动前.txt
# 18_13-14_猩红烟火_行动后.txt
# 19_13-15_短暂齐聚_行动后.txt
# 1_13-1_战场内外.txt
# 20_13-16_“我们”_行动前.txt
# 21_13-16_“我们”_行动后.txt
# 22_13-17_谁来倾诉_行动前.txt
# 23_13-18_挺起胸膛_行动后.txt
# 24_13-20_血潮翻涌_行动后.txt
# 25_13-21_殷红君主_行动前.txt
# 26_13-21_殷红君主_行动后.txt
# 27_13-22_灾厄积渐.txt
# 2_13-2_眼前的伤_行动前.txt
# 3_13-2_眼前的伤_行动后.txt
# 4_13-3_不得暂歇_行动前.txt
# 5_13-3_不得暂歇_行动后.txt
# 6_13-4_佣兵一日_行动前.txt
# 7_13-4_佣兵一日_行动后.txt
# 8_13-5_苦厄盘桓_行动前.txt
# 9_13-5_苦厄盘桓_行动后.txt
# 10_12-7_平议生死_行动前.txt
# 11_12-8_火线重逢_行动后.txt
# 12_12-9_热血年华_行动前.txt
# 13_12-10_广播热线正繁忙_行动后.txt
# 14_12-11_时不我待.txt
# 15_12-12_脱帽致敬_行动前.txt
# 16_12-13_逆光阴影_行动后.txt
# 17_12-14_捂住耳朵_行动前.txt
# 18_12-14_捂住耳朵_行动后.txt
# 19_12-15_千疮百孔_行动前.txt
# 1_12-1_火光热浪.txt
# 20_12-15_千疮百孔_行动后.txt
# 21_12-16_天边的火烧云_行动前.txt
# 22_12-17_被弃之人_行动后.txt
# 23_12-18_晚安_行动前.txt
# 24_12-19_飞跃，烟火_行动后.txt
# 25_12-20_诚挚邀请_行动前.txt
# 26_12-20_诚挚邀请_行动后.txt
# 27_12-21_战场静悄悄.txt
# 2_12-2_静候驾临_行动前.txt
# 3_12-2_静候驾临_行动后.txt
# 4_12-3_善意背叛_行动前.txt
# 5_12-3_善意背叛_行动后.txt
# 6_12-4_团结就是奢望_行动前.txt
# 7_12-4_团结就是奢望_行动后.txt
# 8_12-5_脆钢_行动前.txt
# 9_12-6_谁的战争_行动后.txt
# 10_14-6_确认交战视界_行动前.txt
# 11_14-6_确认交战视界_行动后.txt
# 12_14-7_执行反制作战_行动前.txt
# 13_14-7_执行反制作战_行动后.txt
# 14_14-8_抵近支援作战_行动前.txt
# 15_14-8_抵近支援作战_行动后.txt
# 16_14-9_应对饱和打击_行动前.txt
# 17_14-9_应对饱和打击_行动后.txt
# 18_14-10_自光辉中奔涌_行动前.txt
# 19_14-10_自光辉中奔涌_行动后.txt
# 1_14-1_从回忆中坠落.txt
# 20_14-11_所谓“英雄”_行动前.txt
# 21_14-11_所谓“英雄”_行动后.txt
# 22_14-12_使徒_行动前.txt
# 23_14-12_使徒_行动后.txt
# 24_14-13_自原点中降临.txt
# 25_14-14_高空拒阻行动_行动前.txt
# 26_14-15_突破外围防线_行动后.txt
# 27_14-16_抢占舷侧区域_行动前.txt
# 28_14-16_抢占舷侧区域_行动后.txt
# 29_14-17_核心舱攻防战_行动前.txt
# 2_14-2_作战对策会议_行动前.txt
# 30_14-18_在炽燃间咆哮_行动前.txt
# 31_14-18_在炽燃间咆哮_行动后.txt
# 32_14-19_晶簇之内_行动前.txt
# 33_14-19_晶簇之内_行动后.txt
# 34_14-20_列王行迹_行动前.txt
# 35_14-20_列王行迹_行动后.txt
# 36_14-21_万千愿景_行动前.txt
# 37_14-21_万千愿景_行动后.txt
# 38_14-22_在哀愁绽放的时刻_行动前.txt
# 39_14-22_在哀愁绽放的时刻_行动后.txt
# 3_14-2_作战对策会议_行动后.txt
# 40_14-23_良夜将死.txt
# 41_EG-6_慈悲遗愿.txt
# 4_14-3_破解锤砧战术_行动前.txt
# 5_14-3_破解锤砧战术_行动后.txt
# 6_14-4_通讯静默解除_行动前.txt
# 7_14-4_通讯静默解除_行动后.txt
# 8_14-5_探查岩洞区域_行动前.txt
# 9_14-5_探查岩洞区域_行动后.txt
# 1_14-1_从回忆中坠落plot-checkpoint.txt
# 10_11-6_演绎文明_行动前.txt
# 11_11-7_卷入洪流_行动后.txt
# 12_11-8_停滞_行动前.txt
# 13_11-8_停滞_行动后.txt
# 14_11-9_以命换命_行动前.txt
# 15_11-9_以命换命_行动后.txt
# 16_11-10_异路相对.txt
# 17_11-11_立场不同_行动前.txt
# 18_11-12_汹涌而来_行动后.txt
# 19_11-14_一场相见_行动前.txt
# 1_11-1_维护荣耀_行动前.txt
# 20_11-14_一场相见_行动后.txt
# 21_11-15_土地震颤_行动前.txt
# 22_11-16_荣光猎场_行动后.txt
# 23_11-17_回答我_行动前.txt
# 24_11-17_回答我_行动后.txt
# 25_11-19_直指命运_行动前.txt
# 26_11-19_直指命运_行动后.txt
# 27_11-21_不可避免.txt
# 2_11-1_维护荣耀_行动后.txt
# 3_11-2_一丝光亮_行动前.txt
# 4_11-2_一丝光亮_行动后.txt
# 5_11-3_蒸汽升腾_行动前.txt
# 6_11-3_蒸汽升腾_行动后.txt
# 7_11-4_何谓理想.txt
# 8_11-5_等价交换_行动前.txt
# 9_11-5_等价交换_行动后.txt
# 10_10-6_虽非同族_行动前.txt
# 11_10-6_虽非同族_行动后.txt
# 12_10-7_痛觉相连_行动前.txt
# 13_10-8_无暇哀悼_行动后.txt
# 14_10-9_他乡故知_行动前.txt
# 15_10-9_他乡故知_行动后.txt
# 16_10-10_旧日之影_行动前.txt
# 17_10-10_旧日之影_行动后.txt
# 18_10-11_千疮百孔_行动前.txt
# 19_10-12_仇怨的尽头_行动后.txt
# 1_10-1_被追逐者.txt
# 20_10-13_交叉路口.txt
# 21_10-14_瞄准_行动前.txt
# 22_10-14_瞄准_行动后.txt
# 23_10-15_逃离炮火_行动前.txt
# 24_10-16_血刃高悬_行动后.txt
# 25_10-17_坚城高墙_行动前.txt
# 26_10-17_坚城高墙_行动后.txt
# 27_10-18_理想的倒影.txt
# 28_10-19_远方星火.txt
# 2_10-2_抢夺目标_行动前.txt
# 3_10-2_抢夺目标_行动后.txt
# 4_10-3_低下头_行动前.txt
# 5_10-3_低下头_行动后.txt
# 6_10-4_鸣铳示警_行动前.txt
# 7_10-4_鸣铳示警_行动后.txt
# 8_10-5_城市的呼吸_行动前.txt
# 9_10-5_城市的呼吸_行动后.txt
# 10_7-7_26：37：14.txt
# 11_7-8_沉默者之怒-1_行动前.txt
# 12_7-9_沉默者之怒-2_行动后.txt
# 13_7-10_暗淡者之火_行动前.txt
# 14_7-10_暗淡者之火_行动后.txt
# 15_7-13_感染者之盾-1_行动前.txt
# 16_7-17_感染者之盾-2_行动后.txt
# 17_7-18_爱国者之死_行动前.txt
# 18_7-18_爱国者之死_行动后.txt
# 19_7-19_11：15：38.txt
# 1_7-1_32：00：00.txt
# 20_7-20_？？：？？：？？.txt
# 2_7-2_别离之夜_行动前.txt
# 3_7-2_别离之夜_行动后.txt
# 4_7-3_变节之刃_行动前.txt
# 5_7-3_变节之刃_行动后.txt
# 6_7-4_并肩之约-1_行动前.txt
# 7_7-5_并肩之约-2_行动后.txt
# 8_7-6_遗忘之地_行动前.txt
# 9_7-6_遗忘之地_行动后.txt
# 10_5-6_疑兵之计_行动后.txt
# 11_5-7_生死与共_行动前.txt
# 12_5-7_生死与共_行动后.txt
# 13_5-9_孽生恶物_行动前.txt
# 14_5-9_孽生恶物_行动后.txt
# 15_5-10_长夜终尽_行动前.txt
# 16_5-10_长夜终尽_行动后.txt
# 17_5-11_棋胜后着.txt
# 1_5-1_冤家易结_行动前.txt
# 2_5-1_冤家易结_行动后.txt
# 3_5-2_有口难言_行动前.txt
# 4_5-2_有口难言_行动后.txt
# 5_5-3_义胆凡躯_行动前.txt
# 6_5-3_义胆凡躯_行动后.txt
# 7_5-4_没人在家_行动前.txt
# 8_5-4_没人在家_行动后.txt
# 9_5-6_疑兵之计_行动前.txt
# 10_9-8_灰烬中的诗.txt
# 11_9-9_无辜者_行动前.txt
# 12_9-10_雷声轰鸣_行动后.txt
# 13_9-12_鬼影如潮_行动前.txt
# 14_9-13_战地救援_行动后.txt
# 15_9-14_风中旗帜_行动前.txt
# 16_9-18_“破晓”_行动后.txt
# 17_9-19_长夜枪火_行动前.txt
# 18_9-19_长夜枪火_行动后.txt
# 19_9-20_临近的暴风.txt
# 1_9-1_风暴突击.txt
# 20_9-21_重燃.txt
# 2_9-2_鬼魂危机_行动前.txt
# 3_9-3_牌局_行动后.txt
# 4_9-4_暗火四起_行动前.txt
# 5_9-4_暗火四起_行动后.txt
# 6_9-5_临界值_行动前.txt
# 7_9-5_临界值_行动后.txt
# 8_9-6_深池_行动前.txt
# 9_9-7_捉迷藏_行动后.txt
# 10_0-7_感染_行动后.txt
# 11_0-8_狩猎_行动前.txt
# 12_0-9_临光_行动后.txt
# 13_0-10_困境_行动前.txt
# 14_0-11_突围_行动后.txt
# 1_序章·上.txt
# 2_序章·下.txt
# 3_0-1_坍塌_行动前.txt
# 4_0-1_坍塌_行动后.txt
# 5_0-2_守卫_行动前.txt
# 6_0-2_守卫_行动后.txt
# 7_0-4_混战_行动前.txt
# 8_0-6_强击_行动后.txt
# 9_0-7_感染_行动前.txt
# 10_1-10_残留_行动后.txt
# 11_1-12_代价_行动前.txt
# 12_1-12_代价_行动后.txt
# 1_1-1_孤岛_行动前.txt
# 2_1-1_孤岛_行动后.txt
# 3_1-3_狂奔_行动前.txt
# 4_1-3_狂奔_行动后.txt
# 5_1-4_先兆_行动前.txt
# 6_1-6_灾难_行动前.txt
# 7_1-7_暴君_行动前.txt
# 8_1-7_暴君_行动后.txt
# 9_1-8_意志_行动前.txt
# Ace.txt
# Alty.txt
# Aya.txt
# D.D.D..txt
# Dan.txt
# Dijkstra.txt
# Frost.txt
# Guard.txt
# Logos.txt
# Mantra.txt
# Mechanist.txt
# Medic.txt
# Misery.txt
# Outcast.txt
# Pith.txt
# PRTS.txt
# Scout.txt
# Sharp.txt
# Stormeye.txt
# Touch.txt
# 万尼亚大公.txt
# 三角铁.txt
# 乌尔苏拉.txt
# 乔万娜·罗塞蒂.txt
# 九.txt
# 伊万杰利斯塔十一世.txt
# 伊内丝.txt
# 伊斯.txt
# 伊斯拉姆·维特.txt
# 伊比利亚主教.txt
# 伍德洛.txt
# 休露丝.txt
# 何塞.txt
# 依娜姆.txt
# 依拉.txt
# 光头马丁.txt
# 克丽斯腾·莱特.txt
# 克洛宁.txt
# 克洛维希娅.txt
# 克罗绮·砖石.txt
# 克里夫.txt
# 克雷格.txt
# 凋零骑士.txt
# 切斯特.txt
# 别格勒.txt
# 加勒斯.txt
# 加尔森.txt
# 加西亚.txt
# 博士.txt
# 卡奇·叙光.txt
# 卡彭.txt
# 古罗.txt
# 可萝尔.txt
# 可露希尔.txt
# 叶克多.txt
# 图拉.txt
# 圣徒卡门.txt
# 坎诺特.txt
# 坎黛拉.txt
# 塑料骑士.txt
# 塔佳娜.txt
# 塔季娅娜.txt
# 塔露拉.txt
# 塞弗林.txt
# 塞茜莉亚.txt
# 大嘴莫布.txt
# 大审判官.txt
# 大帝.txt
# 大祭司.txt
# 大长老.txt
# 大鲍勃.txt
# 太傅.txt
# 太合.txt
# 奥伦.txt
# 宁小姐.txt
# 安东尼奥.txt
# 安多恩.txt
# 安妮塔.txt
# 安托.txt
# 尤利娅·许勒尔.txt
# 尤卡坦.txt
# 左手骑士.txt
# 巴顿.txt
# 布兰特·赖纳.txt
# 希尔.txt
# 帕蒂亚.txt
# 弃械.txt
# 弑君者.txt
# 弗莱蒙特.txt
# 弗里达·希曼.txt
# 德米特里·切塔尔多.txt
# 德鲁奇.txt
# 恰尔内.txt
# 战士比尔.txt
# 托兰.txt
# 托尔.txt
# 扬·许勒尔.txt
# 拉赫曼.txt
# 挑山人.txt
# 文月.txt
# 文森特伯爵.txt
# 斐尔迪南·克鲁尼.txt
# 斯特凡诺·托雷格罗萨.txt
# 昆图斯.txt
# 普瑞赛斯.txt
# 曼弗雷德.txt
# 朵拉.txt
# 杜克.txt
# 杜小姐.txt
# 杜玛.txt
# 杰斯顿.txt
# 格哈德·霍夫曼.txt
# 格特鲁德.txt
# 格罗瓦兹尔.txt
# 桑尼.txt
# 梁洵.txt
# 梅菲斯特.txt
# 欧厄尔.txt
# 毕德曼.txt
# 汉密尔顿.txt
# 沃尔纳·冯·霍赫贝格.txt
# 洛里斯·博尔丁.txt
# 浮士德.txt
# 海伦.txt
# 潘乔.txt
# 爱国者.txt
# 爱德华.txt
# 爷爷.txt
# 特蕾西娅.txt
# 特雷西斯.txt
# 玛丽.txt
# 珂拉·洛文斯坦.txt
# 瓦莱丝.txt
# 甘比诺.txt
# 白垩.txt
# 皮加尔.txt
# 碎骨.txt
# 碧银.txt
# 科西切.txt
# 管家.txt
# 米亚罗.txt
# 米莎.txt
# 缪尔赛思.txt
# 罗伊.txt
# 罗素.txt
# 老伊辛.txt
# 老何塞.txt
# 老工匠.txt
# 老船夫.txt
# 老骑士.txt
# 耶奇·地心.txt
# 腐败骑士.txt
# 芭芭拉.txt
# 莉莉娅.txt
# 莫妮克.txt
# 莫希.txt
# 莱姆.txt
# 菈塔托丝.txt
# 董阿伯.txt
# 蒂亚戈.txt
# 蔓德拉.txt
# 蕾缪安.txt
# 薇卡.txt
# 薇尔丽芙.txt
# 血骑士.txt
# 血魔大君.txt
# 西尔莎.txt
# 西莫·威廉姆斯.txt
# 解真.txt
# 说书人.txt
# 贝纳尔多·贝洛内.txt
# 费奥多尔.txt
# 费斯特.txt
# 费莉亚·拉珀尔塔.txt
# 赫尔昏佐伦.txt
# 赫尔曼.txt
# 赫德雷.txt
# 路易斯·凯利.txt
# 迪伦马特.txt
# 逐魇骑士.txt
# 郑掌柜.txt
# 锈铜骑士.txt
# 阿丽娜.txt
# 阿伦茨·帕尔维斯.txt
# 阿克托斯.txt
# 阿勒黛·坎伯兰.txt
# 阿发.txt
# 阿尔图罗.txt
# 阿尔贝托·萨卢佐.txt
# 阿方索.txt
# 阿格尼尔.txt
# 阿然.txt
# 阿玛雅.txt
# 阿赫茉妮.txt
# 霜星.txt
# 食腐者之王.txt
# 马克维茨.txt
# 魏彦吾.txt
# 麦克马丁.txt
# 麦基.txt
# 黎.txt
# 黛柯绮·银币.txt
# 鼠王.txt
# 12F.txt
# Castle-3.txt
# Friston-3.txt
# Lancet-2.txt
# PhonoR-0.txt
# THRM-EX.txt
# U-Official.txt
# W.txt
# 万顷.txt
# 临光.txt
# 乌尔比安.txt
# 乌有.txt
# 九色鹿.txt
# 亚叶.txt
# 仇白.txt
# 令.txt
# 伊内丝.txt
# 伊桑.txt
# 伊芙利特.txt
# 休谟斯.txt
# 伺夜.txt
# 但书.txt
# 佩佩.txt
# 假日威龙陈.txt
# 傀影.txt
# 克洛丝.txt
# 冰酿.txt
# 凛冬.txt
# 凛视.txt
# 凯尔希.txt
# 初雪.txt
# 刺玫.txt
# 刻俄柏.txt
# 刻刀.txt
# 医生.txt
# 华法琳.txt
# 博士.txt
# 卡夫卡.txt
# 卡涅利安.txt
# 卡缇.txt
# 卡达.txt
# 历阵锐枪芬.txt
# 双月.txt
# 古米.txt
# 可颂.txt
# 史尔特尔.txt
# 史都华德.txt
# 号角.txt
# 吽.txt
# 和弦.txt
# 哈洛德.txt
# 嘉维尔.txt
# 四月.txt
# 因陀罗.txt
# 图耶.txt
# 圣约送葬人.txt
# 地灵.txt
# 坚雷.txt
# 埃拉托.txt
# 塑心.txt
# 塞雷娅.txt
# 夏栎.txt
# 夕.txt
# 多萝西.txt
# 夜刀.txt
# 夜半.txt
# 夜烟.txt
# 夜莺.txt
# 夜魔.txt
# 天火.txt
# 奥斯塔.txt
# 奥达.txt
# 妮芙.txt
# 娜仁图亚.txt
# 子月.txt
# 孑.txt
# 守林人.txt
# 安哲拉.txt
# 安德切尔.txt
# 安比尔.txt
# 安洁莉娜.txt
# 安赛尔.txt
# 宴.txt
# 寒檀.txt
# 寒芒克洛丝.txt
# 导火索.txt
# 小满.txt
# 山.txt
# 崖心.txt
# 嵯峨.txt
# 巡林者.txt
# 左乐.txt
# 巫恋.txt
# 布丁.txt
# 布洛卡.txt
# 帕拉斯.txt
# 年.txt
# 幽灵鲨.txt
# 异客.txt
# 归溟幽灵鲨.txt
# 微风.txt
# 德克萨斯.txt
# 惊蛰.txt
# 慑砂.txt
# 慕斯.txt
# 战车.txt
# 截云.txt
# 戴菲恩.txt
# 承曦格雷伊.txt
# 折光.txt
# 拉普兰德.txt
# 拜松.txt
# 掠风.txt
# 推进之王.txt
# 提丰.txt
# 摩根.txt
# 文月.txt
# 斑点.txt
# 斥罪.txt
# 断崖.txt
# 断罪者.txt
# 斯卡蒂.txt
# 早露.txt
# 明椒.txt
# 星极.txt
# 星源.txt
# 星熊.txt
# 晓歌.txt
# 普罗旺斯.txt
# 暗索.txt
# 暮落.txt
# 暴行.txt
# 暴雨.txt
# 月禾.txt
# 月见夜.txt
# 末药.txt
# 术髓.txt
# 杏仁.txt
# 杜宾.txt
# 杜林.txt
# 杰克.txt
# 杰西卡.txt
# 松果.txt
# 极光.txt
# 极境.txt
# 林.txt
# 柏喙.txt
# 格劳克斯.txt
# 格拉尼.txt
# 格雷伊.txt
# 桃金娘.txt
# 桑葚.txt
# 梅.txt
# 梅尔.txt
# 梓兰.txt
# 棘刺.txt
# 森蚺.txt
# 槐琥.txt
# 歌蕾蒂娅.txt
# 止颂.txt
# 正义骑士号.txt
# 水月.txt
# 泡普卡.txt
# 泡泡.txt
# 波登可.txt
# 泥岩.txt
# 泰拉大陆调查团.txt
# 洋灰.txt
# 洛洛.txt
# 流明.txt
# 流星.txt
# 浊心斯卡蒂.txt
# 海沫.txt
# 海蒂.txt
# 海霓.txt
# 涤火杰西卡.txt
# 淬羽赫默.txt
# 深巡.txt
# 深律.txt
# 深海色.txt
# 深靛.txt
# 清流.txt
# 清道夫.txt
# 渡桥.txt
# 温米.txt
# 温蒂.txt
# 澄闪.txt
# 濯尘芙蓉.txt
# 火哨.txt
# 火神.txt
# 火龙S黑角.txt
# 灰喉.txt
# 灰毫.txt
# 灰烬.txt
# 灵知.txt
# 炎客.txt
# 炎熔.txt
# 炎狱炎熔.txt
# 烈夏.txt
# 焰尾.txt
# 焰影苇草.txt
# 煌.txt
# 熔泉.txt
# 燧石.txt
# 爱丽丝.txt
# 特米米.txt
# 狮蝎.txt
# 猎蜂.txt
# 玛恩纳.txt
# 玫兰莎.txt
# 玫拉.txt
# 琳琅诗怀雅.txt
# 琴柳.txt
# 瑕光.txt
# 白金.txt
# 白铁.txt
# 白雪.txt
# 白面鸮.txt
# 百炼嘉维尔.txt
# 真理.txt
# 石棉.txt
# 石英.txt
# 砾.txt
# 稀音.txt
# 空.txt
# 空弦.txt
# 空构.txt
# 空爆.txt
# 米格鲁.txt
# 絮雨.txt
# 红.txt
# 红云.txt
# 红豆.txt
# 红隼.txt
# 纯烬艾雅法拉.txt
# 绮良.txt
# 维什戴尔.txt
# 维荻.txt
# 缄默德克萨斯.txt
# 缠丸.txt
# 缪尔赛思.txt
# 罗宾.txt
# 罗小黑.txt
# 罗比菈塔.txt
# 羽毛笔.txt
# 翎羽.txt
# 耀骑士临光.txt
# 老鲤.txt
# 耶拉.txt
# 能天使.txt
# 至简.txt
# 艾丝黛尔.txt
# 艾丽妮.txt
# 艾拉.txt
# 艾雅法拉.txt
# 芙兰卡.txt
# 芙蓉.txt
# 芬.txt
# 芳汀.txt
# 苇草.txt
# 苍苔.txt
# 苏苏洛.txt
# 苦艾.txt
# 莎草.txt
# 莫斯提马.txt
# 莱伊.txt
# 莱恩哈特.txt
# 菲亚梅塔.txt
# 蓝毒.txt
# 薄绿.txt
# 薇薇安娜.txt
# 蚀清.txt
# 蛇屠箱.txt
# 蜜莓.txt
# 蜜蜡.txt
# 衡沙.txt
# 褐果.txt
# 见行者.txt
# 角峰.txt
# 触痕.txt
# 讯使.txt
# 诗怀雅.txt
# 调香师.txt
# 谜图.txt
# 豆苗.txt
# 贝娜.txt
# 贾维.txt
# 赤冬.txt
# 赫德雷.txt
# 赫拉格.txt
# 赫默.txt
# 跃跃.txt
# 车尔尼.txt
# 达格达.txt
# 远山.txt
# 远牙.txt
# 迷迭香.txt
# 送葬人.txt
# 逻各斯.txt
# 郁金香.txt
# 酸糖.txt
# 重岳.txt
# 野鬃.txt
# 铃兰.txt
# 铅踝.txt
# 铎铃.txt
# 银灰.txt
# 铸铁.txt
# 锋刃.txt
# 锏.txt
# 锡人.txt
# 锡兰.txt
# 闪击.txt
# 闪灵.txt
# 阿.txt
# 阿斯卡纶.txt
# 阿消.txt
# 阿米娅.txt
# 阿罗玛.txt
# 陈.txt
# 陨星.txt
# 隐现.txt
# 雪绒.txt
# 雪雉.txt
# 雷蛇.txt
# 霍尔海雅.txt
# 霜华.txt
# 霜叶.txt
# 露托.txt
# 青枳.txt
# 鞭刃.txt
# 风丸.txt
# 风暴眼.txt
# 风笛.txt
# 食铁兽.txt
# 香草.txt
# 魏彦吾.txt
# 魔王.txt
# 鸿雪.txt
# 麒麟R夜刀.txt
# 麦哲伦.txt
# 黍.txt
# 黑.txt
# 黑角.txt
# 黑键.txt
# 龙舌兰.txt
# 1_习惯.txt
# 2_被选择的.txt
# 3_在梦中相遇.txt
# 4_表里不一.txt
# 5_胡言秘语.txt
# 6_一切照常.txt
# 7_在春天之前.txt
# 1_来办联欢会吧.txt
# 2_日记本.txt
# 3_今日厨房.txt
# 4_流浪者的归宿.txt
# 5_自讨苦吃.txt
# 6_向前走.txt
# 1_盖不住的锅盖.txt
# 2_不回头的车辙.txt
# 3_狂奔的瓶树.txt
# 4_落定的锤子.txt
# 5_咧嘴的矿井.txt
# 6_被踩住的影子.txt
# 1_向左向右.txt
# 2_隔墙有你.txt
# 3_扬尼与我.txt
# 4_告别时刻.txt
# 5_一次重逢.txt
# 6_别太紧张.txt
# 1_我不曾怀揣希望.txt
# 2_我不会全部遗忘.txt
# 3_我不知是否值得.txt
# 4_我所思不止于此.txt
# 5_我无惧前路何往.txt
# 6_我与最后的赌注.txt
# 1_无名氏的战争.txt
# 2_破局者.txt
# 3_射击训练.txt
# 4_存续公正.txt
# 5_课后作业.txt
# 6_北极星.txt
# 7_和光同尘.txt
# 1_荒舍.txt
# 2_只见星辰.txt
# 3_我曾凝望.txt
# 4_不得安宁.txt
# 5_日落已久.txt
# 6_空盔甲.txt
# 7_告别词.txt
# 1_近乡情怯.txt
# 2_中庭旅谷.txt
# 3_不问鬼神.txt
# 4_出入平安.txt
# 5_无名之辈.txt
# 6_独见寒山.txt
# 1_布朗陶.txt
# 2_后会有期.txt
# 3_狼与狼群.txt
# 4_再见罗伊.txt
# 5_和而不同.txt
# 6_真实故事.txt
# 1_无续集.txt
# 2_荒野路漫漫.txt
# 3_童话永存.txt
# 4_信仰号街车.txt
# 5_盲盒旅途.txt
# 6_剑与天秤.txt
# 7_为更好的自己.txt
# 1_洪炉示岁·迎春.txt
# 2_洪炉示岁·贺岁.txt
# 3_洪炉示岁·拜年.txt
# 1_粉碎大地.txt
# 2_烁烁星火.txt
# 3_真假怪谈.txt
# 4_遗落灯塔.txt
# 5_异类.txt
# 6_信.txt
# 1_如烟花般坠地.txt
# 2_归来时的街道.txt
# 3_披床单的怪物.txt
# 4_未完成的态度.txt
# 5_女巫与下午茶.txt
# 6_罐头里有什么.txt
# 1_沉于冰寒.txt
# 2_冰原的女儿.txt
# 3_树影幢幢.txt
# 4_自然的启示.txt
# 5_归乡.txt
# 6_终有一日.txt
# 7_未见之景.txt
# 1_红松.txt
# 2_落灰.txt
# 3_我也要大干一场.txt
# 4_只影孤身.txt
# 5_骑士之道.txt
# 6_大人物.txt
# 7_随风飘荡.txt
# 1_归处.txt
# 2_域外同族.txt
# 3_不知返.txt
# 4__回首.txt
# 5_四月的歌.txt
# 6_交错光影.txt
# 7_天空的故事.txt
# 1_或许有时.txt
# 2_我如浮萍.txt
# 3_终将同行.txt
# 4_孤行骑警.txt
# 5_必有所偿.txt
# 6_叮咚作响.txt
# 10_CV-ST-2_突然冲击.txt
# 11_CV-5_疑惑之影_行动前.txt
# 12_CV-5_疑惑之影_行动后.txt
# 13_CV-6_猎人之夜_行动前.txt
# 14_CV-6_猎人之夜_行动后.txt
# 15_CV-7_白热_行动前.txt
# 16_CV-7_白热_行动后.txt
# 17_CV-8_告别往昔_行动前.txt
# 18_CV-8_告别往昔_行动后.txt
# 19_CV-ST-3_法外之徒.txt
# 1_CV-ST-1_火线之中.txt
# 2_CV-1_孤独之地_行动前.txt
# 3_CV-1_孤独之地_行动后.txt
# 4_CV-2_双重保险_行动前.txt
# 5_CV-2_双重保险_行动后.txt
# 6_CV-3_圈套_行动前.txt
# 7_CV-3_圈套_行动后.txt
# 8_CV-4_缺席的人_行动前.txt
# 9_CV-4_缺席的人_行动后.txt
# 10_IS-ST-2_切开.txt
# 11_IS-5_恒久法则_行动前.txt
# 12_IS-5_恒久法则_行动后.txt
# 13_IS-6_旧日碾轧_行动前.txt
# 14_IS-6_旧日碾轧_行动后.txt
# 15_IS-7_何以忘却_行动前.txt
# 16_IS-7_何以忘却_行动后.txt
# 17_IS-8_危如累卵_行动前.txt
# 18_IS-8_危如累卵_行动后.txt
# 19_IS-ST-3_剜刺.txt
# 1_IS-ST-1_沉疴.txt
# 20_IS-9_文明的谎言_行动前.txt
# 21_IS-9_文明的谎言_行动后.txt
# 22_IS-10_“狼之主”_行动前.txt
# 23_IS-10_“狼之主”_行动后.txt
# 24_IS-ST-4_缝合.txt
# 2_IS-1_雨落无声_行动前.txt
# 3_IS-1_雨落无声_行动后.txt
# 4_IS-2_荣誉之人_行动前.txt
# 5_IS-2_荣誉之人_行动后.txt
# 6_IS-3_万箭所指_行动前.txt
# 7_IS-3_万箭所指_行动后.txt
# 8_IS-4_苦夜惊雷_行动前.txt
# 9_IS-4_苦夜惊雷_行动后.txt
# 10_GA-5_葬礼_行动前.txt
# 11_GA-5_葬礼_行动后.txt
# 12_GA-6_安魂曲_行动前.txt
# 13_GA-6_安魂曲_行动后.txt
# 14_GA-7_光与影_行动前.txt
# 15_GA-7_光与影_行动后.txt
# 16_GA-8_影与灰_行动前.txt
# 17_GA-8_影与灰_行动后.txt
# 18_GA-ST-2_鸢尾花.txt
# 1_GA-ST-1_风云际会.txt
# 2_GA-1_灯下黑_行动前.txt
# 3_GA-1_灯下黑_行动后.txt
# 4_GA-2_散步时光_行动前.txt
# 5_GA-2_散步时光_行动后.txt
# 6_GA-3_混血儿_行动前.txt
# 7_GA-3_混血儿_行动后.txt
# 8_GA-4_安魂教堂_行动前.txt
# 9_GA-4_安魂教堂_行动后.txt
# 10_CB-5_8：31P.M._行动前.txt
# 11_CB-5_8：31P.M._行动后.txt
# 12_CB-ST1_晚风轻拂.txt
# 13_CB-6_10：26P.M._行动前.txt
# 14_CB-6_10：26P.M._行动后.txt
# 15_CB-7_11：08P.M._行动前.txt
# 16_CB-7_11：08P.M._行动后.txt
# 17_CB-8_11：41P.M._行动前.txt
# 18_CB-8_11：41P.M._行动后.txt
# 19_CB-ST2_午夜龙门.txt
# 1_序章.txt
# 20_CB-9_0：01A.M._行动前.txt
# 21_CB-9_0：01A.M._行动后.txt
# 22_CB-10_1：11A.M._行动前.txt
# 23_CB-10_1：11A.M._行动后.txt
# 24_CB-ST3_破晓时分.txt
# 25_CB-EX1_群架诀窍_行动后.txt
# 26_CB-EX2_南辕北辙_行动后.txt
# 27_CB-EX3_林中小屋_行动后.txt
# 2_CB-1_6：44P.M._行动前.txt
# 3_CB-1_6：44P.M._行动后.txt
# 4_CB-2_7：15P.M._行动前.txt
# 5_CB-2_7：15P.M._行动后.txt
# 6_CB-3_7：22P.M._行动前.txt
# 7_CB-3_7：22P.M._行动后.txt
# 8_CB-4_7：59P.M._行动前.txt
# 9_CB-4_7：59P.M._行动后.txt
# 10_DH-4_铁人三项_行动前.txt
# 11_DH-4_铁人三项_行动后.txt
# 12_DH-5_曲径求胜_行动前.txt
# 13_DH-5_曲径求胜_行动后.txt
# 14_DH-6_紧追猛赶_行动前.txt
# 15_DH-6_紧追猛赶_行动后.txt
# 16_DH-ST-3_请君入瓮.txt
# 17_DH-7_沙滩阻击_行动前.txt
# 18_DH-8_抢滩登陆_行动后.txt
# 19_DH-9_鼠胆龙威_行动前.txt
# 1_DH-ST-1_不期而遇.txt
# 20_DH-9_鼠胆龙威_行动后.txt
# 21_DH-ST-4_海浪照常拍岸.txt
# 2_DH-TR-1_初来乍到_行动后.txt
# 3_DH-1_意外入选_行动前.txt
# 4_DH-1_意外入选_行动后.txt
# 5_DH-2_首轮竞赛_行动前.txt
# 6_DH-2_首轮竞赛_行动后.txt
# 7_DH-3_拔铳相助_行动前.txt
# 8_DH-3_拔铳相助_行动后.txt
# 9_DH-ST-2_中场休息.txt
# 10_MB-5_危险交易_行动前.txt
# 11_MB-5_危险交易_行动后.txt
# 12_MB-6_制定计划_行动前.txt
# 13_MB-6_制定计划_行动后.txt
# 14_MB-7_背叛_行动前.txt
# 15_MB-7_背叛_行动后.txt
# 16_MB-8_激战之末_行动前.txt
# 17_MB-8_激战之末_行动后.txt
# 18_MB-ST-2_正确的代价.txt
# 1_MB-1_密会_行动前.txt
# 2_MB-1_密会_行动后.txt
# 3_MB-2_另一个视角_行动前.txt
# 4_MB-2_另一个视角_行动后.txt
# 5_MB-3_首次遇袭_行动前.txt
# 6_MB-3_首次遇袭_行动后.txt
# 7_MB-ST-1_邀请.txt
# 8_MB-4_勇敢，莽撞_行动前.txt
# 9_MB-4_勇敢，莽撞_行动后.txt
# 10_CW-4_一波又起_行动后.txt
# 11_CW-5_柳暗花明_行动前.txt
# 12_CW-5_柳暗花明_行动后.txt
# 13_CW-6_群英荟萃_行动前.txt
# 14_CW-6_群英荟萃_行动后.txt
# 15_CW-7_空中楼阁_行动前.txt
# 16_CW-7_空中楼阁_行动后.txt
# 17_CW-8_过去与现在的交会_行动前.txt
# 18_CW-8_过去与现在的交会_行动后.txt
# 19_CW-9_恩怨纠葛_行动前.txt
# 1_CW-ST-1_阴云密布.txt
# 20_CW-9_恩怨纠葛_行动后.txt
# 21_CW-10_散于星辰之间_行动前.txt
# 22_CW-10_散于星辰之间_行动后.txt
# 23_CW-ST-3_留下的人.txt
# 24_CW-ST-4_推开未来之门.txt
# 2_CW-1_迷雾重重_行动前.txt
# 3_CW-1_迷雾重重_行动后.txt
# 4_CW-2_无迹可寻_行动前.txt
# 5_CW-2_无迹可寻_行动后.txt
# 6_CW-3_台前幕后_行动前.txt
# 7_CW-3_台前幕后_行动后.txt
# 8_CW-ST-2_一波未平.txt
# 9_CW-4_一波又起_行动前.txt
# 10_RI-5_各有所长_行动前.txt
# 11_RI-5_各有所长_行动后.txt
# 12_RI-6_邂逅_行动前.txt
# 13_RI-6_邂逅_行动后.txt
# 14_RI-ST-2_休息时间.txt
# 15_RI-7_有客先来_行动前.txt
# 16_RI-7_有客先来_行动后.txt
# 17_RI-8_嘉维尔之拳_行动前.txt
# 18_RI-8_嘉维尔之拳_行动后.txt
# 19_RI-9_走出密林_行动前.txt
# 1_RI-1_高空坠物_行动前.txt
# 20_RI-9_走出密林_行动后.txt
# 21_RI-EX-1_声东击西_行动后.txt
# 2_RI-1_高空坠物_行动后.txt
# 3_RI-2_粗细有别_行动前.txt
# 4_RI-2_粗细有别_行动后.txt
# 5_RI-3_往昔_行动前.txt
# 6_RI-3_往昔_行动后.txt
# 7_RI-4_机兽咆哮_行动前.txt
# 8_RI-4_机兽咆哮_行动后.txt
# 9_RI-ST-1_悍将之心.txt
# 10_IW-ST-2_万物有灵.txt
# 11_IW-5_货与人_行动前.txt
# 12_IW-5_货与人_行动后.txt
# 13_IW-6_传说_行动前.txt
# 14_IW-6_传说_行动后.txt
# 15_IW-7_乱局_行动前.txt
# 16_IW-7_乱局_行动后.txt
# 17_IW-9_岁相_行动前.txt
# 18_IW-9_岁相_行动后.txt
# 19_IW-ST-3_再弈.txt
# 1_IW-ST-1_客将至.txt
# 2_IW-1_化物_行动前.txt
# 3_IW-1_化物_行动后.txt
# 4_IW-2_无寻处_行动前.txt
# 5_IW-2_无寻处_行动后.txt
# 6_IW-3_光与影_行动前.txt
# 7_IW-3_光与影_行动后.txt
# 8_IW-4_秉烛_行动前.txt
# 9_IW-4_秉烛_行动后.txt
# 10_LE-ST-2_春之祭.txt
# 11_LE-5_月光_行动前.txt
# 12_LE-5_月光_行动后.txt
# 13_LE-6_骷髅之舞_行动前.txt
# 14_LE-6_骷髅之舞_行动后.txt
# 15_LE-7_升华之夜_行动前.txt
# 16_LE-7_升华之夜_行动后.txt
# 17_LE-8_命运_行动前.txt
# 18_LE-8_命运_行动后.txt
# 19_LE-ST-3_自新大陆.txt
# 1_LE-ST-1_华丽大圆舞曲.txt
# 2_LE-1_闲聊波尔卡_行动前.txt
# 3_LE-1_闲聊波尔卡_行动后.txt
# 4_LE-2_热情，或悲怆_行动前.txt
# 5_LE-2_热情，或悲怆_行动后.txt
# 6_LE-3_自由射手_行动前.txt
# 7_LE-3_自由射手_行动后.txt
# 8_LE-4_惊愕_行动前.txt
# 9_LE-4_惊愕_行动后.txt
# 10_ZT-5_奏鸣曲“秋日”_行动前.txt
# 11_ZT-5_奏鸣曲“秋日”_行动后.txt
# 12_ZT-ST-2_间奏“未竟赋格”.txt
# 13_ZT-6_华尔兹“假面”_行动前.txt
# 14_ZT-6_华尔兹“假面”_行动后.txt
# 15_ZT-7_协奏曲“复活”_行动前.txt
# 16_ZT-7_协奏曲“复活”_行动后.txt
# 17_ZT-8_夜歌“未见的高塔”_行动前.txt
# 18_ZT-8_夜歌“未见的高塔”_行动后.txt
# 19_ZT-9_幻想曲“赠答”_行动前.txt
# 1_ZT-ST-1_前奏“意外归来”.txt
# 20_ZT-9_幻想曲“赠答”_行动后.txt
# 21_ZT-10_弥撒“君王”_行动前.txt
# 22_ZT-10_弥撒“君王”_行动后.txt
# 23_ZT-ST-3_尾奏“晚霞”.txt
# 2_ZT-1_清唱“晴空之歌”_行动前.txt
# 3_ZT-1_清唱“晴空之歌”_行动后.txt
# 4_ZT-2_序曲“哨兵”_行动前.txt
# 5_ZT-2_序曲“哨兵”_行动后.txt
# 6_ZT-3_练习曲“奇遇”_行动前.txt
# 7_ZT-3_练习曲“奇遇”_行动后.txt
# 8_ZT-4_狂想曲“望想”_行动前.txt
# 9_ZT-4_狂想曲“望想”_行动后.txt
# 10_BB-4_悠长的旅途_行动后.txt
# 11_BB-5_激变烽烟_行动前.txt
# 12_BB-5_激变烽烟_行动后.txt
# 13_BB-6_灯火闪烁不定_行动前.txt
# 14_BB-6_灯火闪烁不定_行动后.txt
# 15_BB-7_阴影显现_行动前.txt
# 16_BB-7_阴影显现_行动后.txt
# 17_BB-8_终局倒计时_行动前.txt
# 18_BB-8_终局倒计时_行动后.txt
# 19_BB-9_尘埃落定_行动前.txt
# 1_BB-ST-1_未完成的告别.txt
# 20_BB-9_尘埃落定_行动后.txt
# 21_BB-10_再见，再见_行动前.txt
# 22_BB-10_再见，再见_行动后.txt
# 23_BB-ST-3_灵魂尽头.txt
# 2_BB-1_宏伟愿景_行动前.txt
# 3_BB-1_宏伟愿景_行动后.txt
# 4_BB-2_命途何在_行动前.txt
# 5_BB-2_命途何在_行动后.txt
# 6_BB-3_无声破裂_行动前.txt
# 7_BB-3_无声破裂_行动后.txt
# 8_BB-ST-2_在疲惫中苏醒.txt
# 9_BB-4_悠长的旅途_行动前.txt
# 10_HS-5_纺绫罗_行动前.txt
# 11_HS-5_纺绫罗_行动后.txt
# 12_HS-ST-2_织锦缎.txt
# 13_HS-6_卷赤霞_行动前.txt
# 14_HS-7_梦四时_行动后.txt
# 15_HS-8_种因_行动前.txt
# 16_HS-8_种因_行动后.txt
# 17_HS-9_得果_行动前.txt
# 18_HS-9_得果_行动后.txt
# 19_HS-ST-3_彻风雨.txt
# 1_HS-ST-1_禾下梦.txt
# 2_HS-1_赴大荒_行动前.txt
# 3_HS-1_赴大荒_行动后.txt
# 4_HS-2_祭神农_行动前.txt
# 5_HS-2_祭神农_行动后.txt
# 6_HS-3_早芒种_行动前.txt
# 7_HS-3_早芒种_行动后.txt
# 8_HS-4_话桑麻_行动前.txt
# 9_HS-4_话桑麻_行动后.txt
# 10_SN-4_灯塔入口_行动后.txt
# 11_SN-5_灯塔控制室_行动前.txt
# 12_SN-5_灯塔控制室_行动后.txt
# 13_SN-6_中央通道_行动前.txt
# 14_SN-ST-6_下层大厅.txt
# 15_SN-ST-7_宴会厅.txt
# 16_SN-7_黄金回廊_行动后.txt
# 17_SN-ST-8_指挥大厅.txt
# 18_SN-ST-9_主舰桥.txt
# 19_SN-8_观测所_行动后.txt
# 1_SN-ST-1_古井.txt
# 20_SN-ST-10_甲板室.txt
# 21_SN-ST-11_主桅杆.txt
# 22_SN-10_礼仪广场_行动前.txt
# 23_SN-10_礼仪广场_行动后.txt
# 24_SN-ST-12_格兰法洛.txt
# 2_SN-1_中心广场_行动前.txt
# 3_SN-1_中心广场_行动后.txt
# 4_SN-ST-2_海滨小道.txt
# 5_SN-2_广场南路_行动后.txt
# 6_SN-ST-3_空旷的大街.txt
# 7_SN-3_安静的步道_行动后.txt
# 8_SN-ST-4_临海长街.txt
# 9_SN-ST-5_登陆点.txt
# 10_CR-5_消防通道_行动前.txt
# 11_CR-5_消防通道_行动后.txt
# 12_CR-6_反艺术运动_行动前.txt
# 13_CR-6_反艺术运动_行动后.txt
# 14_CR-ST-2_策展人会客厅.txt
# 15_CR-7_安全出口_行动前.txt
# 16_CR-7_安全出口_行动后.txt
# 17_CR-8_一跃而下_行动前.txt
# 18_CR-8_一跃而下_行动后.txt
# 19_CR-ST-3_艺术馆餐厅.txt
# 1_CR-ST-1_特别参观通道.txt
# 2_CR-1_城市主题展_行动前.txt
# 3_CR-1_城市主题展_行动后.txt
# 4_CR-2_不对称庭园_行动前.txt
# 5_CR-2_不对称庭园_行动后.txt
# 6_CR-3_假面舞池_行动前.txt
# 7_CR-3_假面舞池_行动后.txt
# 8_CR-4_非传统艺术空间_行动前.txt
# 9_CR-4_非传统艺术空间_行动后.txt
# 10_TW-5_冬灵挽歌_行动前.txt
# 11_TW-5_冬灵挽歌_行动后.txt
# 12_TW-6_怒意漫延_行动前.txt
# 13_TW-6_怒意漫延_行动后.txt
# 14_TW-7_群峦崩塌_行动前.txt
# 15_TW-7_群峦崩塌_行动后.txt
# 16_TW-8_月光沉沦_行动前.txt
# 17_TW-8_月光沉沦_行动后.txt
# 18_TW-ST-2_余烬之上.txt
# 19_TW-S-1_三座巨像_行动后.txt
# 1_TW-ST-1_老栎树下.txt
# 20_TW-S-2_一束哀悼_行动后.txt
# 2_TW-1_缄默不言_行动前.txt
# 3_TW-1_缄默不言_行动后.txt
# 4_TW-2_叛乱前哨_行动前.txt
# 5_TW-2_叛乱前哨_行动后.txt
# 6_TW-3_高塔烟火_行动前.txt
# 7_TW-3_高塔烟火_行动后.txt
# 8_TW-4_复仇之魂_行动前.txt
# 9_TW-4_复仇之魂_行动后.txt
# 10_OD-6_领主宅邸攻防战_行动前.txt
# 11_OD-6_领主宅邸攻防战_行动后.txt
# 12_OD-ST-2_一场葬礼.txt
# 13_OD-7_地堡防线_行动前.txt
# 14_OD-7_地堡防线_行动后.txt
# 15_OD-8_渗透作战_行动前.txt
# 16_OD-8_渗透作战_行动后.txt
# 17_OD-ST-3_行走于大地之上.txt
# 1_OD-ST-1_拉马克行动.txt
# 2_OD-1_外勤记录_行动前.txt
# 3_OD-1_外勤记录_行动后.txt
# 4_OD-2_扩大防守范围_行动前.txt
# 5_OD-2_扩大防守范围_行动后.txt
# 6_OD-3_安全屋攻防战_行动前.txt
# 7_OD-3_安全屋攻防战_行动后.txt
# 8_OD-5_物资回收计划_行动前.txt
# 9_OD-5_物资回收计划_行动后.txt
# 10_SL-5_我会唱一首彩虹_行动前.txt
# 11_SL-5_我会唱一首彩虹_行动后.txt
# 12_SL-ST-2_雨啊，雨啊，快离开.txt
# 13_SL-6_林中小木屋_行动前.txt
# 14_SL-6_林中小木屋_行动后.txt
# 15_SL-7_靠着我的肩膀哭泣_行动前.txt
# 16_SL-7_靠着我的肩膀哭泣_行动后.txt
# 17_SL-8_爱之歌_行动前.txt
# 18_SL-8_爱之歌_行动后.txt
# 19_SL-ST-3_晴天.txt
# 1_SL-ST-1_到站旁.txt
# 2_SL-1_你的耳朵长不长？_行动前.txt
# 3_SL-1_你的耳朵长不长？_行动后.txt
# 4_SL-2_小蓝孩_行动前.txt
# 5_SL-2_小蓝孩_行动后.txt
# 6_SL-3_手指之家_行动前.txt
# 7_SL-3_手指之家_行动后.txt
# 8_SL-4_一个水手出海了_行动前.txt
# 9_SL-4_一个水手出海了_行动后.txt
# 10_OF-4_他是将军_行动前.txt
# 11_OF-4_他是将军_行动后.txt
# 12_OF-ST3_压力之下.txt
# 13_OF-5_别阻止我_行动前.txt
# 14_OF-5_别阻止我_行动后.txt
# 15_OF-6_杀手女皇_行动前.txt
# 16_OF-6_杀手女皇_行动后.txt
# 17_OF-ST4_爱某个人.txt
# 18_OF-7_一锤定音_行动前.txt
# 19_OF-7_一锤定音_行动后.txt
# 1_演出开始.txt
# 20_OF-8_汐斯塔狂想曲_行动前.txt
# 21_OF-8_汐斯塔狂想曲_行动后.txt
# 22_OF-ST5_此生挚爱.txt
# 23_OF-ST6_邂逅潮声.txt
# 24_OF-EX1_预热活动_行动后.txt
# 25_OF-EX3_采访环节_行动后.txt
# 26_OF-EX6_完美落幕_行动后.txt
# 2_OF-ST1_摇滚起来.txt
# 3_OF-1_火山制造_行动前.txt
# 4_OF-1_火山制造_行动后.txt
# 5_OF-ST2_冲破藩篱.txt
# 6_OF-2_演出继续_行动前.txt
# 7_OF-2_演出继续_行动后.txt
# 8_OF-3_竞走赛_行动前.txt
# 9_OF-3_竞走赛_行动后.txt
# 10_FC-5_祝福的歌谣_行动前.txt
# 11_FC-5_祝福的歌谣_行动后.txt
# 12_FC-6_无人知晓_行动后.txt
# 13_FC-7_生灵火花_行动前.txt
# 14_FC-7_生灵火花_行动后.txt
# 15_FC-ST-2_自灰烬之中.txt
# 16_FC-8_她的影子_行动前.txt
# 17_FC-8_她的影子_行动后.txt
# 18_FC-ST-3_一声呜咽.txt
# 1_FC-ST-1_荒地钟声.txt
# 2_FC-1_逃离与追逐_行动前.txt
# 3_FC-1_逃离与追逐_行动后.txt
# 4_FC-2_不幸重逢_行动前.txt
# 5_FC-2_不幸重逢_行动后.txt
# 6_FC-3_引燃草垛_行动前.txt
# 7_FC-3_引燃草垛_行动后.txt
# 8_FC-4_热灼梦_行动前.txt
# 9_FC-4_热灼梦_行动后.txt
# 10_MN-5_斯沃玛视频_行动前.txt
# 11_MN-5_斯沃玛视频_行动后.txt
# 12_MN-6_蓝耳酒窖_行动前.txt
# 13_MN-6_蓝耳酒窖_行动后.txt
# 14_MN-7_梅什科集团_行动前.txt
# 15_MN-7_梅什科集团_行动后.txt
# 16_MN-ST-2_酒杯.txt
# 17_MN-8_商业联合_行动前.txt
# 18_MN-8_商业联合_行动后.txt
# 19_MN-ST-3_缄默启程.txt
# 1_MN-ST-1_亮相.txt
# 2_MN-1_艾伦精选_行动前.txt
# 3_MN-1_艾伦精选_行动后.txt
# 4_MN-2_呼啸守卫_行动前.txt
# 5_MN-2_呼啸守卫_行动后.txt
# 6_MN-3_玫瑰报业_行动前.txt
# 7_MN-3_玫瑰报业_行动后.txt
# 8_MN-4_辉煌盾工业_行动前.txt
# 9_MN-4_辉煌盾工业_行动后.txt
# 10_IC-5_加速冲线_行动前.txt
# 11_IC-5_加速冲线_行动后.txt
# 12_IC-6_战逃反应_行动前.txt
# 13_IC-6_战逃反应_行动后.txt
# 14_IC-7_生活之道_行动前.txt
# 15_IC-7_生活之道_行动后.txt
# 16_IC-8_金属气味_行动前.txt
# 17_IC-9_穹顶之上_行动后.txt
# 18_IC-ST-2_失乐园.txt
# 1_IC-ST-1_旅行前夕.txt
# 2_IC-1_沉浸式游览_行动前.txt
# 3_IC-1_沉浸式游览_行动后.txt
# 4_IC-2_下坠_行动前.txt
# 5_IC-2_下坠_行动后.txt
# 6_IC-3_奇谈怪论_行动前.txt
# 7_IC-3_奇谈怪论_行动后.txt
# 8_IC-4_“大水坑”_行动前.txt
# 9_IC-4_“大水坑”_行动后.txt
# 10_DM-7_龟裂_行动后.txt
# 11_DM-8_离散_行动前.txt
# 12_DM-8_离散_行动后.txt
# 13_DM-ST-1_求生.txt
# 1_DM-1_埋藏_行动前.txt
# 2_DM-1_埋藏_行动后.txt
# 3_DM-2_偶然_行动前.txt
# 4_DM-2_偶然_行动后.txt
# 5_DM-3_挤压_行动前.txt
# 6_DM-5_旗帜_行动后.txt
# 7_DM-6_远遁_行动前.txt
# 8_DM-6_远遁_行动后.txt
# 9_DM-7_龟裂_行动前.txt
# 10_BP-5_不治的命运_行动前.txt
# 11_BP-5_不治的命运_行动后.txt
# 12_BP-6_阿戈尔失格_行动前.txt
# 13_BP-6_阿戈尔失格_行动后.txt
# 14_BP-ST-2_如海流倒灌.txt
# 15_BP-7_从历史中来_行动前.txt
# 16_BP-7_从历史中来_行动后.txt
# 17_BP-8_“何谓存续？”_行动前.txt
# 18_BP-8_“何谓存续？”_行动后.txt
# 19_BP-ST-3_歧路者与同行者.txt
# 1_BP-ST-1_浪潮守望者.txt
# 2_BP-1_第一次接触_行动前.txt
# 3_BP-1_第一次接触_行动后.txt
# 4_BP-2_评议式迎接_行动前.txt
# 5_BP-2_评议式迎接_行动后.txt
# 6_BP-3_如海雪纷散_行动前.txt
# 7_BP-3_如海雪纷散_行动后.txt
# 8_BP-4_牺牲与代价_行动前.txt
# 9_BP-4_牺牲与代价_行动后.txt
# 10_WR-ST-2_一日之祸.txt
# 11_WR-6_画中_行动前.txt
# 12_WR-6_画中_行动后.txt
# 13_WR-8_大梦_行动前.txt
# 14_WR-8_大梦_行动后.txt
# 15_WR-10_夕_行动前.txt
# 16_WR-10_夕_行动后.txt
# 17_WR-ST-3_一问之答.txt
# 1_WR-ST-1_一钳之恩.txt
# 2_WR-1_初醒_行动前.txt
# 3_WR-1_初醒_行动后.txt
# 4_WR-2_墨魉_行动前.txt
# 5_WR-2_墨魉_行动后.txt
# 6_WR-4_掌柜_行动前.txt
# 7_WR-4_掌柜_行动后.txt
# 8_WR-5_拙山_行动前.txt
# 9_WR-5_拙山_行动后.txt
# 10_WB-ST-2_信我所信.txt
# 11_WB-5_风雨欲来_行动前.txt
# 12_WB-6_瑟瑟秋华_行动后.txt
# 13_WB-7_“屏风卫”_行动前.txt
# 14_WB-7_“屏风卫”_行动后.txt
# 15_WB-8_旷古之晤_行动前.txt
# 16_WB-8_旷古之晤_行动后.txt
# 17_WB-9_“冬藏”_行动前.txt
# 18_WB-9_“冬藏”_行动后.txt
# 19_WB-ST-3_粘劫收后.txt
# 1_WB-ST-1_忽梦少年事.txt
# 2_WB-1_塞上春来_行动前.txt
# 3_WB-1_塞上春来_行动后.txt
# 4_WB-2_沙海黄尘_行动前.txt
# 5_WB-2_沙海黄尘_行动后.txt
# 6_WB-3_树犹如此_行动前.txt
# 7_WB-3_树犹如此_行动后.txt
# 8_WB-4_不念往昔_行动前.txt
# 9_WB-4_不念往昔_行动后.txt
# 10_HE-5_主在圣殿中_行动前.txt
# 11_HE-5_主在圣殿中_行动后.txt
# 12_HE-6_夜半歌声_行动前.txt
# 13_HE-6_夜半歌声_行动后.txt
# 14_HE-ST-2_在花园里.txt
# 15_HE-7_以爱相连_行动前.txt
# 16_HE-7_以爱相连_行动后.txt
# 17_HE-8_愿跟随主_行动前.txt
# 18_HE-8_愿跟随主_行动后.txt
# 19_HE-ST-3_慈光引导.txt
# 1_HE-ST-1_奉上冠冕.txt
# 2_HE-1_我有一个荣美家乡_行动前.txt
# 3_HE-1_我有一个荣美家乡_行动后.txt
# 4_HE-2_生命运河_行动前.txt
# 5_HE-2_生命运河_行动后.txt
# 6_HE-3_岂可空手回天府？_行动前.txt
# 7_HE-3_岂可空手回天府？_行动后.txt
# 8_HE-4_我曾舍命为你_行动前.txt
# 9_HE-4_我曾舍命为你_行动后.txt
# 10_DV-5_多萝西的承诺_行动前.txt
# 11_DV-S-1_困心.txt
# 12_DV-5_多萝西的承诺_行动后.txt
# 13_DV-6_挣脱美梦_行动前.txt
# 14_DV-6_挣脱美梦_行动后.txt
# 15_DV-7_疯狂的信号_行动前.txt
# 16_DV-S-2_衡虑.txt
# 17_DV-7_疯狂的信号_行动后.txt
# 18_DV-8_连接内心_行动前.txt
# 19_DV-8_连接内心_行动后.txt
# 1_DV-ST-1_逆行.txt
# 20_DV-ST-2_启程.txt
# 2_DV-1_特里蒙街道_行动前.txt
# 3_DV-1_特里蒙街道_行动后.txt
# 4_DV-2_拓荒者小屋_行动前.txt
# 5_DV-2_拓荒者小屋_行动后.txt
# 6_DV-3_动力装甲_行动前.txt
# 7_DV-3_动力装甲_行动后.txt
# 8_DV-4_无人的小巷_行动前.txt
# 9_DV-4_无人的小巷_行动后.txt
# 10_CF-5_野蛮肇事者_行动后.txt
# 11_CF-6_禁飞区_行动前.txt
# 12_CF-6_禁飞区_行动后.txt
# 13_CF-7_锥心之刺_行动前.txt
# 14_CF-7_锥心之刺_行动后.txt
# 15_CF-8_奸诈者必自食恶果_行动前.txt
# 16_CF-8_奸诈者必自食恶果_行动后.txt
# 17_CF-9_决战！燃烧的狩魂！_行动前.txt
# 18_CF-9_决战！燃烧的狩魂！_行动后.txt
# 19_CF-ST-3_晨曦.txt
# 1_CF-ST-1_噩梦.txt
# 2_CF-TR-1_来袭！天空王者！_行动前.txt
# 3_CF-TR-1_来袭！天空王者！_行动后.txt
# 4_CF-2_坚硬磐石_行动前.txt
# 5_CF-2_坚硬磐石_行动后.txt
# 6_CF-3_迎头痛击_行动前.txt
# 7_CF-4_破空的飞羽_行动后.txt
# 8_CF-ST-2_林昏焰明.txt
# 9_CF-5_野蛮肇事者_行动前.txt
# 10_SV-6_厌食_行动后.txt
# 11_SV-7_守护者_行动前.txt
# 12_SV-7_守护者_行动后.txt
# 13_SV-ST-1_唤醒噩梦.txt
# 14_SV-8_亲族_行动前.txt
# 15_SV-8_亲族_行动后.txt
# 16_SV-9_笃信者_行动前.txt
# 17_SV-9_笃信者_行动后.txt
# 18_SV-ST-2_侥幸离去.txt
# 1_SV-1_闯入者_行动前.txt
# 2_SV-1_闯入者_行动后.txt
# 3_SV-2_歌手_行动前.txt
# 4_SV-2_歌手_行动后.txt
# 5_SV-3_外来者_行动前.txt
# 6_SV-3_外来者_行动后.txt
# 7_SV-4_海洋_行动前.txt
# 8_SV-5_遭弃者_行动后.txt
# 9_SV-6_厌食_行动前.txt
# 10_WD-7_家园_行动前.txt
# 11_WD-7_家园_行动后.txt
# 12_WD-8_大雪将至_行动前.txt
# 13_WD-8_大雪将至_行动后.txt
# 14_WD-ST-2_异乡来客.txt
# 1_WD-1_赤角小镇之围_行动前.txt
# 2_WD-1_赤角小镇之围_行动后.txt
# 3_WD-2_绿洲惊雷_行动前.txt
# 4_WD-2_绿洲惊雷_行动后.txt
# 5_WD-3_仙人掌沙丘_行动前.txt
# 6_WD-3_仙人掌沙丘_行动后.txt
# 7_WD-ST-1_松心百合.txt
# 8_WD-5_沁礁之地_行动前.txt
# 9_WD-5_沁礁之地_行动后.txt
# 10_RS-ST-2_登山铁道.txt
# 11_RS-5_逃票？_行动前.txt
# 12_RS-5_逃票？_行动后.txt
# 13_RS-6_补票！_行动前.txt
# 14_RS-6_补票！_行动后.txt
# 15_RS-7_制动失灵_行动前.txt
# 16_RS-7_制动失灵_行动后.txt
# 17_RS-8_极限时速_行动前.txt
# 18_RS-8_极限时速_行动后.txt
# 19_RS-ST-3_终点站.txt
# 1_RS-ST-1_候车大厅.txt
# 2_RS-1_注意事项_行动前.txt
# 3_RS-1_注意事项_行动后.txt
# 4_RS-2_同车异图_行动前.txt
# 5_RS-2_同车异图_行动后.txt
# 6_RS-3_临时停车_行动前.txt
# 7_RS-3_临时停车_行动后.txt
# 8_RS-4_重回正轨_行动前.txt
# 9_RS-4_重回正轨_行动后.txt
# 10_NL-ST-2_权与力.txt
# 11_NL-5_人言可畏_行动前.txt
# 12_NL-5_人言可畏_行动后.txt
# 13_NL-6_被包围者_行动前.txt
# 14_NL-6_被包围者_行动后.txt
# 15_NL-ST-3_酣眠的城市.txt
# 16_NL-7_梦的余韵_行动前.txt
# 17_NL-7_梦的余韵_行动后.txt
# 18_NL-8_最后的怯薛_行动前.txt
# 19_NL-8_最后的怯薛_行动后.txt
# 1_NL-ST-1_欣欣向荣.txt
# 20_NL-9_叹息_行动前.txt
# 21_NL-9_叹息_行动后.txt
# 22_NL-10_耀骑士_行动前.txt
# 23_NL-10_耀骑士_行动后.txt
# 24_NL-ST-4_未知与未来.txt
# 2_NL-1_金盏花_行动前.txt
# 3_NL-1_金盏花_行动后.txt
# 4_NL-2_垂死的刺_行动前.txt
# 5_NL-2_垂死的刺_行动后.txt
# 6_NL-3_筹备着_行动前.txt
# 7_NL-3_筹备着_行动后.txt
# 8_NL-4_诗的容貌_行动前.txt
# 9_NL-4_诗的容貌_行动后.txt
# 10_BI-4_立雪求道_行动后.txt
# 11_BI-5_猎场_行动前.txt
# 12_BI-5_猎场_行动后.txt
# 13_BI-ST-3_一着不慎.txt
# 14_BI-6_歧路_行动前.txt
# 15_BI-6_歧路_行动后.txt
# 16_BI-7_破冰_行动前.txt
# 17_BI-7_破冰_行动后.txt
# 18_BI-8_将军_行动前.txt
# 19_BI-8_将军_行动后.txt
# 1_BI-1_不欢而聚_行动前.txt
# 20_BI-ST-4_封盘.txt
# 2_BI-1_不欢而聚_行动后.txt
# 3_BI-ST-1_入乡随俗.txt
# 4_BI-2_息事宁人_行动前.txt
# 5_BI-2_息事宁人_行动后.txt
# 6_BI-3_人心难测_行动前.txt
# 7_BI-3_人心难测_行动后.txt
# 8_BI-ST-2_山雪欲来.txt
# 9_BI-4_立雪求道_行动前.txt
# 10_GT-5_各抒己见_行动后.txt
# 11_GT-6_黄金三角_行动前.txt
# 12_GT-6_黄金三角_行动后.txt
# 13_GT-EX-1_大地惊雷_行动后.txt
# 14_GT-EX-3_与狼共舞_行动后.txt
# 15_GT-HX-1_碧血金沙_行动后.txt
# 16_GT-HX-3_西部往事_行动后.txt
# 1_GT-1_日正当中_行动前.txt
# 2_GT-1_日正当中_行动后.txt
# 3_GT-2_察言观色_行动前.txt
# 4_GT-2_察言观色_行动后.txt
# 5_GT-3_意外之旅_行动前.txt
# 6_GT-3_意外之旅_行动后.txt
# 7_GT-4_污点证人_行动前.txt
# 8_GT-4_污点证人_行动后.txt
# 9_GT-5_各抒己见_行动前.txt
# 1_新星主播.txt
# 2_再也没有什么能阻止她了.txt
# 3_警惕新型金融诈骗.txt
# 4_她不禁开始思索是谁动了自己的瘤奶.txt
# 5_一生四，四生三，三生万物.txt
# 6_断罪者最喜欢的一集.txt
# 7_敬请收看：爱、主播&单推人.txt
# 8_“就那样吧”.txt
# 1_隐藏剧情.txt
# 2_采购中心.txt
# 3_EP09_前情提要.txt
# 4_EP10_序曲.txt
# 5_EP11_序曲.txt
# 6_EP12_序曲.txt
# 7_艺术之神.txt
# 8_多维合作.txt
# 9_保全派驻.txt
# 1_危机合约.txt
# 2_荒芜行动_P1.txt
# 3_荒芜行动_P2.txt
# 1_金牌讲师.txt
# 2_IM-1_行动后.txt
# 1_嘻哈之王.txt
# 2_LTTB_Extraordinary_rap_battle!_行动后.txt
# 1_狂弹要塞.txt
# 2_BF-3_没想到还有一关_行动后.txt
# 1_固定开头AVG.txt
# 2_开头AVG.txt
# 3_结尾AVG.txt
# 1_逃离.txt
# 2_选择.txt
# 3_路漫漫.txt
# 1_沙中之火.txt
# 2_结局1.txt
# 3_结局2.txt
# 4_结局3.txt
# 1_初来乍到.txt
# 2_见证往昔.txt
# 3_寻宝与援兵.txt
# 4_阿尔萨兰的秘密.txt
# 5_和平的回归.txt
# 1_序章.txt
# 2_舞会终场.txt
# 3_滑稽喜剧.txt
# 4_盛大揭幕.txt
# 5_沉默之章.txt
# 1_行动开始.txt
# 2_迷尘幻梦.txt
# 3_茫然行者.txt
# 4_归于荒野.txt
# 1_序章.txt
# 2_越过群山.txt
# 3_直至冬夜降临.txt
# 4_自深处的一瞥.txt
# 5_终始.txt
# 1_序章.txt
# 2_平凡即是喜乐.txt
# 3_静谧时代.txt
# 4_息潮的代价.txt
# 5_如星空般深蓝.txt
# 1_序章.txt
# 2_憧憬未来.txt
# 3_双王记.txt
# 4_天使之城.txt

# %%
# Walk through the directory tree
import os
for dirpath, dirnames, filenames in os.walk("./plot/"):
  for file in filenames:
    print(file)
    if file[-4:] == "json" or file[-8:] == "plot.txt":
      file_path = os.path.join(dirpath, file)
      try:
        os.remove(file_path)  # Delete the file
        print(f"Deleted: {file_path}")
      except Exception as e:
        print(f"Error deleting {file_path}: {e}")
# Out:
# 10_3-5_呼叫_行动后.txt
# 11_3-6_决定_行动前.txt
# 12_3-6_决定_行动后.txt
# 13_3-7_轰鸣_行动前.txt
# 14_3-7_轰鸣_行动后.txt
# 15_3-8_黄昏_行动前.txt
# 16_3-8_黄昏_行动后.txt
# 1_3-1_会合_行动前.txt
# 2_3-1_会合_行动后.txt
# 3_3-2_记忆_行动前.txt
# 4_3-2_记忆_行动后.txt
# 5_3-3_回旋_行动前.txt
# 6_3-3_回旋_行动后.txt
# 7_3-4_龟裂_行动前.txt
# 8_3-4_龟裂_行动后.txt
# 9_3-5_呼叫_行动前.txt
# 10_6-5_解决谁？_行动后.txt
# 11_6-6_别说过去的事.txt
# 12_6-7_断弦_行动前.txt
# 13_6-7_断弦_行动后.txt
# 14_6-8_只是从天而降！_行动前.txt
# 15_6-8_只是从天而降！_行动后.txt
# 16_6-9_换一个角度_行动前.txt
# 17_6-10_解开铃铛_行动后.txt
# 18_6-11_“这种事”_行动前.txt
# 19_6-11_“这种事”_行动后.txt
# 1_6-1_僵局_行动前.txt
# 20_6-12_冰原之雪_行动前.txt
# 21_6-13_没有火,没有光.txt
# 22_6-14_冰原之霜_行动后.txt
# 23_6-15_不错的回忆_行动前.txt
# 24_6-15_不错的回忆_行动后.txt
# 25_6-16_黑兔子,白兔子_行动前.txt
# 26_6-17_冬逝_行动后.txt
# 27_6-18_只有你知道.txt
# 2_6-1_僵局_行动后.txt
# 3_6-2_一些误会_行动前.txt
# 4_6-2_一些误会_行动后.txt
# 5_6-3_同时走失_行动前.txt
# 6_6-3_同时走失_行动后.txt
# 7_6-4_溃烂的疮疤_行动前.txt
# 8_6-4_溃烂的疮疤_行动后.txt
# 9_6-5_解决谁？_行动前.txt
# 10_2-5_高空坠物_行动后.txt
# 11_2-6_握紧扶手_行动前.txt
# 12_2-6_握紧扶手_行动后.txt
# 13_2-7_注意卫生_行动前.txt
# 14_2-7_注意卫生_行动后.txt
# 15_2-8_不做约定_行动前.txt
# 16_2-8_不做约定_行动后.txt
# 17_2-9_操作暗箱_行动前.txt
# 18_2-9_操作暗箱_行动后.txt
# 19_2-10_病入膏肓_行动前.txt
# 1_TR-11_战术阻滞_行动前.txt
# 20_2-10_病入膏肓_行动后.txt
# 2_2-1_龙门之行_行动后.txt
# 3_2-2_兵不接刃_行动前.txt
# 4_2-2_兵不接刃_行动后.txt
# 5_2-3_无罪推定_行动前.txt
# 6_2-3_无罪推定_行动后.txt
# 7_2-4_企鹅物流_行动前.txt
# 8_2-4_企鹅物流_行动后.txt
# 9_2-5_高空坠物_行动前.txt
# 10_R8-5_寒冷，来自知觉_行动前.txt
# 11_R8-5_寒冷，来自知觉_行动后.txt
# 12_M8-4_意志，片缕幻影.txt
# 13_R8-6_战场，蔓延不止_行动前.txt
# 14_R8-6_战场，蔓延不止_行动后.txt
# 15_M8-5_厄运，等候已久.txt
# 16_R8-8_人心，向背无常_行动前.txt
# 17_R8-8_人心，向背无常_行动后.txt
# 18_M8-6_再见，只为再见_行动前.txt
# 19_M8-6_再见，只为再见_行动后.txt
# 1_R8-1_昨日，谷壳将裂_行动前.txt
# 20_R8-9_相逢，总是离别_行动前.txt
# 21_R8-9_相逢，总是离别_行动后.txt
# 22_M8-7_恶言，报应不爽_行动前.txt
# 23_M8-7_恶言，报应不爽_行动后.txt
# 24_R8-11_落雪，浸黑国土_行动前.txt
# 25_R8-11_落雪，浸黑国土_行动后.txt
# 26_M8-8_苏醒，浮出梦乡_行动前.txt
# 27_M8-8_苏醒，浮出梦乡_行动后.txt
# 28_JT8-1_恨火，流向原野_行动前.txt
# 29_JT8-1_恨火，流向原野_行动后.txt
# 2_R8-1_昨日，谷壳将裂_行动后.txt
# 30_JT8-2_睁眼，便是日暮_行动前.txt
# 31_JT8-2_睁眼，便是日暮_行动后.txt
# 32_JT8-3_昂首，足践烈焰_行动前.txt
# 33_JT8-3_昂首，足践烈焰_行动后.txt
# 34_END8-1_尾声，抑或开始.txt
# 35_EG-1_燃烧的片段1.txt
# 36_EG-2_燃烧的片段2.txt
# 37_EG-3_燃烧的片段3.txt
# 38_EG-4_燃烧的片段4.txt
# 39_EG-5_燃烧的片段5.txt
# 3_M8-1_今日，血色满溢.txt
# 4_R8-3_麦秆，极易燃烧_行动前.txt
# 5_R8-3_麦秆，极易燃烧_行动后.txt
# 6_M8-2_失语，产自多言.txt
# 7_R8-4_火种，一触即灭_行动前.txt
# 8_R8-4_火种，一触即灭_行动后.txt
# 9_M8-3_死亡，召之即来.txt
# 10_4-5_官僚主义_行动后.txt
# 11_4-6_少见多怪_行动前.txt
# 12_4-6_少见多怪_行动后.txt
# 13_4-7_各取所需_行动前.txt
# 14_4-7_各取所需_行动后.txt
# 15_4-8_应激反应_行动前.txt
# 16_4-8_应激反应_行动后.txt
# 17_4-9_彻入骨髓_行动前.txt
# 18_4-9_彻入骨髓_行动后.txt
# 19_4-10_灯火将熄_行动前.txt
# 1_4-1_免费拥抱_行动前.txt
# 20_4-10_灯火将熄_行动后.txt
# 2_4-1_免费拥抱_行动后.txt
# 3_4-2_雨中漫步_行动前.txt
# 4_4-2_雨中漫步_行动后.txt
# 5_4-3_人工制冷_行动前.txt
# 6_4-3_人工制冷_行动后.txt
# 7_4-4_不要恐慌_行动前.txt
# 8_4-4_不要恐慌_行动后.txt
# 9_4-5_官僚主义_行动前.txt
# 10_13-6_典范之名_行动前.txt
# 11_13-6_典范之名_行动后.txt
# 12_TR-24_寻迹而行_行动前.txt
# 13_13-8_不虞之会_行动后.txt
# 14_13-9_窥冠冕者.txt
# 15_13-10_幻境迁流_行动后.txt
# 16_13-11_小镇翳云_行动前.txt
# 17_13-12_破碎温室_行动前.txt
# 18_13-14_猩红烟火_行动后.txt
# 19_13-15_短暂齐聚_行动后.txt
# 1_13-1_战场内外.txt
# 20_13-16_“我们”_行动前.txt
# 21_13-16_“我们”_行动后.txt
# 22_13-17_谁来倾诉_行动前.txt
# 23_13-18_挺起胸膛_行动后.txt
# 24_13-20_血潮翻涌_行动后.txt
# 25_13-21_殷红君主_行动前.txt
# 26_13-21_殷红君主_行动后.txt
# 27_13-22_灾厄积渐.txt
# 2_13-2_眼前的伤_行动前.txt
# 3_13-2_眼前的伤_行动后.txt
# 4_13-3_不得暂歇_行动前.txt
# 5_13-3_不得暂歇_行动后.txt
# 6_13-4_佣兵一日_行动前.txt
# 7_13-4_佣兵一日_行动后.txt
# 8_13-5_苦厄盘桓_行动前.txt
# 9_13-5_苦厄盘桓_行动后.txt
# 10_12-7_平议生死_行动前.txt
# 11_12-8_火线重逢_行动后.txt
# 12_12-9_热血年华_行动前.txt
# 13_12-10_广播热线正繁忙_行动后.txt
# 14_12-11_时不我待.txt
# 15_12-12_脱帽致敬_行动前.txt
# 16_12-13_逆光阴影_行动后.txt
# 17_12-14_捂住耳朵_行动前.txt
# 18_12-14_捂住耳朵_行动后.txt
# 19_12-15_千疮百孔_行动前.txt
# 1_12-1_火光热浪.txt
# 20_12-15_千疮百孔_行动后.txt
# 21_12-16_天边的火烧云_行动前.txt
# 22_12-17_被弃之人_行动后.txt
# 23_12-18_晚安_行动前.txt
# 24_12-19_飞跃，烟火_行动后.txt
# 25_12-20_诚挚邀请_行动前.txt
# 26_12-20_诚挚邀请_行动后.txt
# 27_12-21_战场静悄悄.txt
# 2_12-2_静候驾临_行动前.txt
# 3_12-2_静候驾临_行动后.txt
# 4_12-3_善意背叛_行动前.txt
# 5_12-3_善意背叛_行动后.txt
# 6_12-4_团结就是奢望_行动前.txt
# 7_12-4_团结就是奢望_行动后.txt
# 8_12-5_脆钢_行动前.txt
# 9_12-6_谁的战争_行动后.txt
# 10_14-6_确认交战视界_行动前.txt
# 11_14-6_确认交战视界_行动后.txt
# 12_14-7_执行反制作战_行动前.txt
# 13_14-7_执行反制作战_行动后.txt
# 14_14-8_抵近支援作战_行动前.txt
# 15_14-8_抵近支援作战_行动后.txt
# 16_14-9_应对饱和打击_行动前.txt
# 17_14-9_应对饱和打击_行动后.txt
# 18_14-10_自光辉中奔涌_行动前.txt
# 19_14-10_自光辉中奔涌_行动后.txt
# 1_14-1_从回忆中坠落.txt
# 20_14-11_所谓“英雄”_行动前.txt
# 21_14-11_所谓“英雄”_行动后.txt
# 22_14-12_使徒_行动前.txt
# 23_14-12_使徒_行动后.txt
# 24_14-13_自原点中降临.txt
# 25_14-14_高空拒阻行动_行动前.txt
# 26_14-15_突破外围防线_行动后.txt
# 27_14-16_抢占舷侧区域_行动前.txt
# 28_14-16_抢占舷侧区域_行动后.txt
# 29_14-17_核心舱攻防战_行动前.txt
# 2_14-2_作战对策会议_行动前.txt
# 30_14-18_在炽燃间咆哮_行动前.txt
# 31_14-18_在炽燃间咆哮_行动后.txt
# 32_14-19_晶簇之内_行动前.txt
# 33_14-19_晶簇之内_行动后.txt
# 34_14-20_列王行迹_行动前.txt
# 35_14-20_列王行迹_行动后.txt
# 36_14-21_万千愿景_行动前.txt
# 37_14-21_万千愿景_行动后.txt
# 38_14-22_在哀愁绽放的时刻_行动前.txt
# 39_14-22_在哀愁绽放的时刻_行动后.txt
# 3_14-2_作战对策会议_行动后.txt
# 40_14-23_良夜将死.txt
# 41_EG-6_慈悲遗愿.txt
# 4_14-3_破解锤砧战术_行动前.txt
# 5_14-3_破解锤砧战术_行动后.txt
# 6_14-4_通讯静默解除_行动前.txt
# 7_14-4_通讯静默解除_行动后.txt
# 8_14-5_探查岩洞区域_行动前.txt
# 9_14-5_探查岩洞区域_行动后.txt
# 1_14-1_从回忆中坠落plot-checkpoint.txt
# 10_11-6_演绎文明_行动前.txt
# 11_11-7_卷入洪流_行动后.txt
# 12_11-8_停滞_行动前.txt
# 13_11-8_停滞_行动后.txt
# 14_11-9_以命换命_行动前.txt
# 15_11-9_以命换命_行动后.txt
# 16_11-10_异路相对.txt
# 17_11-11_立场不同_行动前.txt
# 18_11-12_汹涌而来_行动后.txt
# 19_11-14_一场相见_行动前.txt
# 1_11-1_维护荣耀_行动前.txt
# 20_11-14_一场相见_行动后.txt
# 21_11-15_土地震颤_行动前.txt
# 22_11-16_荣光猎场_行动后.txt
# 23_11-17_回答我_行动前.txt
# 24_11-17_回答我_行动后.txt
# 25_11-19_直指命运_行动前.txt
# 26_11-19_直指命运_行动后.txt
# 27_11-21_不可避免.txt
# 2_11-1_维护荣耀_行动后.txt
# 3_11-2_一丝光亮_行动前.txt
# 4_11-2_一丝光亮_行动后.txt
# 5_11-3_蒸汽升腾_行动前.txt
# 6_11-3_蒸汽升腾_行动后.txt
# 7_11-4_何谓理想.txt
# 8_11-5_等价交换_行动前.txt
# 9_11-5_等价交换_行动后.txt
# 10_10-6_虽非同族_行动前.txt
# 11_10-6_虽非同族_行动后.txt
# 12_10-7_痛觉相连_行动前.txt
# 13_10-8_无暇哀悼_行动后.txt
# 14_10-9_他乡故知_行动前.txt
# 15_10-9_他乡故知_行动后.txt
# 16_10-10_旧日之影_行动前.txt
# 17_10-10_旧日之影_行动后.txt
# 18_10-11_千疮百孔_行动前.txt
# 19_10-12_仇怨的尽头_行动后.txt
# 1_10-1_被追逐者.txt
# 20_10-13_交叉路口.txt
# 21_10-14_瞄准_行动前.txt
# 22_10-14_瞄准_行动后.txt
# 23_10-15_逃离炮火_行动前.txt
# 24_10-16_血刃高悬_行动后.txt
# 25_10-17_坚城高墙_行动前.txt
# 26_10-17_坚城高墙_行动后.txt
# 27_10-18_理想的倒影.txt
# 28_10-19_远方星火.txt
# 2_10-2_抢夺目标_行动前.txt
# 3_10-2_抢夺目标_行动后.txt
# 4_10-3_低下头_行动前.txt
# 5_10-3_低下头_行动后.txt
# 6_10-4_鸣铳示警_行动前.txt
# 7_10-4_鸣铳示警_行动后.txt
# 8_10-5_城市的呼吸_行动前.txt
# 9_10-5_城市的呼吸_行动后.txt
# 10_7-7_26：37：14.txt
# 11_7-8_沉默者之怒-1_行动前.txt
# 12_7-9_沉默者之怒-2_行动后.txt
# 13_7-10_暗淡者之火_行动前.txt
# 14_7-10_暗淡者之火_行动后.txt
# 15_7-13_感染者之盾-1_行动前.txt
# 16_7-17_感染者之盾-2_行动后.txt
# 17_7-18_爱国者之死_行动前.txt
# 18_7-18_爱国者之死_行动后.txt
# 19_7-19_11：15：38.txt
# 1_7-1_32：00：00.txt
# 20_7-20_？？：？？：？？.txt
# 2_7-2_别离之夜_行动前.txt
# 3_7-2_别离之夜_行动后.txt
# 4_7-3_变节之刃_行动前.txt
# 5_7-3_变节之刃_行动后.txt
# 6_7-4_并肩之约-1_行动前.txt
# 7_7-5_并肩之约-2_行动后.txt
# 8_7-6_遗忘之地_行动前.txt
# 9_7-6_遗忘之地_行动后.txt
# 10_5-6_疑兵之计_行动后.txt
# 11_5-7_生死与共_行动前.txt
# 12_5-7_生死与共_行动后.txt
# 13_5-9_孽生恶物_行动前.txt
# 14_5-9_孽生恶物_行动后.txt
# 15_5-10_长夜终尽_行动前.txt
# 16_5-10_长夜终尽_行动后.txt
# 17_5-11_棋胜后着.txt
# 1_5-1_冤家易结_行动前.txt
# 2_5-1_冤家易结_行动后.txt
# 3_5-2_有口难言_行动前.txt
# 4_5-2_有口难言_行动后.txt
# 5_5-3_义胆凡躯_行动前.txt
# 6_5-3_义胆凡躯_行动后.txt
# 7_5-4_没人在家_行动前.txt
# 8_5-4_没人在家_行动后.txt
# 9_5-6_疑兵之计_行动前.txt
# 10_9-8_灰烬中的诗.txt
# 11_9-9_无辜者_行动前.txt
# 12_9-10_雷声轰鸣_行动后.txt
# 13_9-12_鬼影如潮_行动前.txt
# 14_9-13_战地救援_行动后.txt
# 15_9-14_风中旗帜_行动前.txt
# 16_9-18_“破晓”_行动后.txt
# 17_9-19_长夜枪火_行动前.txt
# 18_9-19_长夜枪火_行动后.txt
# 19_9-20_临近的暴风.txt
# 1_9-1_风暴突击.txt
# 20_9-21_重燃.txt
# 2_9-2_鬼魂危机_行动前.txt
# 3_9-3_牌局_行动后.txt
# 4_9-4_暗火四起_行动前.txt
# 5_9-4_暗火四起_行动后.txt
# 6_9-5_临界值_行动前.txt
# 7_9-5_临界值_行动后.txt
# 8_9-6_深池_行动前.txt
# 9_9-7_捉迷藏_行动后.txt
# 10_0-7_感染_行动后.txt
# 11_0-8_狩猎_行动前.txt
# 12_0-9_临光_行动后.txt
# 13_0-10_困境_行动前.txt
# 14_0-11_突围_行动后.txt
# 1_序章·上.txt
# 2_序章·下.txt
# 3_0-1_坍塌_行动前.txt
# 4_0-1_坍塌_行动后.txt
# 5_0-2_守卫_行动前.txt
# 6_0-2_守卫_行动后.txt
# 7_0-4_混战_行动前.txt
# 8_0-6_强击_行动后.txt
# 9_0-7_感染_行动前.txt
# 10_1-10_残留_行动后.txt
# 11_1-12_代价_行动前.txt
# 12_1-12_代价_行动后.txt
# 1_1-1_孤岛_行动前.txt
# 2_1-1_孤岛_行动后.txt
# 3_1-3_狂奔_行动前.txt
# 4_1-3_狂奔_行动后.txt
# 5_1-4_先兆_行动前.txt
# 6_1-6_灾难_行动前.txt
# 7_1-7_暴君_行动前.txt
# 8_1-7_暴君_行动后.txt
# 9_1-8_意志_行动前.txt
# Ace.txt
# Alty.txt
# Aya.txt
# D.D.D..txt
# Dan.txt
# Dijkstra.txt
# Frost.txt
# Guard.txt
# Logos.txt
# Mantra.txt
# Mechanist.txt
# Medic.txt
# Misery.txt
# Outcast.txt
# Pith.txt
# PRTS.txt
# Scout.txt
# Sharp.txt
# Stormeye.txt
# Touch.txt
# 万尼亚大公.txt
# 三角铁.txt
# 乌尔苏拉.txt
# 乔万娜·罗塞蒂.txt
# 九.txt
# 伊万杰利斯塔十一世.txt
# 伊内丝.txt
# 伊斯.txt
# 伊斯拉姆·维特.txt
# 伊比利亚主教.txt
# 伍德洛.txt
# 休露丝.txt
# 何塞.txt
# 依娜姆.txt
# 依拉.txt
# 光头马丁.txt
# 克丽斯腾·莱特.txt
# 克洛宁.txt
# 克洛维希娅.txt
# 克罗绮·砖石.txt
# 克里夫.txt
# 克雷格.txt
# 凋零骑士.txt
# 切斯特.txt
# 别格勒.txt
# 加勒斯.txt
# 加尔森.txt
# 加西亚.txt
# 博士.txt
# 卡奇·叙光.txt
# 卡彭.txt
# 古罗.txt
# 可萝尔.txt
# 可露希尔.txt
# 叶克多.txt
# 图拉.txt
# 圣徒卡门.txt
# 坎诺特.txt
# 坎黛拉.txt
# 塑料骑士.txt
# 塔佳娜.txt
# 塔季娅娜.txt
# 塔露拉.txt
# 塞弗林.txt
# 塞茜莉亚.txt
# 大嘴莫布.txt
# 大审判官.txt
# 大帝.txt
# 大祭司.txt
# 大长老.txt
# 大鲍勃.txt
# 太傅.txt
# 太合.txt
# 奥伦.txt
# 宁小姐.txt
# 安东尼奥.txt
# 安多恩.txt
# 安妮塔.txt
# 安托.txt
# 尤利娅·许勒尔.txt
# 尤卡坦.txt
# 左手骑士.txt
# 巴顿.txt
# 布兰特·赖纳.txt
# 希尔.txt
# 帕蒂亚.txt
# 弃械.txt
# 弑君者.txt
# 弗莱蒙特.txt
# 弗里达·希曼.txt
# 德米特里·切塔尔多.txt
# 德鲁奇.txt
# 恰尔内.txt
# 战士比尔.txt
# 托兰.txt
# 托尔.txt
# 扬·许勒尔.txt
# 拉赫曼.txt
# 挑山人.txt
# 文月.txt
# 文森特伯爵.txt
# 斐尔迪南·克鲁尼.txt
# 斯特凡诺·托雷格罗萨.txt
# 昆图斯.txt
# 普瑞赛斯.txt
# 曼弗雷德.txt
# 朵拉.txt
# 杜克.txt
# 杜小姐.txt
# 杜玛.txt
# 杰斯顿.txt
# 格哈德·霍夫曼.txt
# 格特鲁德.txt
# 格罗瓦兹尔.txt
# 桑尼.txt
# 梁洵.txt
# 梅菲斯特.txt
# 欧厄尔.txt
# 毕德曼.txt
# 汉密尔顿.txt
# 沃尔纳·冯·霍赫贝格.txt
# 洛里斯·博尔丁.txt
# 浮士德.txt
# 海伦.txt
# 潘乔.txt
# 爱国者.txt
# 爱德华.txt
# 爷爷.txt
# 特蕾西娅.txt
# 特雷西斯.txt
# 玛丽.txt
# 珂拉·洛文斯坦.txt
# 瓦莱丝.txt
# 甘比诺.txt
# 白垩.txt
# 皮加尔.txt
# 碎骨.txt
# 碧银.txt
# 科西切.txt
# 管家.txt
# 米亚罗.txt
# 米莎.txt
# 缪尔赛思.txt
# 罗伊.txt
# 罗素.txt
# 老伊辛.txt
# 老何塞.txt
# 老工匠.txt
# 老船夫.txt
# 老骑士.txt
# 耶奇·地心.txt
# 腐败骑士.txt
# 芭芭拉.txt
# 莉莉娅.txt
# 莫妮克.txt
# 莫希.txt
# 莱姆.txt
# 菈塔托丝.txt
# 董阿伯.txt
# 蒂亚戈.txt
# 蔓德拉.txt
# 蕾缪安.txt
# 薇卡.txt
# 薇尔丽芙.txt
# 血骑士.txt
# 血魔大君.txt
# 西尔莎.txt
# 西莫·威廉姆斯.txt
# 解真.txt
# 说书人.txt
# 贝纳尔多·贝洛内.txt
# 费奥多尔.txt
# 费斯特.txt
# 费莉亚·拉珀尔塔.txt
# 赫尔昏佐伦.txt
# 赫尔曼.txt
# 赫德雷.txt
# 路易斯·凯利.txt
# 迪伦马特.txt
# 逐魇骑士.txt
# 郑掌柜.txt
# 锈铜骑士.txt
# 阿丽娜.txt
# 阿伦茨·帕尔维斯.txt
# 阿克托斯.txt
# 阿勒黛·坎伯兰.txt
# 阿发.txt
# 阿尔图罗.txt
# 阿尔贝托·萨卢佐.txt
# 阿方索.txt
# 阿格尼尔.txt
# 阿然.txt
# 阿玛雅.txt
# 阿赫茉妮.txt
# 霜星.txt
# 食腐者之王.txt
# 马克维茨.txt
# 魏彦吾.txt
# 麦克马丁.txt
# 麦基.txt
# 黎.txt
# 黛柯绮·银币.txt
# 鼠王.txt
# 12F.txt
# Castle-3.txt
# Friston-3.txt
# Lancet-2.txt
# PhonoR-0.txt
# THRM-EX.txt
# U-Official.txt
# W.txt
# 万顷.txt
# 临光.txt
# 乌尔比安.txt
# 乌有.txt
# 九色鹿.txt
# 亚叶.txt
# 仇白.txt
# 令.txt
# 伊内丝.txt
# 伊桑.txt
# 伊芙利特.txt
# 休谟斯.txt
# 伺夜.txt
# 但书.txt
# 佩佩.txt
# 假日威龙陈.txt
# 傀影.txt
# 克洛丝.txt
# 冰酿.txt
# 凛冬.txt
# 凛视.txt
# 凯尔希.txt
# 初雪.txt
# 刺玫.txt
# 刻俄柏.txt
# 刻刀.txt
# 医生.txt
# 华法琳.txt
# 博士.txt
# 卡夫卡.txt
# 卡涅利安.txt
# 卡缇.txt
# 卡达.txt
# 历阵锐枪芬.txt
# 双月.txt
# 古米.txt
# 可颂.txt
# 史尔特尔.txt
# 史都华德.txt
# 号角.txt
# 吽.txt
# 和弦.txt
# 哈洛德.txt
# 嘉维尔.txt
# 四月.txt
# 因陀罗.txt
# 图耶.txt
# 圣约送葬人.txt
# 地灵.txt
# 坚雷.txt
# 埃拉托.txt
# 塑心.txt
# 塞雷娅.txt
# 夏栎.txt
# 夕.txt
# 多萝西.txt
# 夜刀.txt
# 夜半.txt
# 夜烟.txt
# 夜莺.txt
# 夜魔.txt
# 天火.txt
# 奥斯塔.txt
# 奥达.txt
# 妮芙.txt
# 娜仁图亚.txt
# 子月.txt
# 孑.txt
# 守林人.txt
# 安哲拉.txt
# 安德切尔.txt
# 安比尔.txt
# 安洁莉娜.txt
# 安赛尔.txt
# 宴.txt
# 寒檀.txt
# 寒芒克洛丝.txt
# 导火索.txt
# 小满.txt
# 山.txt
# 崖心.txt
# 嵯峨.txt
# 巡林者.txt
# 左乐.txt
# 巫恋.txt
# 布丁.txt
# 布洛卡.txt
# 帕拉斯.txt
# 年.txt
# 幽灵鲨.txt
# 异客.txt
# 归溟幽灵鲨.txt
# 微风.txt
# 德克萨斯.txt
# 惊蛰.txt
# 慑砂.txt
# 慕斯.txt
# 战车.txt
# 截云.txt
# 戴菲恩.txt
# 承曦格雷伊.txt
# 折光.txt
# 拉普兰德.txt
# 拜松.txt
# 掠风.txt
# 推进之王.txt
# 提丰.txt
# 摩根.txt
# 文月.txt
# 斑点.txt
# 斥罪.txt
# 断崖.txt
# 断罪者.txt
# 斯卡蒂.txt
# 早露.txt
# 明椒.txt
# 星极.txt
# 星源.txt
# 星熊.txt
# 晓歌.txt
# 普罗旺斯.txt
# 暗索.txt
# 暮落.txt
# 暴行.txt
# 暴雨.txt
# 月禾.txt
# 月见夜.txt
# 末药.txt
# 术髓.txt
# 杏仁.txt
# 杜宾.txt
# 杜林.txt
# 杰克.txt
# 杰西卡.txt
# 松果.txt
# 极光.txt
# 极境.txt
# 林.txt
# 柏喙.txt
# 格劳克斯.txt
# 格拉尼.txt
# 格雷伊.txt
# 桃金娘.txt
# 桑葚.txt
# 梅.txt
# 梅尔.txt
# 梓兰.txt
# 棘刺.txt
# 森蚺.txt
# 槐琥.txt
# 歌蕾蒂娅.txt
# 止颂.txt
# 正义骑士号.txt
# 水月.txt
# 泡普卡.txt
# 泡泡.txt
# 波登可.txt
# 泥岩.txt
# 泰拉大陆调查团.txt
# 洋灰.txt
# 洛洛.txt
# 流明.txt
# 流星.txt
# 浊心斯卡蒂.txt
# 海沫.txt
# 海蒂.txt
# 海霓.txt
# 涤火杰西卡.txt
# 淬羽赫默.txt
# 深巡.txt
# 深律.txt
# 深海色.txt
# 深靛.txt
# 清流.txt
# 清道夫.txt
# 渡桥.txt
# 温米.txt
# 温蒂.txt
# 澄闪.txt
# 濯尘芙蓉.txt
# 火哨.txt
# 火神.txt
# 火龙S黑角.txt
# 灰喉.txt
# 灰毫.txt
# 灰烬.txt
# 灵知.txt
# 炎客.txt
# 炎熔.txt
# 炎狱炎熔.txt
# 烈夏.txt
# 焰尾.txt
# 焰影苇草.txt
# 煌.txt
# 熔泉.txt
# 燧石.txt
# 爱丽丝.txt
# 特米米.txt
# 狮蝎.txt
# 猎蜂.txt
# 玛恩纳.txt
# 玫兰莎.txt
# 玫拉.txt
# 琳琅诗怀雅.txt
# 琴柳.txt
# 瑕光.txt
# 白金.txt
# 白铁.txt
# 白雪.txt
# 白面鸮.txt
# 百炼嘉维尔.txt
# 真理.txt
# 石棉.txt
# 石英.txt
# 砾.txt
# 稀音.txt
# 空.txt
# 空弦.txt
# 空构.txt
# 空爆.txt
# 米格鲁.txt
# 絮雨.txt
# 红.txt
# 红云.txt
# 红豆.txt
# 红隼.txt
# 纯烬艾雅法拉.txt
# 绮良.txt
# 维什戴尔.txt
# 维荻.txt
# 缄默德克萨斯.txt
# 缠丸.txt
# 缪尔赛思.txt
# 罗宾.txt
# 罗小黑.txt
# 罗比菈塔.txt
# 羽毛笔.txt
# 翎羽.txt
# 耀骑士临光.txt
# 老鲤.txt
# 耶拉.txt
# 能天使.txt
# 至简.txt
# 艾丝黛尔.txt
# 艾丽妮.txt
# 艾拉.txt
# 艾雅法拉.txt
# 芙兰卡.txt
# 芙蓉.txt
# 芬.txt
# 芳汀.txt
# 苇草.txt
# 苍苔.txt
# 苏苏洛.txt
# 苦艾.txt
# 莎草.txt
# 莫斯提马.txt
# 莱伊.txt
# 莱恩哈特.txt
# 菲亚梅塔.txt
# 蓝毒.txt
# 薄绿.txt
# 薇薇安娜.txt
# 蚀清.txt
# 蛇屠箱.txt
# 蜜莓.txt
# 蜜蜡.txt
# 衡沙.txt
# 褐果.txt
# 见行者.txt
# 角峰.txt
# 触痕.txt
# 讯使.txt
# 诗怀雅.txt
# 调香师.txt
# 谜图.txt
# 豆苗.txt
# 贝娜.txt
# 贾维.txt
# 赤冬.txt
# 赫德雷.txt
# 赫拉格.txt
# 赫默.txt
# 跃跃.txt
# 车尔尼.txt
# 达格达.txt
# 远山.txt
# 远牙.txt
# 迷迭香.txt
# 送葬人.txt
# 逻各斯.txt
# 郁金香.txt
# 酸糖.txt
# 重岳.txt
# 野鬃.txt
# 铃兰.txt
# 铅踝.txt
# 铎铃.txt
# 银灰.txt
# 铸铁.txt
# 锋刃.txt
# 锏.txt
# 锡人.txt
# 锡兰.txt
# 闪击.txt
# 闪灵.txt
# 阿.txt
# 阿斯卡纶.txt
# 阿消.txt
# 阿米娅.txt
# 阿罗玛.txt
# 陈.txt
# 陨星.txt
# 隐现.txt
# 雪绒.txt
# 雪雉.txt
# 雷蛇.txt
# 霍尔海雅.txt
# 霜华.txt
# 霜叶.txt
# 露托.txt
# 青枳.txt
# 鞭刃.txt
# 风丸.txt
# 风暴眼.txt
# 风笛.txt
# 食铁兽.txt
# 香草.txt
# 魏彦吾.txt
# 魔王.txt
# 鸿雪.txt
# 麒麟R夜刀.txt
# 麦哲伦.txt
# 黍.txt
# 黑.txt
# 黑角.txt
# 黑键.txt
# 龙舌兰.txt
# 1_习惯.txt
# 2_被选择的.txt
# 3_在梦中相遇.txt
# 4_表里不一.txt
# 5_胡言秘语.txt
# 6_一切照常.txt
# 7_在春天之前.txt
# 1_来办联欢会吧.txt
# 2_日记本.txt
# 3_今日厨房.txt
# 4_流浪者的归宿.txt
# 5_自讨苦吃.txt
# 6_向前走.txt
# 1_盖不住的锅盖.txt
# 2_不回头的车辙.txt
# 3_狂奔的瓶树.txt
# 4_落定的锤子.txt
# 5_咧嘴的矿井.txt
# 6_被踩住的影子.txt
# 1_向左向右.txt
# 2_隔墙有你.txt
# 3_扬尼与我.txt
# 4_告别时刻.txt
# 5_一次重逢.txt
# 6_别太紧张.txt
# 1_我不曾怀揣希望.txt
# 2_我不会全部遗忘.txt
# 3_我不知是否值得.txt
# 4_我所思不止于此.txt
# 5_我无惧前路何往.txt
# 6_我与最后的赌注.txt
# 1_无名氏的战争.txt
# 2_破局者.txt
# 3_射击训练.txt
# 4_存续公正.txt
# 5_课后作业.txt
# 6_北极星.txt
# 7_和光同尘.txt
# 1_荒舍.txt
# 2_只见星辰.txt
# 3_我曾凝望.txt
# 4_不得安宁.txt
# 5_日落已久.txt
# 6_空盔甲.txt
# 7_告别词.txt
# 1_近乡情怯.txt
# 2_中庭旅谷.txt
# 3_不问鬼神.txt
# 4_出入平安.txt
# 5_无名之辈.txt
# 6_独见寒山.txt
# 1_布朗陶.txt
# 2_后会有期.txt
# 3_狼与狼群.txt
# 4_再见罗伊.txt
# 5_和而不同.txt
# 6_真实故事.txt
# 1_无续集.txt
# 2_荒野路漫漫.txt
# 3_童话永存.txt
# 4_信仰号街车.txt
# 5_盲盒旅途.txt
# 6_剑与天秤.txt
# 7_为更好的自己.txt
# 1_洪炉示岁·迎春.txt
# 2_洪炉示岁·贺岁.txt
# 3_洪炉示岁·拜年.txt
# 1_粉碎大地.txt
# 2_烁烁星火.txt
# 3_真假怪谈.txt
# 4_遗落灯塔.txt
# 5_异类.txt
# 6_信.txt
# 1_如烟花般坠地.txt
# 2_归来时的街道.txt
# 3_披床单的怪物.txt
# 4_未完成的态度.txt
# 5_女巫与下午茶.txt
# 6_罐头里有什么.txt
# 1_沉于冰寒.txt
# 2_冰原的女儿.txt
# 3_树影幢幢.txt
# 4_自然的启示.txt
# 5_归乡.txt
# 6_终有一日.txt
# 7_未见之景.txt
# 1_红松.txt
# 2_落灰.txt
# 3_我也要大干一场.txt
# 4_只影孤身.txt
# 5_骑士之道.txt
# 6_大人物.txt
# 7_随风飘荡.txt
# 1_归处.txt
# 2_域外同族.txt
# 3_不知返.txt
# 4__回首.txt
# 5_四月的歌.txt
# 6_交错光影.txt
# 7_天空的故事.txt
# 1_或许有时.txt
# 2_我如浮萍.txt
# 3_终将同行.txt
# 4_孤行骑警.txt
# 5_必有所偿.txt
# 6_叮咚作响.txt
# 10_CV-ST-2_突然冲击.txt
# 11_CV-5_疑惑之影_行动前.txt
# 12_CV-5_疑惑之影_行动后.txt
# 13_CV-6_猎人之夜_行动前.txt
# 14_CV-6_猎人之夜_行动后.txt
# 15_CV-7_白热_行动前.txt
# 16_CV-7_白热_行动后.txt
# 17_CV-8_告别往昔_行动前.txt
# 18_CV-8_告别往昔_行动后.txt
# 19_CV-ST-3_法外之徒.txt
# 1_CV-ST-1_火线之中.txt
# 2_CV-1_孤独之地_行动前.txt
# 3_CV-1_孤独之地_行动后.txt
# 4_CV-2_双重保险_行动前.txt
# 5_CV-2_双重保险_行动后.txt
# 6_CV-3_圈套_行动前.txt
# 7_CV-3_圈套_行动后.txt
# 8_CV-4_缺席的人_行动前.txt
# 9_CV-4_缺席的人_行动后.txt
# 10_IS-ST-2_切开.txt
# 11_IS-5_恒久法则_行动前.txt
# 12_IS-5_恒久法则_行动后.txt
# 13_IS-6_旧日碾轧_行动前.txt
# 14_IS-6_旧日碾轧_行动后.txt
# 15_IS-7_何以忘却_行动前.txt
# 16_IS-7_何以忘却_行动后.txt
# 17_IS-8_危如累卵_行动前.txt
# 18_IS-8_危如累卵_行动后.txt
# 19_IS-ST-3_剜刺.txt
# 1_IS-ST-1_沉疴.txt
# 20_IS-9_文明的谎言_行动前.txt
# 21_IS-9_文明的谎言_行动后.txt
# 22_IS-10_“狼之主”_行动前.txt
# 23_IS-10_“狼之主”_行动后.txt
# 24_IS-ST-4_缝合.txt
# 2_IS-1_雨落无声_行动前.txt
# 3_IS-1_雨落无声_行动后.txt
# 4_IS-2_荣誉之人_行动前.txt
# 5_IS-2_荣誉之人_行动后.txt
# 6_IS-3_万箭所指_行动前.txt
# 7_IS-3_万箭所指_行动后.txt
# 8_IS-4_苦夜惊雷_行动前.txt
# 9_IS-4_苦夜惊雷_行动后.txt
# 10_GA-5_葬礼_行动前.txt
# 11_GA-5_葬礼_行动后.txt
# 12_GA-6_安魂曲_行动前.txt
# 13_GA-6_安魂曲_行动后.txt
# 14_GA-7_光与影_行动前.txt
# 15_GA-7_光与影_行动后.txt
# 16_GA-8_影与灰_行动前.txt
# 17_GA-8_影与灰_行动后.txt
# 18_GA-ST-2_鸢尾花.txt
# 1_GA-ST-1_风云际会.txt
# 2_GA-1_灯下黑_行动前.txt
# 3_GA-1_灯下黑_行动后.txt
# 4_GA-2_散步时光_行动前.txt
# 5_GA-2_散步时光_行动后.txt
# 6_GA-3_混血儿_行动前.txt
# 7_GA-3_混血儿_行动后.txt
# 8_GA-4_安魂教堂_行动前.txt
# 9_GA-4_安魂教堂_行动后.txt
# 10_CB-5_8：31P.M._行动前.txt
# 11_CB-5_8：31P.M._行动后.txt
# 12_CB-ST1_晚风轻拂.txt
# 13_CB-6_10：26P.M._行动前.txt
# 14_CB-6_10：26P.M._行动后.txt
# 15_CB-7_11：08P.M._行动前.txt
# 16_CB-7_11：08P.M._行动后.txt
# 17_CB-8_11：41P.M._行动前.txt
# 18_CB-8_11：41P.M._行动后.txt
# 19_CB-ST2_午夜龙门.txt
# 1_序章.txt
# 20_CB-9_0：01A.M._行动前.txt
# 21_CB-9_0：01A.M._行动后.txt
# 22_CB-10_1：11A.M._行动前.txt
# 23_CB-10_1：11A.M._行动后.txt
# 24_CB-ST3_破晓时分.txt
# 25_CB-EX1_群架诀窍_行动后.txt
# 26_CB-EX2_南辕北辙_行动后.txt
# 27_CB-EX3_林中小屋_行动后.txt
# 2_CB-1_6：44P.M._行动前.txt
# 3_CB-1_6：44P.M._行动后.txt
# 4_CB-2_7：15P.M._行动前.txt
# 5_CB-2_7：15P.M._行动后.txt
# 6_CB-3_7：22P.M._行动前.txt
# 7_CB-3_7：22P.M._行动后.txt
# 8_CB-4_7：59P.M._行动前.txt
# 9_CB-4_7：59P.M._行动后.txt
# 10_DH-4_铁人三项_行动前.txt
# 11_DH-4_铁人三项_行动后.txt
# 12_DH-5_曲径求胜_行动前.txt
# 13_DH-5_曲径求胜_行动后.txt
# 14_DH-6_紧追猛赶_行动前.txt
# 15_DH-6_紧追猛赶_行动后.txt
# 16_DH-ST-3_请君入瓮.txt
# 17_DH-7_沙滩阻击_行动前.txt
# 18_DH-8_抢滩登陆_行动后.txt
# 19_DH-9_鼠胆龙威_行动前.txt
# 1_DH-ST-1_不期而遇.txt
# 20_DH-9_鼠胆龙威_行动后.txt
# 21_DH-ST-4_海浪照常拍岸.txt
# 2_DH-TR-1_初来乍到_行动后.txt
# 3_DH-1_意外入选_行动前.txt
# 4_DH-1_意外入选_行动后.txt
# 5_DH-2_首轮竞赛_行动前.txt
# 6_DH-2_首轮竞赛_行动后.txt
# 7_DH-3_拔铳相助_行动前.txt
# 8_DH-3_拔铳相助_行动后.txt
# 9_DH-ST-2_中场休息.txt
# 10_MB-5_危险交易_行动前.txt
# 11_MB-5_危险交易_行动后.txt
# 12_MB-6_制定计划_行动前.txt
# 13_MB-6_制定计划_行动后.txt
# 14_MB-7_背叛_行动前.txt
# 15_MB-7_背叛_行动后.txt
# 16_MB-8_激战之末_行动前.txt
# 17_MB-8_激战之末_行动后.txt
# 18_MB-ST-2_正确的代价.txt
# 1_MB-1_密会_行动前.txt
# 2_MB-1_密会_行动后.txt
# 3_MB-2_另一个视角_行动前.txt
# 4_MB-2_另一个视角_行动后.txt
# 5_MB-3_首次遇袭_行动前.txt
# 6_MB-3_首次遇袭_行动后.txt
# 7_MB-ST-1_邀请.txt
# 8_MB-4_勇敢，莽撞_行动前.txt
# 9_MB-4_勇敢，莽撞_行动后.txt
# 10_CW-4_一波又起_行动后.txt
# 11_CW-5_柳暗花明_行动前.txt
# 12_CW-5_柳暗花明_行动后.txt
# 13_CW-6_群英荟萃_行动前.txt
# 14_CW-6_群英荟萃_行动后.txt
# 15_CW-7_空中楼阁_行动前.txt
# 16_CW-7_空中楼阁_行动后.txt
# 17_CW-8_过去与现在的交会_行动前.txt
# 18_CW-8_过去与现在的交会_行动后.txt
# 19_CW-9_恩怨纠葛_行动前.txt
# 1_CW-ST-1_阴云密布.txt
# 20_CW-9_恩怨纠葛_行动后.txt
# 21_CW-10_散于星辰之间_行动前.txt
# 22_CW-10_散于星辰之间_行动后.txt
# 23_CW-ST-3_留下的人.txt
# 24_CW-ST-4_推开未来之门.txt
# 2_CW-1_迷雾重重_行动前.txt
# 3_CW-1_迷雾重重_行动后.txt
# 4_CW-2_无迹可寻_行动前.txt
# 5_CW-2_无迹可寻_行动后.txt
# 6_CW-3_台前幕后_行动前.txt
# 7_CW-3_台前幕后_行动后.txt
# 8_CW-ST-2_一波未平.txt
# 9_CW-4_一波又起_行动前.txt
# 10_RI-5_各有所长_行动前.txt
# 11_RI-5_各有所长_行动后.txt
# 12_RI-6_邂逅_行动前.txt
# 13_RI-6_邂逅_行动后.txt
# 14_RI-ST-2_休息时间.txt
# 15_RI-7_有客先来_行动前.txt
# 16_RI-7_有客先来_行动后.txt
# 17_RI-8_嘉维尔之拳_行动前.txt
# 18_RI-8_嘉维尔之拳_行动后.txt
# 19_RI-9_走出密林_行动前.txt
# 1_RI-1_高空坠物_行动前.txt
# 20_RI-9_走出密林_行动后.txt
# 21_RI-EX-1_声东击西_行动后.txt
# 2_RI-1_高空坠物_行动后.txt
# 3_RI-2_粗细有别_行动前.txt
# 4_RI-2_粗细有别_行动后.txt
# 5_RI-3_往昔_行动前.txt
# 6_RI-3_往昔_行动后.txt
# 7_RI-4_机兽咆哮_行动前.txt
# 8_RI-4_机兽咆哮_行动后.txt
# 9_RI-ST-1_悍将之心.txt
# 10_IW-ST-2_万物有灵.txt
# 11_IW-5_货与人_行动前.txt
# 12_IW-5_货与人_行动后.txt
# 13_IW-6_传说_行动前.txt
# 14_IW-6_传说_行动后.txt
# 15_IW-7_乱局_行动前.txt
# 16_IW-7_乱局_行动后.txt
# 17_IW-9_岁相_行动前.txt
# 18_IW-9_岁相_行动后.txt
# 19_IW-ST-3_再弈.txt
# 1_IW-ST-1_客将至.txt
# 2_IW-1_化物_行动前.txt
# 3_IW-1_化物_行动后.txt
# 4_IW-2_无寻处_行动前.txt
# 5_IW-2_无寻处_行动后.txt
# 6_IW-3_光与影_行动前.txt
# 7_IW-3_光与影_行动后.txt
# 8_IW-4_秉烛_行动前.txt
# 9_IW-4_秉烛_行动后.txt
# 10_LE-ST-2_春之祭.txt
# 11_LE-5_月光_行动前.txt
# 12_LE-5_月光_行动后.txt
# 13_LE-6_骷髅之舞_行动前.txt
# 14_LE-6_骷髅之舞_行动后.txt
# 15_LE-7_升华之夜_行动前.txt
# 16_LE-7_升华之夜_行动后.txt
# 17_LE-8_命运_行动前.txt
# 18_LE-8_命运_行动后.txt
# 19_LE-ST-3_自新大陆.txt
# 1_LE-ST-1_华丽大圆舞曲.txt
# 2_LE-1_闲聊波尔卡_行动前.txt
# 3_LE-1_闲聊波尔卡_行动后.txt
# 4_LE-2_热情，或悲怆_行动前.txt
# 5_LE-2_热情，或悲怆_行动后.txt
# 6_LE-3_自由射手_行动前.txt
# 7_LE-3_自由射手_行动后.txt
# 8_LE-4_惊愕_行动前.txt
# 9_LE-4_惊愕_行动后.txt
# 10_ZT-5_奏鸣曲“秋日”_行动前.txt
# 11_ZT-5_奏鸣曲“秋日”_行动后.txt
# 12_ZT-ST-2_间奏“未竟赋格”.txt
# 13_ZT-6_华尔兹“假面”_行动前.txt
# 14_ZT-6_华尔兹“假面”_行动后.txt
# 15_ZT-7_协奏曲“复活”_行动前.txt
# 16_ZT-7_协奏曲“复活”_行动后.txt
# 17_ZT-8_夜歌“未见的高塔”_行动前.txt
# 18_ZT-8_夜歌“未见的高塔”_行动后.txt
# 19_ZT-9_幻想曲“赠答”_行动前.txt
# 1_ZT-ST-1_前奏“意外归来”.txt
# 20_ZT-9_幻想曲“赠答”_行动后.txt
# 21_ZT-10_弥撒“君王”_行动前.txt
# 22_ZT-10_弥撒“君王”_行动后.txt
# 23_ZT-ST-3_尾奏“晚霞”.txt
# 2_ZT-1_清唱“晴空之歌”_行动前.txt
# 3_ZT-1_清唱“晴空之歌”_行动后.txt
# 4_ZT-2_序曲“哨兵”_行动前.txt
# 5_ZT-2_序曲“哨兵”_行动后.txt
# 6_ZT-3_练习曲“奇遇”_行动前.txt
# 7_ZT-3_练习曲“奇遇”_行动后.txt
# 8_ZT-4_狂想曲“望想”_行动前.txt
# 9_ZT-4_狂想曲“望想”_行动后.txt
# 10_BB-4_悠长的旅途_行动后.txt
# 11_BB-5_激变烽烟_行动前.txt
# 12_BB-5_激变烽烟_行动后.txt
# 13_BB-6_灯火闪烁不定_行动前.txt
# 14_BB-6_灯火闪烁不定_行动后.txt
# 15_BB-7_阴影显现_行动前.txt
# 16_BB-7_阴影显现_行动后.txt
# 17_BB-8_终局倒计时_行动前.txt
# 18_BB-8_终局倒计时_行动后.txt
# 19_BB-9_尘埃落定_行动前.txt
# 1_BB-ST-1_未完成的告别.txt
# 20_BB-9_尘埃落定_行动后.txt
# 21_BB-10_再见，再见_行动前.txt
# 22_BB-10_再见，再见_行动后.txt
# 23_BB-ST-3_灵魂尽头.txt
# 2_BB-1_宏伟愿景_行动前.txt
# 3_BB-1_宏伟愿景_行动后.txt
# 4_BB-2_命途何在_行动前.txt
# 5_BB-2_命途何在_行动后.txt
# 6_BB-3_无声破裂_行动前.txt
# 7_BB-3_无声破裂_行动后.txt
# 8_BB-ST-2_在疲惫中苏醒.txt
# 9_BB-4_悠长的旅途_行动前.txt
# 10_HS-5_纺绫罗_行动前.txt
# 11_HS-5_纺绫罗_行动后.txt
# 12_HS-ST-2_织锦缎.txt
# 13_HS-6_卷赤霞_行动前.txt
# 14_HS-7_梦四时_行动后.txt
# 15_HS-8_种因_行动前.txt
# 16_HS-8_种因_行动后.txt
# 17_HS-9_得果_行动前.txt
# 18_HS-9_得果_行动后.txt
# 19_HS-ST-3_彻风雨.txt
# 1_HS-ST-1_禾下梦.txt
# 2_HS-1_赴大荒_行动前.txt
# 3_HS-1_赴大荒_行动后.txt
# 4_HS-2_祭神农_行动前.txt
# 5_HS-2_祭神农_行动后.txt
# 6_HS-3_早芒种_行动前.txt
# 7_HS-3_早芒种_行动后.txt
# 8_HS-4_话桑麻_行动前.txt
# 9_HS-4_话桑麻_行动后.txt
# 10_SN-4_灯塔入口_行动后.txt
# 11_SN-5_灯塔控制室_行动前.txt
# 12_SN-5_灯塔控制室_行动后.txt
# 13_SN-6_中央通道_行动前.txt
# 14_SN-ST-6_下层大厅.txt
# 15_SN-ST-7_宴会厅.txt
# 16_SN-7_黄金回廊_行动后.txt
# 17_SN-ST-8_指挥大厅.txt
# 18_SN-ST-9_主舰桥.txt
# 19_SN-8_观测所_行动后.txt
# 1_SN-ST-1_古井.txt
# 20_SN-ST-10_甲板室.txt
# 21_SN-ST-11_主桅杆.txt
# 22_SN-10_礼仪广场_行动前.txt
# 23_SN-10_礼仪广场_行动后.txt
# 24_SN-ST-12_格兰法洛.txt
# 2_SN-1_中心广场_行动前.txt
# 3_SN-1_中心广场_行动后.txt
# 4_SN-ST-2_海滨小道.txt
# 5_SN-2_广场南路_行动后.txt
# 6_SN-ST-3_空旷的大街.txt
# 7_SN-3_安静的步道_行动后.txt
# 8_SN-ST-4_临海长街.txt
# 9_SN-ST-5_登陆点.txt
# 10_CR-5_消防通道_行动前.txt
# 11_CR-5_消防通道_行动后.txt
# 12_CR-6_反艺术运动_行动前.txt
# 13_CR-6_反艺术运动_行动后.txt
# 14_CR-ST-2_策展人会客厅.txt
# 15_CR-7_安全出口_行动前.txt
# 16_CR-7_安全出口_行动后.txt
# 17_CR-8_一跃而下_行动前.txt
# 18_CR-8_一跃而下_行动后.txt
# 19_CR-ST-3_艺术馆餐厅.txt
# 1_CR-ST-1_特别参观通道.txt
# 2_CR-1_城市主题展_行动前.txt
# 3_CR-1_城市主题展_行动后.txt
# 4_CR-2_不对称庭园_行动前.txt
# 5_CR-2_不对称庭园_行动后.txt
# 6_CR-3_假面舞池_行动前.txt
# 7_CR-3_假面舞池_行动后.txt
# 8_CR-4_非传统艺术空间_行动前.txt
# 9_CR-4_非传统艺术空间_行动后.txt
# 10_TW-5_冬灵挽歌_行动前.txt
# 11_TW-5_冬灵挽歌_行动后.txt
# 12_TW-6_怒意漫延_行动前.txt
# 13_TW-6_怒意漫延_行动后.txt
# 14_TW-7_群峦崩塌_行动前.txt
# 15_TW-7_群峦崩塌_行动后.txt
# 16_TW-8_月光沉沦_行动前.txt
# 17_TW-8_月光沉沦_行动后.txt
# 18_TW-ST-2_余烬之上.txt
# 19_TW-S-1_三座巨像_行动后.txt
# 1_TW-ST-1_老栎树下.txt
# 20_TW-S-2_一束哀悼_行动后.txt
# 2_TW-1_缄默不言_行动前.txt
# 3_TW-1_缄默不言_行动后.txt
# 4_TW-2_叛乱前哨_行动前.txt
# 5_TW-2_叛乱前哨_行动后.txt
# 6_TW-3_高塔烟火_行动前.txt
# 7_TW-3_高塔烟火_行动后.txt
# 8_TW-4_复仇之魂_行动前.txt
# 9_TW-4_复仇之魂_行动后.txt
# 10_OD-6_领主宅邸攻防战_行动前.txt
# 11_OD-6_领主宅邸攻防战_行动后.txt
# 12_OD-ST-2_一场葬礼.txt
# 13_OD-7_地堡防线_行动前.txt
# 14_OD-7_地堡防线_行动后.txt
# 15_OD-8_渗透作战_行动前.txt
# 16_OD-8_渗透作战_行动后.txt
# 17_OD-ST-3_行走于大地之上.txt
# 1_OD-ST-1_拉马克行动.txt
# 2_OD-1_外勤记录_行动前.txt
# 3_OD-1_外勤记录_行动后.txt
# 4_OD-2_扩大防守范围_行动前.txt
# 5_OD-2_扩大防守范围_行动后.txt
# 6_OD-3_安全屋攻防战_行动前.txt
# 7_OD-3_安全屋攻防战_行动后.txt
# 8_OD-5_物资回收计划_行动前.txt
# 9_OD-5_物资回收计划_行动后.txt
# 10_SL-5_我会唱一首彩虹_行动前.txt
# 11_SL-5_我会唱一首彩虹_行动后.txt
# 12_SL-ST-2_雨啊，雨啊，快离开.txt
# 13_SL-6_林中小木屋_行动前.txt
# 14_SL-6_林中小木屋_行动后.txt
# 15_SL-7_靠着我的肩膀哭泣_行动前.txt
# 16_SL-7_靠着我的肩膀哭泣_行动后.txt
# 17_SL-8_爱之歌_行动前.txt
# 18_SL-8_爱之歌_行动后.txt
# 19_SL-ST-3_晴天.txt
# 1_SL-ST-1_到站旁.txt
# 2_SL-1_你的耳朵长不长？_行动前.txt
# 3_SL-1_你的耳朵长不长？_行动后.txt
# 4_SL-2_小蓝孩_行动前.txt
# 5_SL-2_小蓝孩_行动后.txt
# 6_SL-3_手指之家_行动前.txt
# 7_SL-3_手指之家_行动后.txt
# 8_SL-4_一个水手出海了_行动前.txt
# 9_SL-4_一个水手出海了_行动后.txt
# 10_OF-4_他是将军_行动前.txt
# 11_OF-4_他是将军_行动后.txt
# 12_OF-ST3_压力之下.txt
# 13_OF-5_别阻止我_行动前.txt
# 14_OF-5_别阻止我_行动后.txt
# 15_OF-6_杀手女皇_行动前.txt
# 16_OF-6_杀手女皇_行动后.txt
# 17_OF-ST4_爱某个人.txt
# 18_OF-7_一锤定音_行动前.txt
# 19_OF-7_一锤定音_行动后.txt
# 1_演出开始.txt
# 20_OF-8_汐斯塔狂想曲_行动前.txt
# 21_OF-8_汐斯塔狂想曲_行动后.txt
# 22_OF-ST5_此生挚爱.txt
# 23_OF-ST6_邂逅潮声.txt
# 24_OF-EX1_预热活动_行动后.txt
# 25_OF-EX3_采访环节_行动后.txt
# 26_OF-EX6_完美落幕_行动后.txt
# 2_OF-ST1_摇滚起来.txt
# 3_OF-1_火山制造_行动前.txt
# 4_OF-1_火山制造_行动后.txt
# 5_OF-ST2_冲破藩篱.txt
# 6_OF-2_演出继续_行动前.txt
# 7_OF-2_演出继续_行动后.txt
# 8_OF-3_竞走赛_行动前.txt
# 9_OF-3_竞走赛_行动后.txt
# 10_FC-5_祝福的歌谣_行动前.txt
# 11_FC-5_祝福的歌谣_行动后.txt
# 12_FC-6_无人知晓_行动后.txt
# 13_FC-7_生灵火花_行动前.txt
# 14_FC-7_生灵火花_行动后.txt
# 15_FC-ST-2_自灰烬之中.txt
# 16_FC-8_她的影子_行动前.txt
# 17_FC-8_她的影子_行动后.txt
# 18_FC-ST-3_一声呜咽.txt
# 1_FC-ST-1_荒地钟声.txt
# 2_FC-1_逃离与追逐_行动前.txt
# 3_FC-1_逃离与追逐_行动后.txt
# 4_FC-2_不幸重逢_行动前.txt
# 5_FC-2_不幸重逢_行动后.txt
# 6_FC-3_引燃草垛_行动前.txt
# 7_FC-3_引燃草垛_行动后.txt
# 8_FC-4_热灼梦_行动前.txt
# 9_FC-4_热灼梦_行动后.txt
# 10_MN-5_斯沃玛视频_行动前.txt
# 11_MN-5_斯沃玛视频_行动后.txt
# 12_MN-6_蓝耳酒窖_行动前.txt
# 13_MN-6_蓝耳酒窖_行动后.txt
# 14_MN-7_梅什科集团_行动前.txt
# 15_MN-7_梅什科集团_行动后.txt
# 16_MN-ST-2_酒杯.txt
# 17_MN-8_商业联合_行动前.txt
# 18_MN-8_商业联合_行动后.txt
# 19_MN-ST-3_缄默启程.txt
# 1_MN-ST-1_亮相.txt
# 2_MN-1_艾伦精选_行动前.txt
# 3_MN-1_艾伦精选_行动后.txt
# 4_MN-2_呼啸守卫_行动前.txt
# 5_MN-2_呼啸守卫_行动后.txt
# 6_MN-3_玫瑰报业_行动前.txt
# 7_MN-3_玫瑰报业_行动后.txt
# 8_MN-4_辉煌盾工业_行动前.txt
# 9_MN-4_辉煌盾工业_行动后.txt
# 10_IC-5_加速冲线_行动前.txt
# 11_IC-5_加速冲线_行动后.txt
# 12_IC-6_战逃反应_行动前.txt
# 13_IC-6_战逃反应_行动后.txt
# 14_IC-7_生活之道_行动前.txt
# 15_IC-7_生活之道_行动后.txt
# 16_IC-8_金属气味_行动前.txt
# 17_IC-9_穹顶之上_行动后.txt
# 18_IC-ST-2_失乐园.txt
# 1_IC-ST-1_旅行前夕.txt
# 2_IC-1_沉浸式游览_行动前.txt
# 3_IC-1_沉浸式游览_行动后.txt
# 4_IC-2_下坠_行动前.txt
# 5_IC-2_下坠_行动后.txt
# 6_IC-3_奇谈怪论_行动前.txt
# 7_IC-3_奇谈怪论_行动后.txt
# 8_IC-4_“大水坑”_行动前.txt
# 9_IC-4_“大水坑”_行动后.txt
# 10_DM-7_龟裂_行动后.txt
# 11_DM-8_离散_行动前.txt
# 12_DM-8_离散_行动后.txt
# 13_DM-ST-1_求生.txt
# 1_DM-1_埋藏_行动前.txt
# 2_DM-1_埋藏_行动后.txt
# 3_DM-2_偶然_行动前.txt
# 4_DM-2_偶然_行动后.txt
# 5_DM-3_挤压_行动前.txt
# 6_DM-5_旗帜_行动后.txt
# 7_DM-6_远遁_行动前.txt
# 8_DM-6_远遁_行动后.txt
# 9_DM-7_龟裂_行动前.txt
# 10_BP-5_不治的命运_行动前.txt
# 11_BP-5_不治的命运_行动后.txt
# 12_BP-6_阿戈尔失格_行动前.txt
# 13_BP-6_阿戈尔失格_行动后.txt
# 14_BP-ST-2_如海流倒灌.txt
# 15_BP-7_从历史中来_行动前.txt
# 16_BP-7_从历史中来_行动后.txt
# 17_BP-8_“何谓存续？”_行动前.txt
# 18_BP-8_“何谓存续？”_行动后.txt
# 19_BP-ST-3_歧路者与同行者.txt
# 1_BP-ST-1_浪潮守望者.txt
# 2_BP-1_第一次接触_行动前.txt
# 3_BP-1_第一次接触_行动后.txt
# 4_BP-2_评议式迎接_行动前.txt
# 5_BP-2_评议式迎接_行动后.txt
# 6_BP-3_如海雪纷散_行动前.txt
# 7_BP-3_如海雪纷散_行动后.txt
# 8_BP-4_牺牲与代价_行动前.txt
# 9_BP-4_牺牲与代价_行动后.txt
# 10_WR-ST-2_一日之祸.txt
# 11_WR-6_画中_行动前.txt
# 12_WR-6_画中_行动后.txt
# 13_WR-8_大梦_行动前.txt
# 14_WR-8_大梦_行动后.txt
# 15_WR-10_夕_行动前.txt
# 16_WR-10_夕_行动后.txt
# 17_WR-ST-3_一问之答.txt
# 1_WR-ST-1_一钳之恩.txt
# 2_WR-1_初醒_行动前.txt
# 3_WR-1_初醒_行动后.txt
# 4_WR-2_墨魉_行动前.txt
# 5_WR-2_墨魉_行动后.txt
# 6_WR-4_掌柜_行动前.txt
# 7_WR-4_掌柜_行动后.txt
# 8_WR-5_拙山_行动前.txt
# 9_WR-5_拙山_行动后.txt
# 10_WB-ST-2_信我所信.txt
# 11_WB-5_风雨欲来_行动前.txt
# 12_WB-6_瑟瑟秋华_行动后.txt
# 13_WB-7_“屏风卫”_行动前.txt
# 14_WB-7_“屏风卫”_行动后.txt
# 15_WB-8_旷古之晤_行动前.txt
# 16_WB-8_旷古之晤_行动后.txt
# 17_WB-9_“冬藏”_行动前.txt
# 18_WB-9_“冬藏”_行动后.txt
# 19_WB-ST-3_粘劫收后.txt
# 1_WB-ST-1_忽梦少年事.txt
# 2_WB-1_塞上春来_行动前.txt
# 3_WB-1_塞上春来_行动后.txt
# 4_WB-2_沙海黄尘_行动前.txt
# 5_WB-2_沙海黄尘_行动后.txt
# 6_WB-3_树犹如此_行动前.txt
# 7_WB-3_树犹如此_行动后.txt
# 8_WB-4_不念往昔_行动前.txt
# 9_WB-4_不念往昔_行动后.txt
# 10_HE-5_主在圣殿中_行动前.txt
# 11_HE-5_主在圣殿中_行动后.txt
# 12_HE-6_夜半歌声_行动前.txt
# 13_HE-6_夜半歌声_行动后.txt
# 14_HE-ST-2_在花园里.txt
# 15_HE-7_以爱相连_行动前.txt
# 16_HE-7_以爱相连_行动后.txt
# 17_HE-8_愿跟随主_行动前.txt
# 18_HE-8_愿跟随主_行动后.txt
# 19_HE-ST-3_慈光引导.txt
# 1_HE-ST-1_奉上冠冕.txt
# 2_HE-1_我有一个荣美家乡_行动前.txt
# 3_HE-1_我有一个荣美家乡_行动后.txt
# 4_HE-2_生命运河_行动前.txt
# 5_HE-2_生命运河_行动后.txt
# 6_HE-3_岂可空手回天府？_行动前.txt
# 7_HE-3_岂可空手回天府？_行动后.txt
# 8_HE-4_我曾舍命为你_行动前.txt
# 9_HE-4_我曾舍命为你_行动后.txt
# 10_DV-5_多萝西的承诺_行动前.txt
# 11_DV-S-1_困心.txt
# 12_DV-5_多萝西的承诺_行动后.txt
# 13_DV-6_挣脱美梦_行动前.txt
# 14_DV-6_挣脱美梦_行动后.txt
# 15_DV-7_疯狂的信号_行动前.txt
# 16_DV-S-2_衡虑.txt
# 17_DV-7_疯狂的信号_行动后.txt
# 18_DV-8_连接内心_行动前.txt
# 19_DV-8_连接内心_行动后.txt
# 1_DV-ST-1_逆行.txt
# 20_DV-ST-2_启程.txt
# 2_DV-1_特里蒙街道_行动前.txt
# 3_DV-1_特里蒙街道_行动后.txt
# 4_DV-2_拓荒者小屋_行动前.txt
# 5_DV-2_拓荒者小屋_行动后.txt
# 6_DV-3_动力装甲_行动前.txt
# 7_DV-3_动力装甲_行动后.txt
# 8_DV-4_无人的小巷_行动前.txt
# 9_DV-4_无人的小巷_行动后.txt
# 10_CF-5_野蛮肇事者_行动后.txt
# 11_CF-6_禁飞区_行动前.txt
# 12_CF-6_禁飞区_行动后.txt
# 13_CF-7_锥心之刺_行动前.txt
# 14_CF-7_锥心之刺_行动后.txt
# 15_CF-8_奸诈者必自食恶果_行动前.txt
# 16_CF-8_奸诈者必自食恶果_行动后.txt
# 17_CF-9_决战！燃烧的狩魂！_行动前.txt
# 18_CF-9_决战！燃烧的狩魂！_行动后.txt
# 19_CF-ST-3_晨曦.txt
# 1_CF-ST-1_噩梦.txt
# 2_CF-TR-1_来袭！天空王者！_行动前.txt
# 3_CF-TR-1_来袭！天空王者！_行动后.txt
# 4_CF-2_坚硬磐石_行动前.txt
# 5_CF-2_坚硬磐石_行动后.txt
# 6_CF-3_迎头痛击_行动前.txt
# 7_CF-4_破空的飞羽_行动后.txt
# 8_CF-ST-2_林昏焰明.txt
# 9_CF-5_野蛮肇事者_行动前.txt
# 10_SV-6_厌食_行动后.txt
# 11_SV-7_守护者_行动前.txt
# 12_SV-7_守护者_行动后.txt
# 13_SV-ST-1_唤醒噩梦.txt
# 14_SV-8_亲族_行动前.txt
# 15_SV-8_亲族_行动后.txt
# 16_SV-9_笃信者_行动前.txt
# 17_SV-9_笃信者_行动后.txt
# 18_SV-ST-2_侥幸离去.txt
# 1_SV-1_闯入者_行动前.txt
# 2_SV-1_闯入者_行动后.txt
# 3_SV-2_歌手_行动前.txt
# 4_SV-2_歌手_行动后.txt
# 5_SV-3_外来者_行动前.txt
# 6_SV-3_外来者_行动后.txt
# 7_SV-4_海洋_行动前.txt
# 8_SV-5_遭弃者_行动后.txt
# 9_SV-6_厌食_行动前.txt
# 10_WD-7_家园_行动前.txt
# 11_WD-7_家园_行动后.txt
# 12_WD-8_大雪将至_行动前.txt
# 13_WD-8_大雪将至_行动后.txt
# 14_WD-ST-2_异乡来客.txt
# 1_WD-1_赤角小镇之围_行动前.txt
# 2_WD-1_赤角小镇之围_行动后.txt
# 3_WD-2_绿洲惊雷_行动前.txt
# 4_WD-2_绿洲惊雷_行动后.txt
# 5_WD-3_仙人掌沙丘_行动前.txt
# 6_WD-3_仙人掌沙丘_行动后.txt
# 7_WD-ST-1_松心百合.txt
# 8_WD-5_沁礁之地_行动前.txt
# 9_WD-5_沁礁之地_行动后.txt
# 10_RS-ST-2_登山铁道.txt
# 11_RS-5_逃票？_行动前.txt
# 12_RS-5_逃票？_行动后.txt
# 13_RS-6_补票！_行动前.txt
# 14_RS-6_补票！_行动后.txt
# 15_RS-7_制动失灵_行动前.txt
# 16_RS-7_制动失灵_行动后.txt
# 17_RS-8_极限时速_行动前.txt
# 18_RS-8_极限时速_行动后.txt
# 19_RS-ST-3_终点站.txt
# 1_RS-ST-1_候车大厅.txt
# 2_RS-1_注意事项_行动前.txt
# 3_RS-1_注意事项_行动后.txt
# 4_RS-2_同车异图_行动前.txt
# 5_RS-2_同车异图_行动后.txt
# 6_RS-3_临时停车_行动前.txt
# 7_RS-3_临时停车_行动后.txt
# 8_RS-4_重回正轨_行动前.txt
# 9_RS-4_重回正轨_行动后.txt
# 10_NL-ST-2_权与力.txt
# 11_NL-5_人言可畏_行动前.txt
# 12_NL-5_人言可畏_行动后.txt
# 13_NL-6_被包围者_行动前.txt
# 14_NL-6_被包围者_行动后.txt
# 15_NL-ST-3_酣眠的城市.txt
# 16_NL-7_梦的余韵_行动前.txt
# 17_NL-7_梦的余韵_行动后.txt
# 18_NL-8_最后的怯薛_行动前.txt
# 19_NL-8_最后的怯薛_行动后.txt
# 1_NL-ST-1_欣欣向荣.txt
# 20_NL-9_叹息_行动前.txt
# 21_NL-9_叹息_行动后.txt
# 22_NL-10_耀骑士_行动前.txt
# 23_NL-10_耀骑士_行动后.txt
# 24_NL-ST-4_未知与未来.txt
# 2_NL-1_金盏花_行动前.txt
# 3_NL-1_金盏花_行动后.txt
# 4_NL-2_垂死的刺_行动前.txt
# 5_NL-2_垂死的刺_行动后.txt
# 6_NL-3_筹备着_行动前.txt
# 7_NL-3_筹备着_行动后.txt
# 8_NL-4_诗的容貌_行动前.txt
# 9_NL-4_诗的容貌_行动后.txt
# 10_BI-4_立雪求道_行动后.txt
# 11_BI-5_猎场_行动前.txt
# 12_BI-5_猎场_行动后.txt
# 13_BI-ST-3_一着不慎.txt
# 14_BI-6_歧路_行动前.txt
# 15_BI-6_歧路_行动后.txt
# 16_BI-7_破冰_行动前.txt
# 17_BI-7_破冰_行动后.txt
# 18_BI-8_将军_行动前.txt
# 19_BI-8_将军_行动后.txt
# 1_BI-1_不欢而聚_行动前.txt
# 20_BI-ST-4_封盘.txt
# 2_BI-1_不欢而聚_行动后.txt
# 3_BI-ST-1_入乡随俗.txt
# 4_BI-2_息事宁人_行动前.txt
# 5_BI-2_息事宁人_行动后.txt
# 6_BI-3_人心难测_行动前.txt
# 7_BI-3_人心难测_行动后.txt
# 8_BI-ST-2_山雪欲来.txt
# 9_BI-4_立雪求道_行动前.txt
# 10_GT-5_各抒己见_行动后.txt
# 11_GT-6_黄金三角_行动前.txt
# 12_GT-6_黄金三角_行动后.txt
# 13_GT-EX-1_大地惊雷_行动后.txt
# 14_GT-EX-3_与狼共舞_行动后.txt
# 15_GT-HX-1_碧血金沙_行动后.txt
# 16_GT-HX-3_西部往事_行动后.txt
# 1_GT-1_日正当中_行动前.txt
# 2_GT-1_日正当中_行动后.txt
# 3_GT-2_察言观色_行动前.txt
# 4_GT-2_察言观色_行动后.txt
# 5_GT-3_意外之旅_行动前.txt
# 6_GT-3_意外之旅_行动后.txt
# 7_GT-4_污点证人_行动前.txt
# 8_GT-4_污点证人_行动后.txt
# 9_GT-5_各抒己见_行动前.txt
# 1_新星主播.txt
# 2_再也没有什么能阻止她了.txt
# 3_警惕新型金融诈骗.txt
# 4_她不禁开始思索是谁动了自己的瘤奶.txt
# 5_一生四，四生三，三生万物.txt
# 6_断罪者最喜欢的一集.txt
# 7_敬请收看：爱、主播&单推人.txt
# 8_“就那样吧”.txt
# 1_隐藏剧情.txt
# 2_采购中心.txt
# 3_EP09_前情提要.txt
# 4_EP10_序曲.txt
# 5_EP11_序曲.txt
# 6_EP12_序曲.txt
# 7_艺术之神.txt
# 8_多维合作.txt
# 9_保全派驻.txt
# 1_危机合约.txt
# 2_荒芜行动_P1.txt
# 3_荒芜行动_P2.txt
# 1_金牌讲师.txt
# 2_IM-1_行动后.txt
# 1_嘻哈之王.txt
# 2_LTTB_Extraordinary_rap_battle!_行动后.txt
# 1_狂弹要塞.txt
# 2_BF-3_没想到还有一关_行动后.txt
# 1_固定开头AVG.txt
# 2_开头AVG.txt
# 3_结尾AVG.txt
# 1_逃离.txt
# 2_选择.txt
# 3_路漫漫.txt
# 1_沙中之火.txt
# 2_结局1.txt
# 3_结局2.txt
# 4_结局3.txt
# 1_初来乍到.txt
# 2_见证往昔.txt
# 3_寻宝与援兵.txt
# 4_阿尔萨兰的秘密.txt
# 5_和平的回归.txt
# 1_序章.txt
# 2_舞会终场.txt
# 3_滑稽喜剧.txt
# 4_盛大揭幕.txt
# 5_沉默之章.txt
# 1_行动开始.txt
# 2_迷尘幻梦.txt
# 3_茫然行者.txt
# 4_归于荒野.txt
# 1_序章.txt
# 2_越过群山.txt
# 3_直至冬夜降临.txt
# 4_自深处的一瞥.txt
# 5_终始.txt
# 1_序章.txt
# 2_平凡即是喜乐.txt
# 3_静谧时代.txt
# 4_息潮的代价.txt
# 5_如星空般深蓝.txt
# 1_序章.txt
# 2_憧憬未来.txt
# 3_双王记.txt
# 4_天使之城.txt

# %%
# try to find all different kinds of tags
# Walk through the directory tree
tags = {}
import os
import re
for dirpath, dirnames, filenames in os.walk("./plot/"):
  for file in filenames:
    file_path = os.path.join(dirpath, file)
    with open(file_path, "r", encoding="UTF-8") as f:
      lines = f.readlines()
      for i in lines:
        match = re.search(r'\[(\w+)', i)
        if match:
          tags[match.group(1)] = i + " ; " + file_path

# %%
Dialog/dialog : 对话结束 [Dialog]
Decision: 选择 [Decision(options="马上就好，稍等。", values="1")]
Predicate: 选择对应的结果 [Predicate(references="1")]
Subtitle/subtitle: 旁白 [Subtitle(text="“为了你自己。”")]
正常: [name="博卓卡斯替"]......圣卫们，跟上，保护同胞。
# Out:
#   Cell In[7], line 1
#     Dialog/dialog : 对话结束 [Dialog]
#     ^
# SyntaxError: illegal target for annotation

# %%
import os

def convert_gbk_to_utf8(directory):
    # Iterate over all files in the specified directory
    for dirpath, dirnames, filenames in os.walk(directory):
        for filename in filenames:
            file_path = os.path.join(dirpath, filename)
            try:
                # Open the file with GBK encoding
                with open(file_path, 'r', encoding='gbk') as gbk_file:
                    content = gbk_file.read()
                
                # Write the content to a new file with UTF-8 encoding
                with open(file_path, 'w', encoding='utf-8') as utf8_file:
                    utf8_file.write(content)
                
                print(f"Converted: {file_path}")

            except Exception as e:
                print(f"Error processing {file_path}: {e}")

# Usage example
directory_path = './plot/'  # Replace with your directory path
convert_gbk_to_utf8(directory_path)

# %%
dialog_id INT PRIMARY KEY AUTO_INCREMENT COMMENT "对话主键",
story VARCHAR(20) NOT NULL COMMENT "所在故事,例:慈悲灯塔",
chapter VARCHAR(255) NOT NULL COMMENT "所在章节,例:14-1_从回忆中坠落",
dialog VARCHAR(255) NOT NULL COMMENT "对话内容",
speaker VARCHAR(20) NOT NULL COMMENT "说话人,可能是旁白,选项,分支,或者人名,昵称等",
dialog_type VARCHAR(10) NOT NULL COMMENT "对话类型, 对话,旁白,选择,分支等",
created_at DATETIME DEFAULT CURRENT_TIMESTAMP COMMENT "创建时间",
altered_at DATETIME DEFAULT CURRENT_TIMESTAMP COMMENT "修改时间"

# %%
stories = os.listdir(path)[3:]
stories
# Out:
# ['喧闹法则',
#  '多索雷斯假日',
#  '孤岛风云',
#  '孤星',
#  '密林悍将归来',
#  '将进酒',
#  '尘影余音',
#  '崔林特尔梅之金',
#  '巴别塔',
#  '怀黍离',
#  '愚人号',
#  '水晶箭行动',
#  '沃伦姆德的薄暮',
#  '源石尘行动',
#  '火山旅梦',
#  '火蓝之心',
#  '照我以火',
#  '玛莉娅·临光',
#  '理想城：长夏狂欢季',
#  '生于黑夜',
#  '生路',
#  '画中人',
#  '登临意',
#  '空想花庭',
#  '绿野幻梦',
#  '落叶逐火',
#  '覆潮之下',
#  '遗尘漫步',
#  '银心湖列车',
#  '长夜临光',
#  '风雪过境',
#  '骑兵与猎人']

# %%
10-10_旧日之影_行动前
10-6_虽非同族_行动前
10-6_虽非同族_行动后
10-7_痛觉相连_行动前
10-8_无暇哀悼_行动后
10-9_他乡故知_行动前
10-9_他乡故知_行动后

# %%
temp_list = ['16_10-10_旧日之影_行动前.txt',
 '17_10-10_旧日之影_行动后.txt',
 '18_10-11_千疮百孔_行动前.txt',
 '19_10-12_仇怨的尽头_行动后.txt',
 '1_10-1_被追逐者.txt',
 '20_10-13_交叉路口.txt',
 '21_10-14_瞄准_行动前.txt',
 '22_10-14_瞄准_行动后.txt',
 '23_10-15_逃离炮火_行动前.txt',
 '24_10-16_血刃高悬_行动后.txt',
 '25_10-17_坚城高墙_行动前.txt',
 '26_10-17_坚城高墙_行动后.txt',
 '27_10-18_理想的倒影.txt',
 '28_10-19_远方星火.txt',
 '2_10-2_抢夺目标_行动前.txt',
 '3_10-2_抢夺目标_行动后.txt',
 '4_10-3_低下头_行动前.txt',
 '5_10-3_低下头_行动后.txt',
 '6_10-4_鸣铳示警_行动前.txt',
 '7_10-4_鸣铳示警_行动后.txt',
 '8_10-5_城市的呼吸_行动前.txt',
 '9_10-5_城市的呼吸_行动后.txt']

# %%
import os
path = './plot/主线/'
story_type = '主线'
stories = ["苦难摇篮", "靶向药物", "风暴瞭望", "黑暗时代·上", "黑暗时代·下"]
# for story in os.listdir(path):
# story = "破碎日冕"
for story in stories:
  for chapter in os.listdir(path + story):
  # for chapter in temp_list:
    if chapter.split(".")[-1] != "txt":
      continue
    process_raw_file(path, story, '.'.join(chapter.split(".")[:-1]), story_type)
# Out:
# {{剧情模拟器|图片数据={{Widget:Data_Image}}|角色数据={{Widget:Data_Char}}|音频数据={{Widget:Data_Audio}}|文本数据=
#
# [HEADER(key="title_test", is_skippable=true, fit_mode="BLACK_MASK")]
#
# [stopmusic]
#
# [Dialog]
#
# [Character]
#
# 时间不明
#
# [Dialog]
#
# [Character]
#
# [Blocker(a=1, r=0, g=0, b=0, fadetime=1, block=true)]
#
# [Background(image="bg_lungmen_o",screenadapt="coverall")]
#
# [Blocker(a=0, r=0, g=0, b=0, fadetime=1, block=true)]
#
# [playMusic(intro="$dignified_intro", key="$dignified_loop", volume=0.4)]
#
# [Character(name="char_2006_weiywfmzuki_1",fadetime=1,block=true)]
#
# [delay(time=1)]
#
# [name="文月"]
#
# [name="文月"]  ......
#
# [name="文月"]  不拉窗帘吗？
#
# [Character(name="char_2005_weiyw_1#5")]
#
# [name="魏彦吾"]  玻璃已经碎了。拉上窗帘只是欺骗自己。
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=1)]
#
# [name="文月"]  玻璃是小事，小陈她没事......才是大事。
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=2)]
#
# [name="魏彦吾"]  身手很好。既不像她父亲，也不像她母亲。
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=1)]
#
# [name="文月"]  是啊，不像她。
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=2)]
#
# [name="魏彦吾"]  ......
#
# [name="魏彦吾"]  我脚下已经又是一片灯火通明。龙门城已恢复了往日气象，可之后会发生什么，他们尚一无所知。
#
# [name="魏彦吾"]  这场灾难，陈晖洁一个人无法阻止。
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=1)]
#
# [name="文月"]  还有罗德岛和她一起。他们会找到她的。
#
# [name="文月"]  唉......
#
# [name="文月"]  维特已经钳制不住保守派了。这么多年来他努力压制各个大公，却也只能削弱他们，没法彻底打败他们。
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=2)]
#
# [name="魏彦吾"]  大叛乱之后，各集团军将领和旧贵族已经元气大伤，他们的地位和资源只会被帝国议会逐一消化。
#
# [name="魏彦吾"]  可我担心......
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=1)]
#
# [name="文月"]  担心什么？
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=2)]
#
# [name="魏彦吾"]  如果维特在说谎呢？如果这件事正是维特和帝国皇帝谋划的呢？如果那个年轻的皇帝策划了这一切呢？
#
# [name="魏彦吾"]  我们的敌人，一直身处暗处。我们却不得不站在最敞亮的地方。
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=1)]
#
# [name="文月"]  比起其他许多人，你已经在暗处了。
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=2)]
#
# [name="魏彦吾"]  ......还不够。就像当年一样。如果是科西切......如果是科西切，他会藏得更深。
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=1)]
#
# [name="文月"]  可你不是科西切。科西切不会把龙门建设成现在这样。
#
# [name="文月"]  只是，小塔......如果小塔真是被科西切教成这样的......
#
# [name="文月"]  ......
#
# [name="文月"]  你觉得，那个罗德岛的医生，她在说谎吗？
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=2)]
#
# [name="魏彦吾"]  我不清楚。像这个医生一样的人，很少有不说谎的。罗德岛善于掩藏自己。他们对我们示弱，不会透露一点秘密。
#
# [name="魏彦吾"]  但我宁可相信科西切塑造了现在的塔露拉。轻敌的恶果我们承担不起。
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=1)]
#
# [name="文月"]  ......小塔......
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=2)]
#
# [name="魏彦吾"]  也正因如此，我不能让陈晖洁去做这件事。
#
# [name="魏彦吾"]  科西切......事情正无疑向他期待的那样发展。即使他死了，他的愿景也可能被他的继承人塑造成型。
#
# [name="魏彦吾"]  这一切绝不能如他所愿。
#
# [name="魏彦吾"]  侦察队回报，一部分从龙门离开的感染者正往核心城的方向移动。
#
# [name="魏彦吾"]  核心城必须停靠一段时间，这时间里他们会接收感染者难民。
#
# [name="魏彦吾"]  纵使塔露拉露出了属于乌萨斯恶毒的尖牙，她也不会当着所有人的面背叛整合运动。这是最好的机会。
#
# [name="魏彦吾"]  我会带上影卫。
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=1)]
#
# [name="文月"]  你？！
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=2)]
#
# [name="魏彦吾"]  他们已经为我做得太多。
#
# [name="魏彦吾"]  我答应过他们，不会再让他们手沾血腥，之后却一次次地打破承诺。
#
# [name="魏彦吾"]  现在又要让他们再为龙门而死？
#
# [name="魏彦吾"]  ......那我也必与他们一同。
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=1)]
#
# [name="文月"]  不行。
#
# [name="文月"]  你这样做，也是科西切想看的。你这样根本不算赢。
#
# [name="文月"]  ......难道从我们夺回龙门开始，一切就滑向了科西切的陷阱吗？
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=2)]
#
# [name="魏彦吾"]  ......
#
# [name="魏彦吾"]  我们胜利过。
#
# [name="魏彦吾"]  最初是我们的胜利。即使惨痛，我、你、爱德华、舸瑞，没有我们，他将会把这座城市蚕食干净。
#
# [name="魏彦吾"]  我从来没有把这件事当成一个不幸的开始。
#
# [name="魏彦吾"]  ......我也不会把爱德华的死算在科西切的头上。
#
# [Character(name="char_2006_weiywfmzuki_1")]
#
# [name="文月"]  你想把它当一场噩梦吗？
#
# [stopmusic(fadetime=2)]
#
# [Dialog]
#
# [Blocker(a=1, r=0, g=0, b=0, fadetime=1, block=true)]
#
# [Character]
#
# [Image(image="avg_7_10",x=0, y=0, xScale=0.86, yScale=0.86, fadetime=0)]
#
# [Blocker(a=0, r=0, g=0, b=0, fadetime=3, block=false)]
#
# [playMusic(intro="$darkalley_intro", key="$darkalley_loop", volume=0.4)]
#
# [name="魏彦吾"]  不。
#
# [name="魏彦吾"]  噩梦在科西切死的时候就该结束了。
#
# [name="文月"]  他真的死了吗？
#
# [name="魏彦吾"]  也许他活在塔露拉的身上。一个合格的继承者能让他混沌的生命得到延续。
#
# [name="魏彦吾"]  塔露拉太像他了。没有子嗣的科西切得到了最适合的种子。
#
# [Dialog]
#
# [Blocker(a=1, r=0, g=0, b=0, fadetime=2, block=true)]
#
# [image]
#
# [Blocker(a=0, r=0, g=0, b=0, fadetime=2, block=true)]
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=2)]
#
# [name="魏彦吾"]  ......即使我可以把凯尔希的话当成谎言，我也无法否认事实。那就是针对龙门的阴谋，实在是太像科西切的手笔了。
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=1)]
#
# [name="文月"]  我不相信。小塔从来都不是那种人。她为什么要这么做？
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=2)]
#
# [name="魏彦吾"]  你我现在不得不信。这一切都是塔露拉一手策划。
#
# [name="魏彦吾"]  可如果她要觉得龙门会坐以待毙，她就大错特错。
#
# [name="魏彦吾"]  龙门不会失败。我不会让龙门受到丁点伤害。
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=1)]
#
# [name="文月"]  却也不能阻止战争。
#
# [name="文月"]  ......你想让我与你共死吗？
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=2)]
#
# [name="魏彦吾"]  文月？！
#
# [name="魏彦吾"]  ——你在威胁我？
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=1)]
#
# [name="文月"]  唉哟。不是。哎我不是这个意思。我是说......
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=2)]
#
# [name="魏彦吾"]  不！绝不。
#
# [name="魏彦吾"]  ......懦夫才要搭上别人的性命。
#
# [name="魏彦吾"]  何况是你！我不可能.....
#
# [name="魏彦吾"]  也许我曾懦弱过，但是，不，文月。
#
# [name="魏彦吾"]  我不允许任何人动你。
#
# [name="魏彦吾"]  我会把你藏起来。无论是莱塔尼亚还是萨尔贡，萨米......
#
# [name="魏彦吾"]  你不能回东国，我把你送到遥远的国家去，送到那些没有人知道的宁静的小城去。
#
# [name="魏彦吾"]  我会把你藏在无人知晓的地方。胞弟......他再怎么恨我也不会追杀你到那么远的地方......他不会。对，他不会。
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=1)]
#
# [name="文月"]  可我也活不了。
#
# [name="文月"]  你要我一个人独活吗，彦吾？
#
# [name="文月"]  你想用你的死来折磨我吗？你难道不记得你的妹妹是为什么在忧郁中死去吗？
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=2)]
#
# [name="魏彦吾"]  不，不......文月，不，我想你活着。我......
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=1)]
#
# [name="文月"]  魏彦吾，我是说......我可以的。
#
# [name="文月"]  和你一起死，已经是我能想象到的糟糕结局里最好的一种。或者，它尽管很糟糕，对我来说，也是好结局。
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=2)]
#
# [name="魏彦吾"]  文月，不......
#
# [name="魏彦吾"]  我不会做这种人。我也不许你这么做。
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=1)]
#
# [name="文月"]  但你知道，你拦不住我的。我要做什么，你从来没拦住过我。
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=2)]
#
# [name="魏彦吾"]  文月......！
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=1)]
#
# [name="文月"]  彦吾，你一直对我说真心话的。你有时候会什么都不说，但你只要说了，我知道你只会对我说真心话。
#
# [name="文月"]  我不想你死。我也不想小塔死。我不想我们里任何一个人死。
#
# [name="文月"]  我想小塔了，她的面相和你的妹妹是那么像，但她的眼睛又像爱德华，小时候那脾气也不知道像谁......这么多年了，我这么多年没见她了。
#
# [name="文月"]  这一切是我们欠她的。
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=2)]
#
# [name="魏彦吾"]  ......还有晖洁。
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=1)]
#
# [name="文月"]  对。还有小陈。
#
# [name="文月"]  小陈已经走了，我以后再也看不见她，再也没法给她买漂亮的衣服，给她梳些适合她的发型了。
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=2)]
#
# [name="魏彦吾"]  她......她没那么喜欢传统的打扮。
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=1)]
#
# [name="文月"]  可是我喜欢啊。那有多漂亮，她会有多漂亮啊。
#
# [name="文月"]  ......可我还是想，哪怕这样，哪怕是就此永别，我也希望小陈在另一个地方好好活着，好好地活着。我就这么想。
#
# [name="文月"]  我知道你不想倚仗罗德岛，也清楚你不会把宝全部押在他们身上。
#
# [name="文月"]  但我想你等上一等。
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=2)]
#
# [name="魏彦吾"]  ......
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=1)]
#
# [name="文月"]  让他们去做吧，彦吾。
#
# [name="文月"]  如果他们没做到，我们再一起去。你不想再沾上亲人的血了吧？
#
# [name="文月"]  那我来帮你取走小塔的性命。然后我再和你共死。
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=2)]
#
# [name="魏彦吾"]  文月......！
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=1)]
#
# [name="文月"]  你也更想她也活着吧？这座龙门城，难道是想我们所有人都去死吗？
#
# [name="文月"]  我宁可再也见不到她们了。我宁可永远看不到小陈和小塔，把她们都忘了......我也想她们活着。
#
# [name="文月"]  就像你一样。就像你也希望我这么选一样。
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=2)]
#
# [name="魏彦吾"]  文月。一旦事情陷入不可回转的境地，你必须听我的安排。我们的生命......不是不可分割的。
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=1)]
#
# [name="文月"]  当然不是。彦吾，我并不只是为了你才站在这里的。
#
# [name="文月"]  ......我所做的一切，从头至尾，也不全是为了你。
#
# [name="文月"]  你要看到我在坚持什么。
#
# [name="文月"]  别再躲躲闪闪了。看着我。
#
# [Character(name="char_2006_weiywfmzuki_1",name2="char_2005_weiyw_1#5",focus=2)]
#
# [name="魏彦吾"]  ......
#
# [name="魏彦吾"]  我会坚持自己的决定......
#
# [Character(name="char_2006_weiywfmzuki_1")]
#
# [name="文月"]  你想哭吗？
#
# [Character(name="char_2005_weiyw_1#5")]
#
# [name="魏彦吾"]  ......
#
# [Character(name="char_2006_weiywfmzuki_1")]
#
# [name="文月"]  要哭吗，彦吾？
#
# [Character(name="char_2005_weiyw_1#5")]
#
# [name="魏彦吾"]  不。不，文月。
#
# [name="魏彦吾"]  ......不。
#
# [Character(name="char_2006_weiywfmzuki_1")]
#
# [name="文月"]  说真心话。
#
# [Character(name="char_2005_weiyw_1#5")]
#
# [name="魏彦吾"]  ......
#
# [Character]
#
# [Dialog]
#
# [Blocker(a=0.5, r=0, g=0, b=0, fadetime=1, block=true)]
#
# 只是想在一座城市里休养生息的人，凭什么要遭遇无谓的死亡？
#
# 我们不就只是想给他们一个家？我们不是想让所有和我们一样无处可去的人，有一个温暖的地方可以歇脚？
#
# 我不就只是想建一座小城，一座能够让所有人安心住下的小城？
#
# 现在这龙门城，又是为谁而建？
#
# [Blocker(a=0, r=0, g=0, b=0, fadetime=2, block=true)]
#
# [Character(name="char_2005_weiyw_1#5")]
#
# [name="魏彦吾"]  我不是个道德家。但文月，我细细看来，该死的还是只有一个人。
#
# [name="魏彦吾"]  ——我。
#
# [Character(name="char_2006_weiywfmzuki_1")]
#
# [name="文月"]  ......不要这样......别这样！
#
# [Character(name="char_2005_weiyw_1#5")]
#
# [name="魏彦吾"]  我会让影卫送你去萨尔贡。
#
# [Character]
#
# [Dialog]
#
# [Blocker(a=1, r=0, g=0, b=0, fadetime=1, block=true)]
#
# 龙门是什么时候变成这样？
#
# 我是究竟什么时候，变成了现在这样？
#
# [Dialog]
#
# [Blocker(fadetime=1,block=true)]
#
# [Image]
#
# }}
#
# {{剧情导航}}
#
# {{剧情模拟器|图片数据={{Widget:Data_Image}}|角色数据={{Widget:Data_Char}}|音频数据={{Widget:Data_Audio}}|文本数据=
#
# [HEADER(key="title_test", is_skippable=true, fit_mode="BLACK_MASK")]
#
# [stopmusic]
#
# [Dialog]
#
# [Delay(time=1)]
#
# [Character]
#
# [Blocker(fadetime=1,block=true)]
#
# 11:30 a.m.
#
# [Dialog]
#
# [Character]
#
# [Blocker(a=1, r=0, g=0, b=0, fadetime=1, block=true)]
#
# [Background(image="bg_perimeter",screenadapt="coverall")]
#
# [Blocker(a=0, r=0, g=0, b=0, fadetime=1, block=true)]
#
# [playMusic(intro="$darkness02_intro", key="$darkness02_loop", volume=0.4)]
#
# [Character(name="avg_npc_016",name2="avg_npc_016")]
#
# [name="幻影弩手"]  领袖。
#
# [Dialog]
#
# [Character]
#
# [PlaySound(key="$d_gen_walk_n")]
#
# [Character(name="char_011_talula_1",fadetime=1,block=true)]
#
# [delay(time=1)]
#
# [name="塔露拉"]  幻影弩手们。很高兴见到你们平安归来。
#
# [name="塔露拉"]  你们的队伍很浩大。他们都是龙门的同胞？
#
# [Character(name="avg_npc_016",name2="char_011_talula_1",focus=1)]
#
# [name="幻影弩手"]  有许多感染者......和我们一起回来。
#
# [name="幻影弩手"]  没想到会在这里遇到你们。
#
# [Character(name="avg_npc_016",name2="char_011_talula_1",focus=2)]
#
# [name="塔露拉"]  充分利用切尔诺伯格的资源，能拯救许多人。这座核心城将是我们攻破龙门的利器。
#
# [Character(name="avg_npc_016",name2="char_011_talula_1",focus=1)]
#
# [name="幻影弩手"]  什么？不，不对，领袖......
#
# [name="幻影弩手"]  为什么龙门的情况和计划里说的完全不一样？我们多少战友平白无故地在那里送了命！
#
# [Character(name="avg_npc_016",name2="char_1002_nsabr_1",focus=2)]
#
# [name="整合运动成员"]  你怎么敢这样对领袖......
#
# [Character(name="avg_npc_016",name2="char_011_talula_1",focus=2)]
#
# [name="塔露拉"]  不。他说得对。
#
# [name="塔露拉"]  我们可敬的同胞们已经受了太多的苦。我们的作战计划也因为敌人奸诈的圈套，受到了很大的挫折。
#
# [name="塔露拉"]  不过，即使我们的先锋遭遇了一时的阻碍，整合运动却还依然有为你们报仇的决心。你们的创伤，你们的牺牲，我会为你们讨回。
#
# [name="塔露拉"]  请放心，我一直与你们在一起。
#
# [Character(name="avg_npc_016",name2="char_011_talula_1",focus=1)]
#
# [name="幻影弩手"]  ......希望是这样，领袖。
#
# [Character(name="avg_npc_016",name2="char_011_talula_1",focus=2)]
#
# [name="塔露拉"]  嗯，你背着的怎么是......梅菲斯特？他没有......
#
# [name="塔露拉"]  ......
#
# [name="塔露拉"]  浮士德是不是为了救他牺牲了自己？
#
# [Character(name="avg_npc_016",name2="char_011_talula_1",focus=1)]
#
# [name="幻影弩手"]  ......确实如此，领袖。浮士德不顾自己的命，用法术掩盖了我们所有人的踪迹，把逃出来的机会......让给了我们。
#
# [Character(name="avg_npc_016",name2="char_011_talula_1",focus=2)]
#
# [name="塔露拉"]  哦？
#
# [name="塔露拉"]  ......
#
# [name="塔露拉"]  幻影弩手们，整合运动的同胞们......我们会永远怀念浮士德。
#
# [name="塔露拉"]  扶他下去吧。梅菲斯特也许需要一点时间去休息。
#
# [name="塔露拉"]  我会让战士们领你们去现在的驻地。
#
# [Character(name="avg_npc_016",name2="char_011_talula_1",focus=1)]
#
# [name="幻影弩手"]  还有，领袖......我们很早就失去了弑君者的消息，我们不确定她的下落。
#
# [name="幻影弩手"]  至于......雪怪小队，以及霜星小姐，他们都......都......
#
# [Character(name="char_011_talula_1")]
#
# [name="塔露拉"]  ——
#
# [name="塔露拉"]  真是无比令人沉痛的消息。
#
# [name="塔露拉"]  请允许我......独处一小会儿。
#
# [Dialog]
#
# [Character]
#
# [Blocker(a=1, r=0, g=0, b=0, fadetime=1, block=true)]
#
# [Background(image="bg_perimeter",screenadapt="coverall")]
#
# [PlaySound(key="$d_gen_walk_n", volume=1)]
#
# [Blocker(a=0, r=0, g=0, b=0, fadetime=1, block=true)]
#
# [Delay(time=1)]
#
# [Character(name="char_011_talula_1")]
#
# [name="塔露拉"]  ......
#
# [name="塔露拉"]  萨卡兹。不要让他们和任何城内的整合运动成员接触。
#
# [Character(name="avg_npc_053")]
#
# [name="萨卡兹战士"]  做到哪一步？
#
# [Character(name="char_011_talula_1")]
#
# [name="塔露拉"]  最后一步。永远不要。
#
# [Dialog]
#
# [Blocker(a=1, r=0, g=0, b=0, fadetime=1, block=true)]
#
# [Character]
#
# [Background(image="bg_black",screenadapt="coverall")]
#
# [Blocker(a=0, r=0, g=0, b=0, fadetime=1, block=true)]
#
# [Character(name="char_011_talula_1",fadetime=1,block=true)]
#
# [delay(time=1)]
#
# [name="塔露拉"]  是刻意隐瞒，还是钻研得出了成果？他的小队竟然知道我不了解的信息。
#
# [name="塔露拉"]  也许......是在战斗中有了成长。这样的法术已经超乎寻常，而他对我守口如瓶。
#
# [name="塔露拉"]  ......沉默寡言竟然成了伪装的外皮。本以为存活的会是浮士德。
#
# [name="塔露拉"]  如果是这样，那也就不奇怪了。
#
# [stopmusic(fadetime=2)]
#
# [Dialog]
#
# [Blocker(a=1, r=0, g=0, b=0, fadetime=2, block=true)]
#
# [Character]
#
# [Background(image="bg_cherbefore_1",screenadapt="coverall")]
#
# [cameraEffect(effect="Grayscale", keep=true, amount=1, fadetime=0)]
#
# [Blocker(a=0, r=0, g=0, b=0, fadetime=2, block=true)]
#
# [playMusic(intro="$loneliness_intro", key="$loneliness_loop", volume=0.4)]
#
# [name="？？？"]  ......你是谁？
#
# 我是谁？
#
# [name="？？？"]  你想做什么？
#
# 我想做什么......？
#
# [name="？？？"]  加入......你们？为了自己去斗争？
#
# 斗争......？
#
# [name="塔露拉"]  呵，崇高的乌萨斯人啊。
#
# [name="塔露拉"]  原本你们才是应该走到最后的人。
#
# [Dialog]
#
# [stopmusic(fadetime=2)]
#
# [Blocker(a=1, r=0, g=0, b=0, fadetime=2, block=true)]
#
# [Character]
#
# [cameraEffect(effect="Grayscale", keep=true, amount=0, fadetime=0)]
#
# [Background(image="bg_cherunder",screenadapt="coverall")]
#
# [Blocker(a=0, r=0, g=0, b=0, fadetime=2, block=true)]
#
# [playMusic(intro="$batmeeting_intro", key="$batmeeting_loop", volume=0.4)]
#
# [Character(name="char_002_amiya_1",fadetime=1,block=true)]
#
# [delay(time=1)]
#
# [name="阿米娅"]  核心城似乎恢复速度了，停驻的时间不长。
#
# [name="阿米娅"]  往好的方向想，整合运动应该还是接收了一部分从龙门迁移出来的感染者。希望如此......
#
# [Character(name="char_003_kalts_1")]
#
# [name="凯尔希"]  但我们也可能被迫改变策略。
#
# [name="凯尔希"]  可预见的是，核心城还会在路途中停留几次，直到敌人的指挥官不再打算掩盖自己的动机，拒绝感染者难民为止。
#
# [name="凯尔希"]  如果魏彦吾选择类似的时机展开进攻，敌人会改变现有防卫力量的布置，我们很可能会因此暴露位置，成为众矢之的。
#
# [Character(name="char_003_kalts_1",name2="char_002_amiya_1",focus=2)]
#
# [name="阿米娅"]  希望那个协定起码能让文月小姐把魏长官拖上一会儿......
#
# [name="阿米娅"]  嗯......我们已经相当接近核心城的中央区了。
#
# [name="阿米娅"]  大量在地下与地面上穿行的通道，似乎原本是核心城的资源输送系统的一部分。天灾过后，所有工业设施都停止了运作。
#
# [name="阿米娅"]  在这种情况下，核心城居然还能运作，甚至移动......这和凯尔希医生说的地下设施有关吗？
#
# [name="阿米娅"]  无论如何，穿梭通道为我们提供了良好的隐蔽。在这个接近中央区的仓储区域内，敌人的守卫数量已经增加了近一倍......
#
# [name="阿米娅"]  进入核心城以来，我们还没有遭遇太多火力冲突。但在踏入中央区之后，我们与整合运动摩擦、甚至交战的次数，应该会急剧增加。
#
# [Character(name="char_003_kalts_1")]
#
# [name="凯尔希"]  侦察小队与行动小队已经先我们一步到位。迄今为止都很顺利。
#
# [Decision(options="我们怎么只有三支小队共同行动？", values="1")]
#
# [Predicate(references="1")]
#
# [Character(name="char_003_kalts_1")]
#
# [name="凯尔希"]  侦察小队和特别行动小队有他们各自的任务。
#
# [name="凯尔希"]  作为罗德岛的通讯专家之一，Raidian在这次行动中领导侦察小队。
#
# [name="凯尔希"]  依靠Raidian，侦察小队在核心城作战中发挥着通讯中继点的作用。
#
# [name="凯尔希"]  即使在这里，我们也能与其他队伍交流，这全部仰赖这支小队的努力。
#
# [Decision(options="我没看见他们......", values="1")]
#
# [Predicate(references="1")]
#
# [name="凯尔希"]  侦察小队从来都独来独往。
#
# [name="凯尔希"]  Outcast，Raidian，以及在切城营救行动中英勇牺牲的Scout——
#
# [name="凯尔希"]  担任侦察小队队长的精英干员们，担负着独自领导一支小队，发现危机，报告危机，以及尝试独自处理危机的职责。
#
# [name="凯尔希"]  Raidian不像刚才提到的另两位精英干员那样擅长战斗，但在影响战局的层面上，却可以称作是在罗德岛屈指可数的人才。
#
# [name="凯尔希"]  这一次的攻击任务由我们这三支队伍承担，Raidian不必再承担繁重的战斗事务。
#
# [name="凯尔希"]  至于特别小队，他们的任务与正面作战无关。
#
# [Decision(options="和我说说。;......;所以你不准备告诉我？", values="1;2;3")]
#
# [Predicate(references="1;2;3")]
#
# [name="凯尔希"]  知道有其必要即可。更多细节你之后自然会明白。
#
# [name="凯尔希"]  不同的小队是战略计划链条上不同的环节，稳固的结构输出稳定的结果。
#
# [name="凯尔希"]  相应的，强韧的敌手也一样有着错综复杂的根部，它会从各个不同的层面吸取养分，砍掉枝条对他们并无威胁。
#
# [name="凯尔希"]  我们要做的是在暗处引燃敌人根基。
#
# [Decision(options="啊？你说什么？;......;我似乎明白了。", values="1;2;3")]
#
# [Predicate(references="1;2;3")]
#
# [name="凯尔希"]  呵。理应不存在你不能理解的事情......
#
# [name="凯尔希"]  “博士”。
#
# [Dialog]
#
# [Character]
#
# [stopmusic(fadetime=2)]
#
# [delay(time=2)]
#
# [Character(name="avg_npc_042",fadetime=1,block=true)]
#
# [delay(time=1)]
#
# [name="迷迭香"]  等一等。
#
# [name="迷迭香"]  远处有几个很模糊的感觉。
#
# [name="迷迭香"]  很整齐，流向没有变化，没有相互冲突。
#
# [name="迷迭香"]  ......很硬。在移动。
#
# [playMusic(intro="$mist_intro", key="$mist_loop", volume=0.4)]
#
# [Character(name="char_002_amiya_1#7")]
#
# [name="阿米娅"]  整合运动的......守卫部队。先避开他们，寻找其他可以通过的道路......
#
# [name="阿米娅"]  事不宜迟。
#
# [Character(name="char_003_kalts_1")]
#
# [name="凯尔希"]  ——阿米娅。
#
# [Character(name="char_003_kalts_1",name2="char_002_amiya_1",focus=2)]
#
# [name="阿米娅"]  医生？
#
# [Character(name="char_003_kalts_1",name2="char_002_amiya_1",focus=1)]
#
# [name="凯尔希"]  慎重。你没有感受到吗？
#
# [Character(name="char_003_kalts_1")]
#
# [name="凯尔希"]  诸位干员......戴上防护装置。
#
# [Character(name="char_002_amiya_1#7")]
#
# [name="阿米娅"]  ......难道......迷迭香？你有察觉到什么异常吗？
#
# [Character(name="char_002_amiya_1#7",name2="avg_npc_042",focus=2)]
#
# [name="迷迭香"]  唔？......没有吧。我想。
#
# [Character(name="char_003_kalts_1")]
#
# [name="凯尔希"]  那不是迷迭香源石技艺作用的范畴。
#
# [name="凯尔希"]  不要完全依赖情感，阿米娅。知觉不仅能摸索到感情，手指划过发丝，第一感觉不应该是留恋或者喜悦。表象。
#
# [Character(name="char_003_kalts_1",name2="char_002_amiya_1",focus=2)]
#
# [name="阿米娅"]  表象......？
#
# [Character(name="char_003_kalts_1",name2="char_002_amiya_1",focus=1)]
#
# [name="凯尔希"]  阿米娅，你可以从深色的内里回到表象。只有你才能。
#
# [Character(name="char_003_kalts_1",name2="char_002_amiya_1",focus=2)]
#
# [name="阿米娅"]  那我就按医生说的，试一试。
#
# [Dialog]
#
# [Character(name="char_002_amiya_1#7")]
#
# [delay(time=1)]
#
# [Character(name="char_002_amiya_1#7")]
#
# [name="阿米娅"]  唔......好像有一丝......能量。空气中弥漫着一种气味，像是......
#
# [name="阿米娅"]  ......尸体？
#
# [name="阿米娅"]  不，这不是现实的尸体，难道......不。啊？为什么......
#
# [name="阿米娅"]  ......是萨卡兹。是萨卡兹的源石技艺。蕴含死亡气味的......仪......式？
#
# [Character(name="char_003_kalts_1")]
#
# [name="凯尔希"]  成型后自运行的古老仪式。
#
# [name="凯尔希"]  ——这不是现代的法术，更不属于现代战术。
#
# [Decision(options="萨卡兹的法术很不同？", values="1")]
#
# [Predicate(references="1")]
#
# [Character(name="char_002_amiya_1#7")]
#
# [name="阿米娅"]  是的。这很不一般。现在的萨卡兹人没法推动这种法术的运行。
#
# [name="阿米娅"]  我明白凯尔希医生的意思。我想，这不是在现代成型的源石技艺理论的产物。这是古老的萨卡兹仪式。
#
# [Character(name="char_003_kalts_1")]
#
# [name="凯尔希"]  敌人可能是最“纯正”的萨卡兹。这种现代国家不可能使用的技术，只在古老的萨卡兹与散漫的萨尔贡古人间流传。
#
# [Character(name="char_002_amiya_1#7")]
#
# [name="阿米娅"]  ......这是依托于矿石病感染，以及施术者对源石的异样理解来施行的仪式。
#
# [name="阿米娅"]  杂乱的能量正自源石核心处向外渗透、漫溢出去，笼罩在这个街区。
#
# [name="阿米娅"]  难以想像仪式源头高浓度的法术漩涡会对生物产生多大影响。
#
# [name="阿米娅"]  无论是对自己还是对敌人......生命活动的迹象都会被能量波逐渐曳离。
#
# [name="阿米娅"]  这并不符合现代战术的需求，带来的损失有时候会比可能取得的战果还大。
#
# [Character(name="char_003_kalts_1")]
#
# [name="凯尔希"]  “食人”。
#
# [name="凯尔希"]  这个说法耸人听闻，只是，这个仪式确实被这样称呼过。
#
# [name="凯尔希"]  参照它可怖的杀伤力和不谙内情者将之称为“巫术”的行为，把发生装置叫作祭坛，也不奇怪。
#
# [Character(name="char_002_amiya_1#7")]
#
# [name="阿米娅"]  我......我不觉得普通的萨卡兹雇佣兵能使用这种法术。
#
# [name="阿米娅"]  只有在卡兹戴尔汲取法术知识和战争经验的人，才有可能成功施行这种仪式，实施者甚至不用是个术师。
#
# [name="阿米娅"]  但他......他只会是卡兹戴尔的萨卡兹，而不是流浪在大地各处的萨卡兹后裔。
#
# [name="阿米娅"]  ......凯尔希医生，第二套防护装置，是不是设计来抵消这种萨卡兹法术的影响的？
#
# [Character(name="char_003_kalts_1",name2="char_002_amiya_1#7",focus=1)]
#
# [name="凯尔希"]  不完全是。仪式蕴含的能量远超我们设计所能承受的最大限度。
#
# [name="凯尔希"]  正是在这片遭天灾洗劫的城市上，这种仪式才能顺利运行。
#
# [name="凯尔希"]  我们的防护不能抵消敌人仪式的影响，这个法术的威力与它的古老程度无法分割。
#
# [name="凯尔希"]  我们只能稍微削减它的杀伤力，在扫清整片区域后破坏它。
#
# [name="凯尔希"]  萨卡兹的仪式往往不只是在挑战一种现代技术。
#
# [name="凯尔希"]  它几乎是要重新挑战这片大地上的其它文明，就像历史上萨卡兹们谋划过的一样。
#
# [Decision(options="这是个比喻。", values="1")]
#
# [Predicate(references="1")]
#
# [Character(name="char_003_kalts_1")]
#
# [name="凯尔希"]  是。但萨卡兹的历史不是比喻。
#
# [name="凯尔希"]  守卫切尔诺伯格核心城不只是普通的整合运动，这点我已经和你讨论过了。
#
# [name="凯尔希"]  也许整合运动确实依靠“神经网络”中的各个“中枢”来进行大规模的整体运作。
#
# [name="凯尔希"]  但是在如今这种纯粹的推进战略中，整合运动将一反常态。
#
# [name="凯尔希"]  想想看，如果是不擅长对抗感染者的士兵，不知道如何与萨卡兹战斗的现代武装进入了核心城......
#
# [name="凯尔希"]  他们将在这里惨败。
#
# [Character(name="char_002_amiya_1#7")]
#
# [name="阿米娅"]  ......明白。
#
# [name="阿米娅"]  那么......我想一想......
#
# [name="阿米娅"]  ......Dr.{@nickname}，凯尔希医生。
#
# [name="阿米娅"]  敌人施行萨卡兹法术的位置，一定是重要据点，或是交通要道的枢纽处。
#
# [name="阿米娅"]  他们比我们更熟悉这片区域，所有我们可通行的路径，他们会比我们更早发现......他们的布防一定早于我们的行动。
#
# [name="阿米娅"]  我们拥有的唯一优势，就是情报。我们已经了解了敌人的分布，敌人却对我们一无所知。
#
# [name="阿米娅"]  ......所以我们要迅速击溃据守在这片区域里的敌人。用时越少，我们越安全。不要让他们有联系其他守卫的机会。
#
# [name="阿米娅"]  放弃伏击敌人的想法。我们不能在这里浪费过多时间。
#
# [Character(name="char_003_kalts_1", name2="char_002_amiya_1#7", focus=1)]
#
# [name="凯尔希"]  可以，我会帮助你们进行突袭。
#
# [Character(name="char_003_kalts_1", name2="char_002_amiya_1", focus=2)]
#
# [name="阿米娅"]  唔，嗯......我想......
#
# [name="阿米娅"]  医生，你看，我想，如果是......
#
# [Character(name="char_003_kalts_1")]
#
# [name="凯尔希"]  ——好的。
#
# [name="凯尔希"]  如果你们不需要我的协助，Dr.{@nickname}。
#
# [Decision(options="嗯？;......;有什么我能帮上忙的？", values="1;2;3")]
#
# [Predicate(references="1;2;3")]
#
# [Character(name="char_003_kalts_1")]
#
# [name="凯尔希"]  请你帮助阿米娅指挥。
#
# [name="凯尔希"]  战况就由你们自己判断。
#
# [Character(name="char_003_kalts_1", name2="char_002_amiya_1#7", focus=2)]
#
# [name="阿米娅"]  明白！
#
# [Character(name="char_003_kalts_1", name2="char_002_amiya_1", focus=2)]
#
# [name="阿米娅"]  迷迭香，我们行动！
#
# [Character(name="char_002_amiya_1#3")]
#
# [name="阿米娅"]  在这次战斗之后，我们就要彻底离开穿梭区域，完全抵达核心城地表了！
#
# [name="阿米娅"]  迷迭香......至少有阳光了。
#
# [Character(name="avg_npc_042")]
#
# [name="迷迭香"]  阳光~
#
# [Dialog]
#
# [Character]
#
# [PlaySound(key="$rungeneral", volume=0.9)]
#
# [Delay(time=2)]
#
# [Character(name="char_003_kalts_1")]
#
# [name="凯尔希"]  （......）
#
# [name="凯尔希"]  （呵，看她们的样子。）
#
# [name="凯尔希"]  （接下来就交给你了，Dr.{@nickname}。我知道，你绝不让人失望。）
#
# [stopmusic(fadetime=2)]
#
# [Dialog]
#
# [Character]
#
# [Blocker(a=1, r=0, g=0, b=0, fadetime=2, block=true)]
#
# 凯尔希，让人失望的事情是不会再次发生的。
#
# 同样的河流我们没法踏入第二次。同样的事情也不会发生第二次。
#
# 如果是相同的人，相同的事......在不同的时代里，一定会有不一样的结果。这片大地......会被改变。
#
# 你不相信，对吗？
#
# 嗯......你不相信，也是应该的。
#
# 但我很相信。Dr.{@nickname}，这样一个人......我知道......如果不是现在，Dr.{@nickname}不会这样。
#
# 我看过那么多，见过那么多......哪怕所有人都拒绝，我也能理解。
#
# 凯尔希......凯尔希。
#
# 如果......再给我们一点时间......我和你......
#
# [Dialog]
#
# [delay(time=2)]
#
# [name="凯尔希"]  （你能证明自己不是流连于过往的Dr.{@nickname}。）
#
# [name="凯尔希"]  （如果是现在......）
#
# [name="凯尔希"]  （无论哪个层面，Dr.{@nickname}。你必须能。）
#
# [Dialog]
#
# [Blocker(fadetime=2,block=true)]
#
# [Image]
#
# }}
#
# {{剧情导航}}
#
# {{剧情模拟器|图片数据={{Widget:Data_Image}}|角色数据={{Widget:Data_Char}}|音频数据={{Widget:Data_Audio}}|文本数据=
#
# [HEADER(key="title_test", is_skippable=true, fit_mode="BLACK_MASK")]
#
# [stopmusic]
#
# [Dialog]
#
# [Delay(time=1)]
#
# [Character]
#
# [Blocker(fadetime=1,block=true)]
#
# [Dialog(fadetime=2,block=true)]
#
# 切尔诺伯格仓库  12:40  a.m.
#
# [Dialog]
#
# [Character]
#
# [PlaySound(key="$d_gen_soldiersrun",volume=0.5)]
#
# [playMusic(intro="$darkness02_intro", key="$darkness02_loop", volume=0.4)]
#
# [Blocker(a=1, r=0, g=0, b=0, fadetime=1, block=true)]
#
# [Background(image="bg_warehouse",screenadapt="coverall")]
#
# [Blocker(a=0, r=0, g=0, b=0, fadetime=3, block=true)]
#
# [Character(name="char_002_amiya_1")]
#
# [name="阿米娅"]  大量的仓库和储存设备......这里应该是仓库区。
#
# [name="阿米娅"]  循着这条路，我们就可以直达中央区。
#
# [Character(name="avg_npc_012")]
#
# [name="罗德岛干员"]  阿米娅！过来看看。仓库里面。
#
# [Character(name="char_002_amiya_1#7")]
#
# [name="阿米娅"]  这是......啊。
#
# [Character(name="avg_npc_012")]
#
# [name="罗德岛干员"]  尖锐的刃形法术和打斗痕迹。迅速解决了两三个整合运动，都被丢在这边了。
#
# [Character(name="char_002_amiya_1")]
#
# [name="阿米娅"]  ......还有气。
#
# [name="阿米娅"]  凯尔希医生！
#
# [name="阿米娅"]  嗯，拜托你和医疗干员。这几个整合运动也许有我们需要的信息。
#
# [name="阿米娅"]  这里也能看到陈长官的痕迹......
#
# [Dialog]
#
# [Blocker(a=1, r=0, g=0, b=0, fadetime=1, block=true)]
#
# [Character]
#
# [Image(image="avg_7_11",x=0, y=0, xScale=0.86, yScale=0.86, fadetime=0)]
#
# [Blocker(a=0, r=0, g=0, b=0, fadetime=1, block=true)]
#
# [name="阿米娅"]  是血迹。她受了伤。
#
# [name="阿米娅"]  在这里，血迹在这里有沉积，但只到这里为止。她给自己止了血。
#
# [name="阿米娅"]  离开现场的只有一个人，只可能是陈长官了。
#
# [Dialog]
#
# [Blocker(a=1, r=0, g=0, b=0, fadetime=1, block=true)]
#
# [image]
#
# [Background(image="bg_warehouse",screenadapt="coverall")]
#
# [Blocker(a=0, r=0, g=0, b=0, fadetime=2, block=true)]
#
# [Character(name="char_002_amiya_1")]
#
# [name="阿米娅"]  ......千万要撑到我们来，陈长官......
#
# [Decision(options="又要我们做这事儿？;......;怎么感觉以前也发生过。", values="1;2;3")]
#
# [Predicate(references="1;2;3")]
#
# [Character(name="char_002_amiya_1")]
#
# [name="阿米娅"]  哈哈......在切城时，嗯，也是这样。
#
# [name="阿米娅"]  只不过那时候，陈长官可以一人处理一支松散的整合运动小队......
#
# [name="阿米娅"]  但现在的形势已经完全不同了。
#
# [name="阿米娅"]  那时我们还只是单纯的合作关系。我只是刚刚开始了解陈长官是怎样的一个人......
#
# [name="阿米娅"]  但这里已经是......
#
# [stopmusic(fadetime=2)]
#
# [Dialog]
#
# [Character]
#
# [Character(name="avg_npc_057",fadetime=1,block=true)]
#
# [delay(time=2)]
#
# [Character(name="char_002_amiya_1")]
#
# [name="阿米娅"]  那是......平民？
#
# [playMusic(intro="$plot_intro", key="$plot_loop", volume=0.4)]
#
# [Character(name="avg_npc_012")]
#
# [name="罗德岛干员"]  ......哪里出来的？我们居然没找到他们的藏身处......
#
# [Character(name="avg_npc_057")]
#
# [name="？？？"]  这里是乌萨斯人的坟场！
#
# [Character(name="char_002_amiya_1#7")]
#
# [name="阿米娅"]  ！
#
# [name="阿米娅"]  （保持戒备......但别攻击！）
#
# [Character(name="char_002_amiya_1")]
#
# [name="阿米娅"]  我们是中立的感染者查验组织！女士，我们是本着为你们提供救助的原则进入这座城市的！
#
# [name="阿米娅"]  作为普通感染者，我们对你没有敌意——
#
# [Character(name="char_002_amiya_1",name2="avg_npc_057",focus=2)]
#
# [name="？？？"]  感染者？呿，我是乌萨斯人！
#
# [name="乌萨斯感染者"]  救助感染者......？！哈，笑话......你们感染者对我们做了什么，你们自己难道不清楚吗？
#
# [Character(name="char_002_amiya_1#4",name2="avg_npc_057",focus=1)]
#
# [name="阿米娅"]  ......
#
# [name="阿米娅"]  女士，如果你感到不安全，我们就保持现在这个距离。二十米的距离。我们不会再移动。
#
# [Character(name="char_002_amiya_1#4",name2="avg_npc_057",focus=2)]
#
# [name="乌萨斯感染者"]  不，不对，我也是感染者了。我骂不了你，是不是？
#
# [name="乌萨斯感染者"]  你们还救助感染者？！呵呵，呵呵呵......所有感染者都该死！
#
# [name="乌萨斯感染者"]  我也该死。我也该死！没有感染者，我根本不会染病！
#
# [name="乌萨斯感染者"]  想着害人，想着报复......感染者就是这样吗？！我也该这样吗？！
#
# [Character(name="avg_npc_042",name2="char_002_amiya_1#4",focus=1)]
#
# [name="迷迭香"]  ......
#
# [name="迷迭香"]  （阿米娅，安抚她，好吗？）
#
# [Character(name="avg_npc_042",name2="char_002_amiya_1#4",focus=2)]
#
# [name="阿米娅"]  （不，现在不好。）
#
# [name="阿米娅"]  （......让她先发泄吧。一个月来所有的惨痛回忆都刺在她的意识里。）
#
# [name="阿米娅"]  （现在也是她......直面这些事，把这些事都拔出来的机会。）
#
# [Character(name="avg_npc_057")]
#
# [name="乌萨斯感染者"]  ......
#
# [name="乌萨斯感染者"]  你知道这里有什么吗，感染者？
#
# [name="乌萨斯感染者"]  和你一样的感染者，活的感染者还有死的感染者。
#
# [name="乌萨斯感染者"]  因为整合运动只能在这里苟延残喘的感染者，因为整合运动死在这里的无数感染者......
#
# [name="乌萨斯感染者"]  但我们之前没有人感染。
#
# [name="乌萨斯感染者"]  切尔诺伯格的市民，被他们四处驱赶，四处找出来！最开始是屠杀，然后是折磨，最后是像丢垃圾一样随意处置活下来的人！
#
# [name="乌萨斯感染者"]  不知道多少人缺衣少食，死在这里......
#
# [name="乌萨斯感染者"]  活下来的，也因为不断接触源石，全都感染了！到现在，我已经没看见任何还没被感染者的人！
#
# [name="乌萨斯感染者"]  你们感染者......
#
# [name="乌萨斯感染者"]  你们感染者！！
#
# [Character(name="char_002_amiya_1#4",name2="avg_npc_057",focus=1)]
#
# [name="阿米娅"]  相信我们......不用带我们去救治其他人。我们会把必要的医疗援助交给你们。之后，我们立刻就离开。
#
# [Character(name="char_002_amiya_1#4",name2="avg_npc_057",focus=2)]
#
# [name="乌萨斯感染者"]  ......
#
# [name="乌萨斯感染者"]  我不信。
#
# [name="乌萨斯感染者"]  你们是乌萨斯派的，还是龙门派来的？
#
# [Character]
#
# [Dialog]
#
# [name="？？？"]  如果真的是他们，我们应该都已经死了。
#
# [Character(name="char_002_amiya_1#6")]
#
# [name="阿米娅"]  ——
#
# [name="阿米娅"]  你是......！
#
# [Character(name="char_003_kalts_1")]
#
# [name="凯尔希"]  阿米娅。扫一下他的识别码。
#
# [Character(name="char_002_amiya_1#6")]
#
# [name="阿米娅"]  医生......？！
#
# [image]
#
# [Dialog]
#
# [Blocker(a=1, r=0, g=0, b=0, fadetime=1, block=true)]
#
# [PlaySound(key="$d_gen_walk_n")]
#
# [Image(image="avg_7_12",x=0, y=-50, xScale=1, yScale=1, fadetime=0)]
#
# [ImageTween(x=0, yFrom=-50,yTo=0,xScaleFrom=1, yScaleFrom=1, xScaleTo=0.87, yScaleTo=0.87, duration=20, block=false)]
#
# [Blocker(a=0, r=0, g=0, b=0, fadetime=1, block=true)]
#
# [name="？？？"]  ......
#
# [name="凯尔希"]  Guard，解释一下。
#
# [name="罗德岛近卫干员？"]  许久不见，阿米娅，凯尔希医生。
#
# [name="罗德岛近卫干员？"]  以及，Dr.{@nickname}。
#
# [Dialog]
#
# [Blocker(fadetime=3,block=true)]
#
# [Image]
#
# }}
#
# {{剧情导航}}

# %%
db.close()

# %%
import psycopg2
from psycopg2 import sql

class ArknightsDatabase:
    def __init__(self, db_params):
        self.connection = psycopg2.connect(**db_params)
        self.cursor = self.connection.cursor()

    def insert_plot(self, story, chapter, dialog, speaker, dialogType, storyType):
        query = sql.SQL("""
            INSERT INTO plots (story, chapter, dialog, speaker, dialog_type, story_type)
            VALUES (%s, %s, %s, %s, %s, %s)
        """)
        self.cursor.execute(query, (story, chapter, dialog, speaker, dialogType, storyType))
        # self.connection.commit()

    def insert_choices(self, decisionId, decision, story, chapter, decisionValue, storyType):
        query = sql.SQL("""
            INSERT INTO choices (decision_id, decision, story, chapter, decision_value, story_type)
            VALUES (%s, %s, %s, %s, %s, %s)
        """)
        self.cursor.execute(query, (decisionId, decision, story, chapter, decisionValue, storyType))
        # self.connection.commit()

    def insert_outcomes(self, decisionId, dialog, speaker, dialogType, story, chapter, decisionValue, storyType):
        query = sql.SQL("""
            INSERT INTO outcomes (decision_id, dialog, speaker, dialog_type, story, chapter, decision_value, story_type)
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
        """)
        self.cursor.execute(query, (decisionId, dialog, speaker, dialogType, story, chapter, decisionValue, storyType))
        # self.connection.commit()

    def insert_comments(self, dialogId=None, decisionId=None, outcomeId=None, choiceId=None, story=None, chapter=None, username=None, commentContent=None, storyType=None):
        if dialogId is not None:
            query = sql.SQL("""
                INSERT INTO comments (dialog_id, story, chapter, username, comment_content, story_type)
                VALUES (%s, %s, %s, %s, %s, %s)
            """)
            self.cursor.execute(query, (dialogId, story, chapter, username, commentContent, storyType))
        elif decisionId is not None and outcomeId is None:
            query = sql.SQL("""
                INSERT INTO comments (choice_id, story, chapter, username, comment_content, story_type)
                VALUES (%s, %s, %s, %s, %s, %s)
            """)
            self.cursor.execute(query, (decisionId, story, chapter, username, commentContent, storyType))
        elif choiceId is not None and outcomeId is not None:
            query = sql.SQL("""
                INSERT INTO comments (outcome_id, story, chapter, username, comment_content, story_type)
                VALUES (%s, %s, %s, %s, %s, %s)
            """)
            self.cursor.execute(query, (outcomeId, story, chapter, username, commentContent, storyType))
        # self.connection.commit()

    def list_plots(self, story, chapter):
        query = sql.SQL("""
            SELECT * FROM plots WHERE story = %s AND chapter = %s
        """)
        self.cursor.execute(query, (story, chapter))
        return self.cursor.fetchall()

    def list_comments(self, story, chapter, username):
        query = sql.SQL("""
            SELECT * FROM comments WHERE story = %s AND chapter = %s AND username = %s
        """)
        self.cursor.execute(query, (story, chapter, username))
        return self.cursor.fetchall()

    def edit_comments(self, commentId, commentContent):
        query = sql.SQL("""
            UPDATE comments SET comment_content = %s WHERE comment_id = %s
        """)
        self.cursor.execute(query, (commentContent, commentId))
        self.connection.commit()

    def delete_comments(self, commentId):
        query = sql.SQL("""
            DELETE FROM comments WHERE comment_id = %s
        """)
        self.cursor.execute(query, (commentId,))
        self.connection.commit()

    def list_outcomes(self, decision_id, chapter, story, decisionValue):
        query = sql.SQL("""
            SELECT * FROM outcomes WHERE decision_id = %s AND chapter = %s AND story = %s AND decision_value = %s
        """)
        self.cursor.execute(query, (decision_id, chapter, story, decisionValue))
        return self.cursor.fetchall()

    def list_choices(self, decisionId, chapter, story):
        query = sql.SQL("""
            SELECT * FROM choices WHERE decision_id = %s AND chapter = %s AND story = %s
        """)
        self.cursor.execute(query, (decisionId, chapter, story))
        return self.cursor.fetchall()

    def list_all_comments(self):
        query = sql.SQL("""
            SELECT * FROM comments
        """)
        self.cursor.execute(query)
        return self.cursor.fetchall()

    def close(self):
        self.cursor.close()
        self.connection.close()
    def commit(self):
        self.connection.commit()

# Usage example:
db_params = {
  "database": "plots",
  "user": "neondb_owner",
  "password": "FHnKpb8xUw9j",
  "host": "ep-steep-leaf-a4i2z37h-pooler.us-east-1.aws.neon.tech",
  "port": "5432"
  }
db = ArknightsDatabase(db_params)
# db.insert_plot('Story A', 'Chapter 1', 'Dialog text', 'Speaker Name', 'type', 'story_type')
# db.close()

# %%
data = {
  "story": "1",
  "chapter": "2",
  "dialog": "3",
  "speaker": "4",
  "dialogType": "5",
  "storyType": "6"
}

db.insert_plot(**data)

# %%
db.close()

# %%
import re
import os
import requests

headers = {
    'Content-Type': 'application/json'
}

def process_raw_file(path, story, chapter, story_type):
    # # 要读取的文件路径
    # path = './plot/主线/'
    # # 故事
    # story = "慈悲灯塔"
    # # 
    # chapter = "40_14-23_良夜将死"
    # 文件后缀
    suffix = ".txt"
    # Function to extract options and values
    def extract_options_and_values(input_str):
        # Remove the surrounding '[Decision(' and ')]'
        clean_str = input_str.strip("[]Decision()")
        
        # Split the string into options and values
        options_part, values_part = clean_str.split(",")
        
        # Extract the actual options and values
        options = options_part.strip().split('=')[1].strip('"').split(';')
        values = re.sub(r'[^0-9;]', '',values_part.strip().split('=')[1].strip('"')).split(';')
        
        return options, values

    with open(path+story+"/"+chapter+suffix, 'r',encoding='utf-8') as f:
        plots = f.readlines()
    chapter = "_".join(chapter.split("_")[1:])
    plot = []
    choices = []
    outcomes = []
    decision_count = 0
    predicate_values = []
    for i in plots:
        print(i)
        # 第一种类型 对话
        if i[:5] == "[Name" or i[:5] =="[name":
            if predicate_values != []:
                for value in predicate_values:
                    outcomes.append({
                        "decisionId": decision_count,
                        "dialog": i.split("\"]")[-1],
                        "speaker": i.split("\"]")[0].split("name=\"")[-1],
                        "dialogType": "对话",
                        "story": story,
                        "chapter": chapter,
                        "decisionValue": int(value),
                        "storyType": story_type
                    })
            else:
                plot.append({
                    "story": story,
                    "chapter": chapter,
                    "dialog": i.split("\"]")[-1],
                    "speaker": i.split("\"]")[0].split("name=\"")[-1],
                    "dialogType": "对话",
                    "storyType": story_type
                })
        
        # 第二种类型 无人物文字
        elif i[:5] =="[Dial" or i[:5] =="[dial" :
            plot.append({
                "story": story,
                "chapter": chapter,
                "dialog": "\n",
                "speaker": "结束",
                "dialogType": "对话结束",
                "storyType": story_type
            })
            predicate_values = []
        
        # 第三种类型 选择支
        elif i[:5] =="[Deci" or i[:5] =="[deci" :
            decisions, values = extract_options_and_values(i);
            if (len(decisions) == len(values)):
                decision_count += 1
                # 如果两个数组长度相等,说明有多个选项
                for decision in range(len(decisions)):
                    choices.append({
                        "decisionId": decision_count,
                        "decision": decisions[decision],
                        "story": story,
                        "chapter": chapter,
                        "decisionValue": int(values[decision]),
                        "storyType": story_type
                    })
            else:
                # 这种情况属于明日方舟程序员发疯
                # [Decision(options="正常的还是......", values="1;2;3")]
                # 那个疯子会一个选项对应三个值，然后下面还只有1是有后续的
                assert len(decisions) == 1 # 如果不是1，那我也不知道该怎么做了
                for value in values:
                    choices.append({
                        "decisionId": decision_count,
                        "decision": decisions[0],
                        "story": story,
                        "chapter": chapter,
                        "decisionValue": int(value),
                        "storyType": story_type
                    })
            # 同时需要再plot里插入一个选项占位符,由于确定选项位置
            plot.append({
                "story": story,
                "chapter": chapter,
                "dialog": "",
                "speaker": "",
                "dialogType": "选择",
                "storyType": story_type
            })
            predicate_values = []
            # 当predicate查询对应的decision的时候,应该同时按照story, chapter, decision_id,decision_value查询,只有这些所有都满足条件才可以认为我们选了这个选项
        elif i[:5] =="[Pred" or i[:5] =="[pred" :
            # 如果是predicate,那么接下来一直到dialog结束都是predicate的领域
            # 示例, 注意predicate的references可能不止一个
                # [Decision(options="我是这片大地的拯救者。;我是这片大地的毁灭者。", values="1;2")]
                # [Predicate(references="1")]
                # [charslot(slot="m",name="avg_003_kalts_1#2$1",focus="m")]
                # [name="凯尔希"]如果这是你深思熟虑后的想法，我会表示尊重。
                # [charslot(slot="m",name="avg_003_kalts_1#1$1",focus="m")]
                # [name="凯尔希"]但如今的你，还远远做不到。
                # [name="凯尔希"]我们未来的道路还很漫长......不，或许留给我们的时间已经所剩无几。
                # [name="凯尔希"]博士，未来不会等到我们一切就绪之后再准时到来。
                # [charslot(slot="m",name="avg_003_kalts_1#1$1",focus="m")]
                # [name="凯尔希"]但我会无条件陪着你，还有罗德岛走下去。
                # [Dialog]
                # [Predicate(references="2")]
                # [charslot(slot="m",name="avg_003_kalts_1#5$1",focus="m")]
                # [name="凯尔希"]......现在的你，真的还能坦然说出这句话吗？
                # [name="凯尔希"]你在犹豫，你在怀疑。
                # [charslot(slot="m",name="avg_003_kalts_1#7$1",focus="m")]
                # [name="凯尔希"]这本就不是你的本心，不要让无妄的猜测干扰你当前的决心。
                # [name="凯尔希"]我们是谁，本就由我们所做而决定，而非由所说决定，无论走到终点之前你徘徊了多久。
                # [charslot(slot="m",name="avg_003_kalts_1#5$1",focus="m")]
                # [name="凯尔希"]未来会告诉我答案，博士。
                # [name="凯尔希"]如今，我更愿意陪着你走下去。
                # [name="凯尔希"]我们会一同见证。
                # [Dialog]
            match = re.search(r'references="([^"]+)"', i)
            if match:
                predicate_values = match.group(1).split(';')
        elif i[:5] == "[subt" or i[:5] == "[Subt":
            # [Subtitle(text="“如今，萨卡兹能够选择的可能性只剩一种了，特蕾西娅。”", x=300, y=370, alignment="center", size=24, delay=0.04, width=700)]
            i = i[len("[Subtitle(text=\""):].split("\"")[0]
            if predicate_values != []:
                for value in predicate_values:
                    outcomes.append({
                        "decisionId": decision_count,
                        "dialog": i,
                        "speaker": "旁白",
                        "dialogType": "旁白",
                        "story": story,
                        "chapter": chapter,
                        "decisionValue": int(value),
                        "storyType": story_type
                    })
            else:
                plot.append({
                    "story": story,
                    "chapter": chapter,
                    "dialog": i,
                    "speaker": "旁白",
                    "dialogType": "旁白",
                    "storyType": story_type
                })

        # 遇到文字直接输出
        elif i[0] !="[" and i[0] != "{" and i[0] != "}" and i[0] != "]" and i.strip() != "":
            # print(i)
            if predicate_values != []:
                for value in predicate_values:
                    outcomes.append({
                        "decisionId": decision_count,
                        "dialog": i,
                        "speaker": "旁白",
                        "dialogType": "旁白",
                        "story": story,
                        "chapter": chapter,
                        "decisionValue": value,
                        "storyType": story_type
                    })
            else:
                plot.append({
                    "story": story,
                    "chapter": chapter,
                    "dialog": i,
                    "speaker": "旁白",
                    "dialogType": "旁白",
                    "storyType": story_type
                })

    for j in plot:
        # requests.post("http://localhost:8080/insertPlots", json=j, headers=headers)
        # print()
        db.insert_plot(**j)
    for j in choices:
        # requests.post("http://localhost:8080/insertChoices", json=j, headers=headers)
        db.insert_choices(**j)
    for j in outcomes:
        # requests.post("http://localhost:8080/insertOutcomes", json=j, headers=headers)
        db.insert_outcomes(**j)
    db.commit()

# %%
import requests
for i in plot:
  requests.post("http://localhost:8080/insertPlots", i)

# %%
for i in choices:
  requests.post("http://localhost:8080/insertChoices", i)

# %%
for i in outcomes:
  requests.post("http://localhost:8080/insertOutcomes", i)

# %%
import urllib

images = [
  {
    "name": "生息演算",
    "icon": "",
    "cover": "https://patchwiki.biligame.com/images/arknights/3/33/a5wm510ixt1hscz9poxpzbl9xv5kqyo.png",
    "name-en": "TALES WITHIN THE SAND"
  }
]

print("INSERT INTO images (name, icon, cover, name_en, info, type, shift) VALUES")
for i in images:
  print(f"('{i['name']}', '{urllib.parse.unquote(i['icon'])}', '{urllib.parse.unquote(i['cover'])}', '{i['name-en']}', '{i.get('info','')}', '主线', {i.get('shift',0)}),")
# Out:
# INSERT INTO images (name, icon, cover, name_en, info, type, shift) VALUES
# ('生息演算', '', 'https://patchwiki.biligame.com/images/arknights/3/33/a5wm510ixt1hscz9poxpzbl9xv5kqyo.png', 'TALES WITHIN THE SAND', '', '主线', 0),

# %%
import os
print("INSERT INTO stories (chapter, story, story_id, story_type) VALUES")
for chapter in os.listdir("./plot/集成战略"):
  stories = os.listdir(f"./plot/集成战略/{chapter}")
  for story in stories:
    if story.split(".")[-1] != "txt":
      continue
    story_id = int(story.split("_")[0])
    story = "_".join(story.split("_")[1:]).split('.')[0]
    print(f"('{chapter}', '{story}', {story_id},'肉鸽'),")
    # story_id += 1
# Out:
# INSERT INTO stories (chapter, story, story_id, story_type) VALUES
# ('傀影与猩红孤钻', '序章', 1,'肉鸽'),
# ('傀影与猩红孤钻', '舞会终场', 2,'肉鸽'),
# ('傀影与猩红孤钻', '滑稽喜剧', 3,'肉鸽'),
# ('傀影与猩红孤钻', '盛大揭幕', 4,'肉鸽'),
# ('傀影与猩红孤钻', '沉默之章', 5,'肉鸽'),
# ('刻俄柏的灰蕈迷境', '行动开始', 1,'肉鸽'),
# ('刻俄柏的灰蕈迷境', '迷尘幻梦', 2,'肉鸽'),
# ('刻俄柏的灰蕈迷境', '茫然行者', 3,'肉鸽'),
# ('刻俄柏的灰蕈迷境', '归于荒野', 4,'肉鸽'),
# ('探索者的银凇止境', '序章', 1,'肉鸽'),
# ('探索者的银凇止境', '越过群山', 2,'肉鸽'),
# ('探索者的银凇止境', '直至冬夜降临', 3,'肉鸽'),
# ('探索者的银凇止境', '自深处的一瞥', 4,'肉鸽'),
# ('探索者的银凇止境', '终始', 5,'肉鸽'),
# ('水月与深蓝之树', '序章', 1,'肉鸽'),
# ('水月与深蓝之树', '平凡即是喜乐', 2,'肉鸽'),
# ('水月与深蓝之树', '静谧时代', 3,'肉鸽'),
# ('水月与深蓝之树', '息潮的代价', 4,'肉鸽'),
# ('水月与深蓝之树', '如星空般深蓝', 5,'肉鸽'),
# ('萨卡兹的无终奇语', '序章', 1,'肉鸽'),
# ('萨卡兹的无终奇语', '憧憬未来', 2,'肉鸽'),
# ('萨卡兹的无终奇语', '双王记', 3,'肉鸽'),
# ('萨卡兹的无终奇语', '天使之城', 4,'肉鸽'),

# %%
x = "aaa"
x.find
