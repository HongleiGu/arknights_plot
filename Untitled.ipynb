# %%
from typing import Union
import os
import uvicorn
import copy
from io import BytesIO
from fastapi import FastAPI#, Response
import nest_asyncio
# from transformers import AutoModelForCausalLM, AutoTokenizer
# import torch
import json
import random
app = FastAPI()
from typing import Optional
from pydantic import BaseModel
#第二步导入相应的模块
from PyPDF2 import PdfReader, PdfWriter
import urllib
from fastapi.middleware.cors import CORSMiddleware
app.add_middleware(
    CORSMiddleware,
    allow_origins=["*"],
    allow_credentials=True,
    allow_methods=["*"],
    allow_headers=["*"],
)

default_content_position = 14

document = {}
# plot = {}
from PyPDF2 import PdfReader

def valid_plot(x):
    if x.split(".")[-1] == "ipynb":
        return False
    if x.split(".")[-1] == "json":
        return False
    if x[0] == ".":
        return False
    return True


@app.get("/list_files")
def list_files(filepath):
    filepath = urllib.parse.unquote(filepath)
    print(filepath)
    filelist = list(filter(valid_plot, os.listdir(filepath)))
    rtrn = []
    for i in filelist:
        if "." in i:
            rtrn.append({"filename": i, "type": "file"})
        else:
            rtrn.append({"filename": i, "type": "folder"})
    print(rtrn)
    return rtrn
        
@app.get("/get_pdf_pages")
def get_num_pages(filename):
    """
    获取文件总页码
    :param file_path: 文件路径
    :return:
    """
    reader = PdfReader(filename + ".pdf")
    # 不解密可能会报错：PyPDF2.utils.PdfReadError: File has not been decrypted
    if reader.is_encrypted:
        reader.decrypt('')
    return len(reader.pages)

@app.get("/get_files")
def get_files(filename):
        
#     print(filename)
    filename = filename.split("#")[0]
    with open("./database.json", "r") as file:
        document[filename] = json.load(file)[filename]
    for i in range(len(document[filename]["plot"])):
        document[filename]["plot"][i]["id"] = i
    return document[filename]["plot"]
#     rtrn = []
#     index = 0
#     with open("./" + filename + ".txt", "r") as file:
#         lines = file.readlines()
#     for i in lines:
#         if i.strip() != "":
#             content = i.strip()[default_content_position:]
#             role = i.strip()[:default_content_position].strip()
#             rtrn.append({"content": content, "role": role,  "id":index})
#             index += 1
#     return rtrn

@app.get("/get_all_comments")
def get_all_comments():
    with open("./database.json", "r") as f:
        temp_document = json.load(f)
    temp_comment = []
    for i in temp_document.keys():
        for j in range(len(temp_document[i]["comments"])):
            temp_document[i]["comments"][j]["filename"] = i
            temp_comment.append(temp_document[i]["comments"][j])
    del temp_document
    return temp_comment
    

@app.get("/get_comments")
def get_comments(filename):
    global document
    filename = filename.split("#")[0]
#     with open("./" + filename + ".json", "r") as f:
    with open("./database.json") as f:
        document[filename]["comments"] = json.load(f)[filename]["comments"]
    print(document[filename]["comments"])
    for i in range(len(document[filename]["comments"])):
        document[filename]["comments"][i]["id"] = i
    return document[filename]["comments"]

@app.get("/update_comments")
def update_comments(filename):
    global document
    filename = filename.split("#")[0]
    return document[filename]["comments"]

@app.get("/add_comments")
def add_comments(content, position, maxId, type, filename):
    global document
    filename = filename.split("#")[0]
    try:
        document[filename]["comments"].append({"filename":filename, "id":maxId,"position":position,"content":content, "type": str(type)})
    except: 
        document[filename]["comments"] = [{"filename":filename,"id":maxId,"position":position,"content":content, "type": str(type)}]

@app.get("/save")
def save(filepath):
    global document
    filepath = filepath.split("#")[0]
#     with open(filepath + ".json", "w", encoding="utf-8") as f:
#         json.dump(document[filepath], f, ensure_ascii=False)
    with open("./database.json","r",encoding="utf-8") as f:
        content = json.load(f)
        content[filepath] = document[filepath]
    with open("./database.json","w",encoding="utf-8") as f:
        json.dump(content, f, ensure_ascii=False)
        
@app.get("/delete_comments")
def delete_comments(maxId, filename):
    global document
    filename = filename.split("#")[0]
    for i in range(len(document[filename]["comments"])-1, -1, -1):
        if int(document[filename]["comments"][i]["id"]) == int(maxId):
            del document[filename]["comments"][i]
        
@app.get("/edit_comments")
def edit_comments(id, content, filename):
    global document
#     print(id)
    filename = filename.split("#")[0]
    for i in range(len(document[filename]["comments"])):
#         print(comments[i]["id"])
#         print(int(comments[i]["id"]) == int(id))
        if int(document[filename]["comments"][i]["id"]) == int(id):
            document[filename]["comments"][i]["content"] = content
    
@app.get("/get_file_type")
def get_file_type(path):
    if os.path.exists(path + ".txt"):
        return "txt"
    elif os.path.exists(path + ".pdf"):
        return "pdf"
    return ""

@app.get("/get_files_pdf")
def get_files_pdf(filename):
    reader = PdfReader(filename + ".pdf")
    # 不解密可能会报错：PyPDF2.utils.PdfReadError: File has not been decrypted
    if reader.is_encrypted:
        reader.decrypt('')
#     print

    page = reader.pages[0]
    pdf_bytes = BytesIO()
    pdf_writer = PdfWriter()
    pdf_writer.add_page(page)
    pdf_writer.write(pdf_bytes)
    pdf_bytes.seek(0)

    
#     return 
    response = Response(content=pdf_bytes.getvalue(), media_type="application/pdf")

#     设置响应头，告诉浏览器以附件形式保存文件
#     response.headers["Content-Disposition"] = f"attachment; filename={path}.pdf"

    return response

@app.get("/add_answer")
def add_answer(target_filename, target_id, answer_filename, answer_id):
    if (target_filename == answer_filename and target_id == answer_id):
        return
    with open("./database.json", "r") as f:
        temp_document = json.load(f)
    print(temp_document[answer_filename]["comments"])
    print(answer_id)
    temp_solution = copy.deepcopy(temp_document[answer_filename]["comments"][int(answer_id)])
    temp_solution1 = copy.deepcopy(temp_document[target_filename]["comments"][int(target_id)])
    try:
        del temp_solution["solution"]
    except:
        print(1)
    try:
        del temp_solution1["solution"]
    except:
        print(1)
    try:
        if temp_solution not in temp_document[target_filename]["comments"][int(target_id)]["solution"]:
            temp_document[target_filename]["comments"][int(target_id)]["solution"].append(temp_solution)
    except:
        temp_document[target_filename]["comments"][int(target_id)]["solution"]=[temp_solution]
    try:
        if temp_solution1 not in temp_document[answer_filename]["comments"][int(answer_id)]["solution"]:
            temp_document[answer_filename]["comments"][int(answer_id)]["solution"].append(temp_solution1)
    except:
        temp_document[answer_filename]["comments"][int(answer_id)]["solution"]=[temp_solution1]
#     temp_document[answer_filename]["comments"][int(answer_id)]["solution"]=list(set(temp_document[answer_filename]["comments"][int(answer_id)]["solution"]))
    with open("./database.json", "w") as f:
        json.dump(temp_document, f, ensure_ascii=False)
    del temp_solution
    del temp_document

@app.get("/get_answer")
def get_answer(target_filename, target_id):
    with open("./database.json", "r") as f:
        temp_document = json.load(f)
        try:
            return temp_document[target_filename]["comments"][int(target_id)]["solution"]
        except:
            return []

@app.get("/delete_answer")
def delete_answer(target_filename, target_id, answer_filename, answer_id):
    with open("./database.json", "r") as f:
        temp_document = json.load(f)
    index = 0
    while temp_document[target_filename]["comments"][int(target_id)]["solution"][index]["filename"] != answer_filename and temp_document[target_filename]["comments"][int(target_id)]["solution"][index]["id"] != answer_id:
        index+=1
    del temp_document[target_filename]["comments"][int(target_id)]["solution"][index]
    index = 0
    while temp_document[answer_filename]["comments"][int(answer_id)]["solution"][index]["filename"] != target_filename and temp_document[answer_filename]["comments"][int(answer_id)]["solution"][index]["id"] != target_id:
        index+=1
    del temp_document[answer_filename]["comments"][int(answer_id)]["solution"][index]
    with open("./database.json", "w") as f:
        json.dump(temp_document, f, ensure_ascii=False)
        

if __name__ == '__main__':
    # 运行fastapi程序
    nest_asyncio.apply()
    uvicorn.run(app, host='0.0.0.0', port = 8000)
# Out:
# INFO:     Started server process [4768]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# INFO:     Shutting down
# INFO:     Finished server process [4768]

# %%
def valid_plot(x):
    if x.split(".")[-1] == "ipynb":
        return False
    if x.split(".")[-1] == "json":
        return False
    if x[0] == ".":
        return False
    return True
list(filter(valid_plot, os.listdir("./plot/")))
# Out:
# ['主线', '刻俄柏的灰蕈迷境', '剧情', '支线', '沙中之火', '隐藏剧情']

# %%
import json
def process_raw_plot(filepath):
    plot = []
    id = 0
    with open(filepath + ".txt", "r") as f:
        lines = f.readlines()
        for i in lines:
            if i.strip() == "":
                continue
            role = i.strip().split(" "*5)[0]
            content = i.strip().split(" "*5)[-1]
            plot.append({"role": role, "content": content, "id": id, "type": "dialog"})
            id += 1
    with open(filepath + "plot.json", "w") as f:
        json.dump(plot, f, ensure_ascii=False)

# %%
import json
with open("./database.json", "r") as f:
    temp_document = json.load(f)
def write_files(filename):
    global temp_document
    temp = {}
    temp["plot"] = []
    temp["comments"] = []
    id = 0
    with open("./plot/"+filename+".txt") as f:
        lines = f.readlines()
        for line in lines:
            if "[name=" in line:
                name = line.split("name=")[1].split("]")[0]
                if name == "":
                    name = "旁白或者未知"
                if len(name) <= 10:
                    while len(name) < 10:
                        name = name + " "
                text = line.split("]")[1]
                name = name.strip().replace("\"","")
                text = text.strip()
                temp["plot"].append({"id": id, "type": "dialog", "role": name, "content": text})
            elif "[Decision(options=\"" in line:
                name = "游戏中选项"
                text = line.split("[Decision(options=\"")[1].split(";")[0]
                temp["plot"].append({"id": id, "type": "dialog", "role": name, "content": text})
            elif "[" not in line and "{" not in line and "]" not in line and "}" not in line:
                name = "旁白"
                text = line.strip()
                temp["plot"].append({"id": id, "type": "dialog", "role": name, "content": text})
    with open("./plot/"+filename + "plot.txt", "w") as f:
        for line in lines:
#             name = ""
            if "[name=" in line:
                name = line.split("name=")[1].split("]")[0]
                if name == "":
                    name = "旁白或者未知"
                if len(name) <= 10:
                    while len(name) < 10:
                        name = name + " "
                text = line.split("]")[1]
                name = name.strip().replace("\"","")
                text = text.strip()
#                 temp["plot"].append({"id": id, "type": "dialog", "role": name, "content": text})
            elif "[Decision(options=\"" in line:
                name = ""
                text = line.split("[Decision(options=\"")[1].split(";")[0].split("\"")[0]
                f.write(text)
                f.write("\n")
                continue
#                 temp["plot"].append({"id": id, "type": "dialog", "role": name, "content": text})
            elif "[" not in line and "{" not in line and "]" not in line and "}" not in line:
                name = ""
                text = line.strip()
                f.write(text)
                f.write("\n")
                continue
            elif "[Dialog]" in line:
                f.write("\n\n\n")
                continue
            else:
                continue
            f.write(name+": "+text)
            f.write("\n")
#                 temp["plot"].append({"id": id, "type": "dialog", "role": name, "content": text})
#         for i in temp["plot"]:
#             name = i["role"]
#             name = name + ":"
#             while len(name) < 15:
#                 name = name + " "
#             f.write(name + i["content"] + "\n")
    with open("./plot/"+filename + "plot.json", "w") as f:
        json.dump(temp["plot"], f, ensure_ascii=False)
    temp_document[filename] = temp

# %%
import requests
from bs4 import BeautifulSoup
all_plot_url = "https://prts.wiki/w/%E5%89%A7%E6%83%85%E4%B8%80%E8%A7%88"
res = requests.get(all_plot_url)
soup = BeautifulSoup(res.text, "html.parser")
tbodies = soup.find_all("tbody")

# %%
import json
import time
import urllib
plot_names = []
for tbody in tbodies:
    trs = tbody.find_all("tr")
    for i in trs[1:]:
        try:
            chapter = i.find_all("th")[0].text.strip()
            temp = i.find_all("th")[1].text.strip()
            for j in i.find_all("td")[0].find_all("a"):
                href = j.get("href")[3:]
                filename = urllib.parse.unquote(j.get("href"))[3:].replace("/","_")
                plot_names.append({"href": href, "filename": filename, "folder": temp+"/"+chapter+"/"})
        except:
            continue
print(plot_names)
# Out:
# [{'href': '%E9%9A%90%E8%97%8F%E5%89%A7%E6%83%85/%E5%89%A7%E6%83%85', 'filename': '隐藏剧情_剧情', 'folder': '剧情/特殊/'}, {'href': '%E9%87%87%E8%B4%AD%E4%B8%AD%E5%BF%83/%E5%89%A7%E6%83%85', 'filename': '采购中心_剧情', 'folder': '剧情/特殊/'}, {'href': 'EP09/ENTRY', 'filename': 'EP09_ENTRY', 'folder': '剧情/特殊/'}, {'href': 'EP10/ENTRY', 'filename': 'EP10_ENTRY', 'folder': '剧情/特殊/'}, {'href': 'EP11/ENTRY', 'filename': 'EP11_ENTRY', 'folder': '剧情/特殊/'}, {'href': 'EP12/ENTRY', 'filename': 'EP12_ENTRY', 'folder': '剧情/特殊/'}, {'href': 'W2G/BEG', 'filename': 'W2G_BEG', 'folder': '主线/黑暗时代·上/'}, {'href': 'G2H/END', 'filename': 'G2H_END', 'folder': '主线/黑暗时代·上/'}, {'href': '0-1_%E5%9D%8D%E5%A1%8C/BEG', 'filename': '0-1_坍塌_BEG', 'folder': '主线/黑暗时代·上/'}, {'href': '0-1_%E5%9D%8D%E5%A1%8C/END', 'filename': '0-1_坍塌_END', 'folder': '主线/黑暗时代·上/'}, {'href': '0-2_%E5%AE%88%E5%8D%AB/BEG', 'filename': '0-2_守卫_BEG', 'folder': '主线/黑暗时代·上/'}, {'href': '0-2_%E5%AE%88%E5%8D%AB/END', 'filename': '0-2_守卫_END', 'folder': '主线/黑暗时代·上/'}, {'href': '0-4_%E6%B7%B7%E6%88%98/BEG', 'filename': '0-4_混战_BEG', 'folder': '主线/黑暗时代·上/'}, {'href': '0-6_%E5%BC%BA%E5%87%BB/END', 'filename': '0-6_强击_END', 'folder': '主线/黑暗时代·上/'}, {'href': '0-7_%E6%84%9F%E6%9F%93/BEG', 'filename': '0-7_感染_BEG', 'folder': '主线/黑暗时代·上/'}, {'href': '0-7_%E6%84%9F%E6%9F%93/END', 'filename': '0-7_感染_END', 'folder': '主线/黑暗时代·上/'}, {'href': '0-8_%E7%8B%A9%E7%8C%8E/BEG', 'filename': '0-8_狩猎_BEG', 'folder': '主线/黑暗时代·上/'}, {'href': '0-9_%E4%B8%B4%E5%85%89/END', 'filename': '0-9_临光_END', 'folder': '主线/黑暗时代·上/'}, {'href': '0-10_%E5%9B%B0%E5%A2%83/BEG', 'filename': '0-10_困境_BEG', 'folder': '主线/黑暗时代·上/'}, {'href': '0-11_%E7%AA%81%E5%9B%B4/END', 'filename': '0-11_突围_END', 'folder': '主线/黑暗时代·上/'}, {'href': '1-1_%E5%AD%A4%E5%B2%9B/BEG', 'filename': '1-1_孤岛_BEG', 'folder': '主线/黑暗时代·下/'}, {'href': '1-1_%E5%AD%A4%E5%B2%9B/END', 'filename': '1-1_孤岛_END', 'folder': '主线/黑暗时代·下/'}, {'href': '1-3_%E7%8B%82%E5%A5%94/BEG', 'filename': '1-3_狂奔_BEG', 'folder': '主线/黑暗时代·下/'}, {'href': '1-3_%E7%8B%82%E5%A5%94/END', 'filename': '1-3_狂奔_END', 'folder': '主线/黑暗时代·下/'}, {'href': '1-4_%E5%85%88%E5%85%86/BEG', 'filename': '1-4_先兆_BEG', 'folder': '主线/黑暗时代·下/'}, {'href': '1-6_%E7%81%BE%E9%9A%BE/BEG', 'filename': '1-6_灾难_BEG', 'folder': '主线/黑暗时代·下/'}, {'href': '1-7_%E6%9A%B4%E5%90%9B/BEG', 'filename': '1-7_暴君_BEG', 'folder': '主线/黑暗时代·下/'}, {'href': '1-7_%E6%9A%B4%E5%90%9B/END', 'filename': '1-7_暴君_END', 'folder': '主线/黑暗时代·下/'}, {'href': '1-8_%E6%84%8F%E5%BF%97/BEG', 'filename': '1-8_意志_BEG', 'folder': '主线/黑暗时代·下/'}, {'href': '1-10_%E6%AE%8B%E7%95%99/END', 'filename': '1-10_残留_END', 'folder': '主线/黑暗时代·下/'}, {'href': '1-12_%E4%BB%A3%E4%BB%B7/BEG', 'filename': '1-12_代价_BEG', 'folder': '主线/黑暗时代·下/'}, {'href': '1-12_%E4%BB%A3%E4%BB%B7/END', 'filename': '1-12_代价_END', 'folder': '主线/黑暗时代·下/'}, {'href': 'TR-11_%E6%88%98%E6%9C%AF%E9%98%BB%E6%BB%9E/BEG', 'filename': 'TR-11_战术阻滞_BEG', 'folder': '主线/异卵同生/'}, {'href': '2-1_%E9%BE%99%E9%97%A8%E4%B9%8B%E8%A1%8C/END', 'filename': '2-1_龙门之行_END', 'folder': '主线/异卵同生/'}, {'href': '2-2_%E5%85%B5%E4%B8%8D%E6%8E%A5%E5%88%83/BEG', 'filename': '2-2_兵不接刃_BEG', 'folder': '主线/异卵同生/'}, {'href': '2-2_%E5%85%B5%E4%B8%8D%E6%8E%A5%E5%88%83/END', 'filename': '2-2_兵不接刃_END', 'folder': '主线/异卵同生/'}, {'href': '2-3_%E6%97%A0%E7%BD%AA%E6%8E%A8%E5%AE%9A/BEG', 'filename': '2-3_无罪推定_BEG', 'folder': '主线/异卵同生/'}, {'href': '2-3_%E6%97%A0%E7%BD%AA%E6%8E%A8%E5%AE%9A/END', 'filename': '2-3_无罪推定_END', 'folder': '主线/异卵同生/'}, {'href': '2-4_%E4%BC%81%E9%B9%85%E7%89%A9%E6%B5%81/BEG', 'filename': '2-4_企鹅物流_BEG', 'folder': '主线/异卵同生/'}, {'href': '2-4_%E4%BC%81%E9%B9%85%E7%89%A9%E6%B5%81/END', 'filename': '2-4_企鹅物流_END', 'folder': '主线/异卵同生/'}, {'href': '2-5_%E9%AB%98%E7%A9%BA%E5%9D%A0%E7%89%A9/BEG', 'filename': '2-5_高空坠物_BEG', 'folder': '主线/异卵同生/'}, {'href': '2-5_%E9%AB%98%E7%A9%BA%E5%9D%A0%E7%89%A9/END', 'filename': '2-5_高空坠物_END', 'folder': '主线/异卵同生/'}, {'href': '2-6_%E6%8F%A1%E7%B4%A7%E6%89%B6%E6%89%8B/BEG', 'filename': '2-6_握紧扶手_BEG', 'folder': '主线/异卵同生/' ...

# %%
with open("./all_plots.json", "w") as f:
    f.write("[\n")
    for i in range(len(plot_names)-1):
        json.dump(plot_names[i], f, ensure_ascii=False)
        f.write(",\n")
    json.dump(plot_names[-1], f, ensure_ascii=False)
    f.write("]")
exception = []
for i in plot_names:
    res = requests.get(f"https://prts.wiki/index.php?title={i['href']}&action=edit")
    soup = BeautifulSoup(res.text, "html.parser")
    if not os.path.exists("./plot/" + i["folder"].split("/")[0]):
        os.mkdir("./plot/"+i["folder"].split("/")[0])
    if not os.path.exists("./plot/"+i["folder"]):
        os.mkdir("./plot/"+i["folder"])
    with open("./plot/"+i["folder"]+i["filename"]+".txt", "w") as f:
#         print(soup.find("textarea"))
        try:
            f.write(soup.find("textarea").text)
        except:
            exception.append(i)
    print("./plot/"+i["folder"]+i["filename"]+".txt")
    time.sleep(1)
# Out:
# ./plot/剧情/特殊/隐藏剧情_剧情.txt
# ./plot/剧情/特殊/采购中心_剧情.txt
# ./plot/剧情/特殊/EP09_ENTRY.txt
# ./plot/剧情/特殊/EP10_ENTRY.txt
# ./plot/剧情/特殊/EP11_ENTRY.txt
# ./plot/剧情/特殊/EP12_ENTRY.txt
# ./plot/主线/黑暗时代·上/W2G_BEG.txt
# ./plot/主线/黑暗时代·上/G2H_END.txt
# ./plot/主线/黑暗时代·上/0-1_坍塌_BEG.txt
# ./plot/主线/黑暗时代·上/0-1_坍塌_END.txt
# ./plot/主线/黑暗时代·上/0-2_守卫_BEG.txt
# ./plot/主线/黑暗时代·上/0-2_守卫_END.txt
# ./plot/主线/黑暗时代·上/0-4_混战_BEG.txt
# ./plot/主线/黑暗时代·上/0-6_强击_END.txt
# ./plot/主线/黑暗时代·上/0-7_感染_BEG.txt
# ./plot/主线/黑暗时代·上/0-7_感染_END.txt
# ./plot/主线/黑暗时代·上/0-8_狩猎_BEG.txt
# ./plot/主线/黑暗时代·上/0-9_临光_END.txt
# ./plot/主线/黑暗时代·上/0-10_困境_BEG.txt
# ./plot/主线/黑暗时代·上/0-11_突围_END.txt
# ./plot/主线/黑暗时代·下/1-1_孤岛_BEG.txt
# ./plot/主线/黑暗时代·下/1-1_孤岛_END.txt
# ./plot/主线/黑暗时代·下/1-3_狂奔_BEG.txt
# ./plot/主线/黑暗时代·下/1-3_狂奔_END.txt
# ./plot/主线/黑暗时代·下/1-4_先兆_BEG.txt
# ./plot/主线/黑暗时代·下/1-6_灾难_BEG.txt
# ./plot/主线/黑暗时代·下/1-7_暴君_BEG.txt
# ./plot/主线/黑暗时代·下/1-7_暴君_END.txt
# ./plot/主线/黑暗时代·下/1-8_意志_BEG.txt
# ./plot/主线/黑暗时代·下/1-10_残留_END.txt
# ./plot/主线/黑暗时代·下/1-12_代价_BEG.txt
# ./plot/主线/黑暗时代·下/1-12_代价_END.txt
# ./plot/主线/异卵同生/TR-11_战术阻滞_BEG.txt
# ./plot/主线/异卵同生/2-1_龙门之行_END.txt
# ./plot/主线/异卵同生/2-2_兵不接刃_BEG.txt
# ./plot/主线/异卵同生/2-2_兵不接刃_END.txt
# ./plot/主线/异卵同生/2-3_无罪推定_BEG.txt
# ./plot/主线/异卵同生/2-3_无罪推定_END.txt
# ./plot/主线/异卵同生/2-4_企鹅物流_BEG.txt
# ./plot/主线/异卵同生/2-4_企鹅物流_END.txt
# ./plot/主线/异卵同生/2-5_高空坠物_BEG.txt
# ./plot/主线/异卵同生/2-5_高空坠物_END.txt
# ./plot/主线/异卵同生/2-6_握紧扶手_BEG.txt
# ./plot/主线/异卵同生/2-6_握紧扶手_END.txt
# ./plot/主线/异卵同生/2-7_注意卫生_BEG.txt
# ./plot/主线/异卵同生/2-7_注意卫生_END.txt
# ./plot/主线/异卵同生/2-8_不做约定_BEG.txt
# ./plot/主线/异卵同生/2-8_不做约定_END.txt
# ./plot/主线/异卵同生/2-9_操作暗箱_BEG.txt
# ./plot/主线/异卵同生/2-9_操作暗箱_END.txt
# ./plot/主线/异卵同生/2-10_病入膏肓_BEG.txt
# ./plot/主线/异卵同生/2-10_病入膏肓_END.txt
# ./plot/主线/二次呼吸/3-1_会合_BEG.txt
# ./plot/主线/二次呼吸/3-1_会合_END.txt
# ./plot/主线/二次呼吸/3-2_记忆_BEG.txt
# ./plot/主线/二次呼吸/3-2_记忆_END.txt
# ./plot/主线/二次呼吸/3-3_回旋_BEG.txt
# ./plot/主线/二次呼吸/3-3_回旋_END.txt
# ./plot/主线/二次呼吸/3-4_龟裂_BEG.txt
# ./plot/主线/二次呼吸/3-4_龟裂_END.txt
# ./plot/主线/二次呼吸/3-5_呼叫_BEG.txt
# ./plot/主线/二次呼吸/3-5_呼叫_END.txt
# ./plot/主线/二次呼吸/3-6_决定_BEG.txt
# ./plot/主线/二次呼吸/3-6_决定_END.txt
# ./plot/主线/二次呼吸/3-7_轰鸣_BEG.txt
# ./plot/主线/二次呼吸/3-7_轰鸣_END.txt
# ./plot/主线/二次呼吸/3-8_黄昏_BEG.txt
# ./plot/主线/二次呼吸/3-8_黄昏_END.txt
# ./plot/主线/急性衰竭/4-1_免费拥抱_BEG.txt
# ./plot/主线/急性衰竭/4-1_免费拥抱_END.txt
# ./plot/主线/急性衰竭/4-2_雨中漫步_BEG.txt
# ./plot/主线/急性衰竭/4-2_雨中漫步_END.txt
# ./plot/主线/急性衰竭/4-3_人工制冷_BEG.txt
# ./plot/主线/急性衰竭/4-3_人工制冷_END.txt
# ./plot/主线/急性衰竭/4-4_不要恐慌_BEG.txt
# ./plot/主线/急性衰竭/4-4_不要恐慌_END.txt
# ./plot/主线/急性衰竭/4-5_官僚主义_BEG.txt
# ./plot/主线/急性衰竭/4-5_官僚主义_END.txt
# ./plot/主线/急性衰竭/4-6_少见多怪_BEG.txt
# ./plot/主线/急性衰竭/4-6_少见多怪_END.txt
# ./plot/主线/急性衰竭/4-7_各取所需_BEG.txt
# ./plot/主线/急性衰竭/4-7_各取所需_END.txt
# ./plot/主线/急性衰竭/4-8_应激反应_BEG.txt
# ./plot/主线/急性衰竭/4-8_应激反应_END.txt
# ./plot/主线/急性衰竭/4-9_彻入骨髓_BEG.txt
# ./plot/主线/急性衰竭/4-9_彻入骨髓_END.txt
# ./plot/主线/急性衰竭/4-10_灯火将熄_BEG.txt
# ./plot/主线/急性衰竭/4-10_灯火将熄_END.txt
# ./plot/主线/靶向药物/5-1_冤家易结_BEG.txt
# ./plot/主线/靶向药物/5-1_冤家易结_END.txt
# ./plot/主线/靶向药物/5-2_有口难言_BEG.txt
# ./plot/主线/靶向药物/5-2_有口难言_END.txt
# ./plot/主线/靶向药物/5-3_义胆凡躯_BEG.txt
# ./plot/主线/靶向药物/5-3_义胆凡躯_END.txt
# ./plot/主线/靶向药物/5-4_没人在家_BEG.txt
# ./plot/主线/靶向药物/5-4_没人在家_END.txt
# ./plot/主线/靶向药物/5-6_疑兵之计_BEG.txt
# ./plot/主线/靶向药物/5-6_疑兵之计_END.txt
# ./plot/主线/靶向药物/5-7_生死与共_BEG.txt
# ./plot/主线/靶向药物/5-7_生死与共_END.txt
# ./plot/主线/靶向药物/5-9_孽生恶物_BEG.txt
# ./plot/主线/靶向药物/5-9_孽生恶物_END.txt
# ./plot/主线/靶向药物/5-10_长夜终尽_BEG.txt
# ./plot/主线/靶向药物/5-10_长夜终尽_END.txt
# ./plot/主线/靶向药物/5-11_棋胜后着_NBT.txt
# ./plot/主线/局部坏死/6-1_僵局_BEG.txt
# ./plot/主线/局部坏死/6-1_僵局_END.txt
# ./plot/主线/局部坏死/6-2_一些误会_BEG.txt
# ./plot/主线/局部坏死/6-2_一些误会_END.txt
# ./plot/主线/局部坏死/6-3_同时走失_BEG.txt
# ./plot/主线/局部坏死/6-3_同时走失_END.txt
# ./plot/主线/局部坏死/6-4_溃烂的疮疤_BEG.txt
# ./plot/主线/局部坏死/6-4_溃烂的疮疤_END.txt
# ./plot/主线/局部坏死/6-5_解决谁？_BEG.txt
# ./plot/主线/局部坏死/6-5_解决谁？_END.txt
# ./plot/主线/局部坏死/6-6_别说过去的事_NBT.txt
# ./plot/主线/局部坏死/6-7_断弦_BEG.txt
# ./plot/主线/局部坏死/6-7_断弦_END.txt
# ./plot/主线/局部坏死/6-8_只是从天而降！_BEG.txt
# ./plot/主线/局部坏死/6-8_只是从天而降！_END.txt
# ./plot/主线/局部坏死/6-9_换一个角度_BEG.txt
# ./plot/主线/局部坏死/6-10_解开铃铛_END.txt
# ./plot/主线/局部坏死/6-11_“这种事”_BEG.txt
# ./plot/主线/局部坏死/6-11_“这种事”_END.txt
# ./plot/主线/局部坏死/6-12_冰原之雪_BEG.txt
# ./plot/主线/局部坏死/6-13_没有火,没有光_NBT.txt
# ./plot/主线/局部坏死/6-14_冰原之霜_END.txt
# ./plot/主线/局部坏死/6-15_不错的回忆_BEG.txt
# ./plot/主线/局部坏死/6-15_不错的回忆_END.txt
# ./plot/主线/局部坏死/6-16_黑兔子,白兔子_BEG.txt
# ./plot/主线/局部坏死/6-17_冬逝_END.txt
# ./plot/主线/局部坏死/6-18_只有你知道_NBT.txt
# ./plot/主线/苦难摇篮/7-1_32:00:00_NBT.txt
# ./plot/主线/苦难摇篮/7-2_别离之夜_BEG.txt
# ./plot/主线/苦难摇篮/7-2_别离之夜_END.txt
# ./plot/主线/苦难摇篮/7-3_变节之刃_BEG.txt
# ./plot/主线/苦难摇篮/7-3_变节之刃_END.txt
# ./plot/主线/苦难摇篮/7-4_并肩之约-1_BEG.txt
# ./plot/主线/苦难摇篮/7-5_并肩之约-2_END.txt
# ./plot/主线/苦难摇篮/7-6_遗忘之地_BEG.txt
# ./plot/主线/苦难摇篮/7-6_遗忘之地_END.txt
# ./plot/主线/苦难摇篮/7-7_26:37:14_NBT.txt
# ./plot/主线/苦难摇篮/7-8_沉默者之怒-1_BEG.txt
# ./plot/主线/苦难摇篮/7-9_沉默者之怒-2_END.txt
# ./plot/主线/苦难摇篮/7-10_暗淡者之火_BEG.txt
# ./plot/主线/苦难摇篮/7-10_暗淡者之火_END.txt
# ./plot/主线/苦难摇篮/7-13_感染者之盾-1_BEG.txt
# ./plot/主线/苦难摇篮/7-17_感染者之盾-2_END.txt
# ./plot/主线/苦难摇篮/7-18_爱国者之死_BEG.txt
# ./plot/主线/苦难摇篮/7-18_爱国者之死_END.txt
# ./plot/主线/苦难摇篮/7-19_11:15:38_NBT.txt
# ./plot/主线/苦难摇篮/7-20_??:??:??_NBT.txt
# ./plot/主线/怒号光明/R8-1_昨日，谷壳将裂_BEG.txt
# ./plot/主线/怒号光明/R8-1_昨日，谷壳将裂_END.txt
# ./plot/主线/怒号光明/M8-1_今日，血色满溢_NBT.txt
# ./plot/主线/怒号光明/R8-3_麦秆，极易燃烧_BEG.txt
# ./plot/主线/怒号光明/R8-3_麦秆，极易燃烧_END.txt
# ./plot/主线/怒号光明/M8-2_失语，产自多言_NBT.txt
# ./plot/主线/怒号光明/R8-4_火种，一触即灭_BEG.txt
# ./plot/主线/怒号光明/R8-4_火种，一触即灭_END.txt
# ./plot/主线/怒号光明/M8-3_死亡，召之即来_NBT.txt
# ./plot/主线/怒号光明/R8-5_寒冷，来自知觉_BEG.txt
# ./plot/主线/怒号光明/R8-5_寒冷，来自知觉_END.txt
# ./plot/主线/怒号光明/M8-4_意志，片缕幻影_NBT.txt
# ./plot/主线/怒号光明/R8-6_战场，蔓延不止_BEG.txt
# ./plot/主线/怒号光明/R8-6_战场，蔓延不止_END.txt
# ./plot/主线/怒号光明/M8-5_厄运，等候已久_NBT.txt
# ./plot/主线/怒号光明/R8-8_人心，向背无常_BEG.txt
# ./plot/主线/怒号光明/R8-8_人心，向背无常_END.txt
# ./plot/主线/怒号光明/M8-6_再见，只为再见_BEG.txt
# ./plot/主线/怒号光明/M8-6_再见，只为再见_END.txt
# ./plot/主线/怒号光明/R8-9_相逢，总是离别_BEG.txt
# ./plot/主线/怒号光明/R8-9_相逢，总是离别_END.txt
# ./plot/主线/怒号光明/M8-7_恶言，报应不爽_BEG.txt
# ./plot/主线/怒号光明/M8-7_恶言，报应不爽_END.txt
# ./plot/主线/怒号光明/R8-11_落雪，浸黑国土_BEG.txt
# ./plot/主线/怒号光明/R8-11_落雪，浸黑国土_END.txt
# ./plot/主线/怒号光明/M8-8_苏醒，浮出梦乡_BEG.txt
# ./plot/主线/怒号光明/M8-8_苏醒，浮出梦乡_END.txt
# ./plot/主线/怒号光明/JT8-1_恨火，流向原野_BEG.txt
# ./plot/主线/怒号光明/JT8-1_恨火，流向原野_END.txt
# ./plot/主线/怒号光明/JT8-2_睁眼，便是日暮_BEG.txt
# ./plot/主线/怒号光明/JT8-2_睁眼，便是日暮_END.txt
# ./plot/主线/怒号光明/JT8-3_昂首，足践烈焰_BEG.txt
# ./plot/主线/怒号光明/JT8-3_昂首，足践烈焰_END.txt
# ./plot/主线/怒号光明/END8-1_尾声，抑或开始_NBT.txt
# ./plot/主线/怒号光明/EG-1_燃烧的片段1_NBT.txt
# ./plot/主线/怒号光明/EG-2_燃烧的片段2_NBT.txt
# ./plot/主线/怒号光明/EG-3_燃烧的片段3_NBT.txt
# ./plot/主线/怒号光明/EG-4_燃烧的片段4_NBT.txt
# ./plot/主线/怒号光明/EG-5_燃烧的片段5_NBT.txt
# ./plot/主线/风暴瞭望/9-1_风暴突击_NBT.txt
# ./plot/主线/风暴瞭望/9-2_鬼魂危机_BEG.txt
# ./plot/主线/风暴瞭望/9-3_牌局_END.txt
# ./plot/主线/风暴瞭望/9-4_暗火四起_BEG.txt
# ./plot/主线/风暴瞭望/9-4_暗火四起_END.txt
# ./plot/主线/风暴瞭望/9-5_临界值_BEG.txt
# ./plot/主线/风暴瞭望/9-5_临界值_END.txt
# ./plot/主线/风暴瞭望/9-6_深池_BEG.txt
# ./plot/主线/风暴瞭望/9-7_捉迷藏_END.txt
# ./plot/主线/风暴瞭望/9-8_灰烬中的诗_NBT.txt
# ./plot/主线/风暴瞭望/9-9_无辜者_BEG.txt
# ./plot/主线/风暴瞭望/9-10_雷声轰鸣_END.txt
# ./plot/主线/风暴瞭望/9-12_鬼影如潮_BEG.txt
# ./plot/主线/风暴瞭望/9-13_战地救援_END.txt
# ./plot/主线/风暴瞭望/9-14_风中旗帜_BEG.txt
# ./plot/主线/风暴瞭望/9-18_“破晓”_END.txt
# ./plot/主线/风暴瞭望/9-19_长夜枪火_BEG.txt
# ./plot/主线/风暴瞭望/9-19_长夜枪火_END.txt
# ./plot/主线/风暴瞭望/9-20_临近的暴风_NBT.txt
# ./plot/主线/风暴瞭望/9-21_重燃_NBT.txt
# ./plot/主线/破碎日冕/10-1_被追逐者_NBT.txt
# ./plot/主线/破碎日冕/10-2_抢夺目标_BEG.txt
# ./plot/主线/破碎日冕/10-2_抢夺目标_END.txt
# ./plot/主线/破碎日冕/10-3_低下头_BEG.txt
# ./plot/主线/破碎日冕/10-3_低下头_END.txt
# ./plot/主线/破碎日冕/10-4_鸣铳示警_BEG.txt
# ./plot/主线/破碎日冕/10-4_鸣铳示警_END.txt
# ./plot/主线/破碎日冕/10-5_城市的呼吸_BEG.txt
# ./plot/主线/破碎日冕/10-5_城市的呼吸_END.txt
# ./plot/主线/破碎日冕/10-6_虽非同族_BEG.txt
# ./plot/主线/破碎日冕/10-6_虽非同族_END.txt
# ./plot/主线/破碎日冕/10-7_痛觉相连_BEG.txt
# ./plot/主线/破碎日冕/10-8_无暇哀悼_END.txt
# ./plot/主线/破碎日冕/10-9_他乡故知_BEG.txt
# ./plot/主线/破碎日冕/10-9_他乡故知_END.txt
# ./plot/主线/破碎日冕/10-10_旧日之影_BEG.txt
# ./plot/主线/破碎日冕/10-10_旧日之影_END.txt
# ./plot/主线/破碎日冕/10-11_千疮百孔_BEG.txt
# ./plot/主线/破碎日冕/10-12_仇怨的尽头_END.txt
# ./plot/主线/破碎日冕/10-13_交叉路口_NBT.txt
# ./plot/主线/破碎日冕/10-14_瞄准_BEG.txt
# ./plot/主线/破碎日冕/10-14_瞄准_END.txt
# ./plot/主线/破碎日冕/10-15_逃离炮火_BEG.txt
# ./plot/主线/破碎日冕/10-16_血刃高悬_END.txt
# ./plot/主线/破碎日冕/10-17_坚城高墙_BEG.txt
# ./plot/主线/破碎日冕/10-17_坚城高墙_END.txt
# ./plot/主线/破碎日冕/10-18_理想的倒影_NBT.txt
# ./plot/主线/破碎日冕/10-19_远方星火_NBT.txt
# ./plot/主线/淬火尘霾/11-1_维护荣耀_BEG.txt
# ./plot/主线/淬火尘霾/11-1_维护荣耀_END.txt
# ./plot/主线/淬火尘霾/11-2_一丝光亮_BEG.txt
# ./plot/主线/淬火尘霾/11-2_一丝光亮_END.txt
# ./plot/主线/淬火尘霾/11-3_蒸汽升腾_BEG.txt
# ./plot/主线/淬火尘霾/11-3_蒸汽升腾_END.txt
# ./plot/主线/淬火尘霾/11-4_何谓理想_NBT.txt
# ./plot/主线/淬火尘霾/11-5_等价交换_BEG.txt
# ./plot/主线/淬火尘霾/11-5_等价交换_END.txt
# ./plot/主线/淬火尘霾/11-6_演绎文明_BEG.txt
# ./plot/主线/淬火尘霾/11-7_卷入洪流_END.txt
# ./plot/主线/淬火尘霾/11-8_停滞_BEG.txt
# ./plot/主线/淬火尘霾/11-8_停滞_END.txt
# ./plot/主线/淬火尘霾/11-9_以命换命_BEG.txt
# ./plot/主线/淬火尘霾/11-9_以命换命_END.txt
# ./plot/主线/淬火尘霾/11-10_异路相对_NBT.txt
# ./plot/主线/淬火尘霾/11-11_立场不同_BEG.txt
# ./plot/主线/淬火尘霾/11-12_汹涌而来_END.txt
# ./plot/主线/淬火尘霾/11-14_一场相见_BEG.txt
# ./plot/主线/淬火尘霾/11-14_一场相见_END.txt
# ./plot/主线/淬火尘霾/11-15_土地震颤_BEG.txt
# ./plot/主线/淬火尘霾/11-16_荣光猎场_END.txt
# ./plot/主线/淬火尘霾/11-17_回答我_BEG.txt
# ./plot/主线/淬火尘霾/11-17_回答我_END.txt
# ./plot/主线/淬火尘霾/11-19_直指命运_BEG.txt
# ./plot/主线/淬火尘霾/11-19_直指命运_END.txt
# ./plot/主线/淬火尘霾/11-21_不可避免_NBT.txt
# ./plot/主线/惊霆无声/12-1_火光热浪_NBT.txt
# ./plot/主线/惊霆无声/12-2_静候驾临_BEG.txt
# ./plot/主线/惊霆无声/12-2_静候驾临_END.txt
# ./plot/主线/惊霆无声/12-3_善意背叛_BEG.txt
# ./plot/主线/惊霆无声/12-3_善意背叛_END.txt
# ./plot/主线/惊霆无声/12-4_团结就是奢望_BEG.txt
# ./plot/主线/惊霆无声/12-4_团结就是奢望_END.txt
# ./plot/主线/惊霆无声/12-5_脆钢_BEG.txt
# ./plot/主线/惊霆无声/12-6_谁的战争_END.txt
# ./plot/主线/惊霆无声/12-7_平议生死_BEG.txt
# ./plot/主线/惊霆无声/12-8_火线重逢_END.txt
# ./plot/主线/惊霆无声/12-9_热血年华_BEG.txt
# ./plot/主线/惊霆无声/12-10_广播热线正繁忙_END.txt
# ./plot/主线/惊霆无声/12-11_时不我待_NBT.txt
# ./plot/主线/惊霆无声/12-12_脱帽致敬_BEG.txt
# ./plot/主线/惊霆无声/12-13_逆光阴影_END.txt
# ./plot/主线/惊霆无声/12-14_捂住耳朵_BEG.txt
# ./plot/主线/惊霆无声/12-14_捂住耳朵_END.txt
# ./plot/主线/惊霆无声/12-15_千疮百孔_BEG.txt
# ./plot/主线/惊霆无声/12-15_千疮百孔_END.txt
# ./plot/主线/惊霆无声/12-16_天边的火烧云_BEG.txt
# ./plot/主线/惊霆无声/12-17_被弃之人_END.txt
# ./plot/主线/惊霆无声/12-18_晚安_BEG.txt
# ./plot/主线/惊霆无声/12-19_飞跃，烟火_END.txt
# ./plot/主线/惊霆无声/12-20_诚挚邀请_BEG.txt
# ./plot/主线/惊霆无声/12-20_诚挚邀请_END.txt
# ./plot/主线/惊霆无声/12-21_战场静悄悄_NBT.txt
# ./plot/主线/恶兆湍流/13-1_战场内外_NBT.txt
# ./plot/主线/恶兆湍流/13-2_眼前的伤_BEG.txt
# ./plot/主线/恶兆湍流/13-2_眼前的伤_END.txt
# ./plot/主线/恶兆湍流/13-3_不得暂歇_BEG.txt
# ./plot/主线/恶兆湍流/13-3_不得暂歇_END.txt
# ./plot/主线/恶兆湍流/13-4_佣兵一日_BEG.txt
# ./plot/主线/恶兆湍流/13-4_佣兵一日_END.txt
# ./plot/主线/恶兆湍流/13-5_苦厄盘桓_BEG.txt
# ./plot/主线/恶兆湍流/13-5_苦厄盘桓_END.txt
# ./plot/主线/恶兆湍流/13-6_典范之名_BEG.txt
# ./plot/主线/恶兆湍流/13-6_典范之名_END.txt
# ./plot/主线/恶兆湍流/TR-24_寻迹而行_BEG.txt
# ./plot/主线/恶兆湍流/13-8_不虞之会_END.txt
# ./plot/主线/恶兆湍流/13-9_窥冠冕者_NBT.txt
# ./plot/主线/恶兆湍流/13-10_幻境迁流_END.txt
# ./plot/主线/恶兆湍流/13-11_小镇翳云_BEG.txt
# ./plot/主线/恶兆湍流/13-12_破碎温室_BEG.txt
# ./plot/主线/恶兆湍流/13-14_猩红烟火_END.txt
# ./plot/主线/恶兆湍流/13-15_短暂齐聚_END.txt
# ./plot/主线/恶兆湍流/13-16_“我们”_BEG.txt
# ./plot/主线/恶兆湍流/13-16_“我们”_END.txt
# ./plot/主线/恶兆湍流/13-17_谁来倾诉_BEG.txt
# ./plot/主线/恶兆湍流/13-18_挺起胸膛_END.txt
# ./plot/主线/恶兆湍流/13-20_血潮翻涌_END.txt
# ./plot/主线/恶兆湍流/13-21_殷红君主_BEG.txt
# ./plot/主线/恶兆湍流/13-21_殷红君主_END.txt
# ./plot/主线/恶兆湍流/13-22_灾厄积渐_NBT.txt
# ./plot/主线/慈悲灯塔/14-1_从回忆中坠落_NBT.txt
# ./plot/主线/慈悲灯塔/14-2_作战对策会议_BEG.txt
# ./plot/主线/慈悲灯塔/14-2_作战对策会议_END.txt
# ./plot/主线/慈悲灯塔/14-3_破解锤砧战术_BEG.txt
# ./plot/主线/慈悲灯塔/14-3_破解锤砧战术_END.txt
# ./plot/主线/慈悲灯塔/14-4_通讯静默解除_BEG.txt
# ./plot/主线/慈悲灯塔/14-4_通讯静默解除_END.txt
# ./plot/主线/慈悲灯塔/14-5_探查岩洞区域_BEG.txt
# ./plot/主线/慈悲灯塔/14-5_探查岩洞区域_END.txt
# ./plot/主线/慈悲灯塔/14-6_确认交战视界_BEG.txt
# ./plot/主线/慈悲灯塔/14-6_确认交战视界_END.txt
# ./plot/主线/慈悲灯塔/14-7_执行反制作战_BEG.txt
# ./plot/主线/慈悲灯塔/14-7_执行反制作战_END.txt
# ./plot/主线/慈悲灯塔/14-8_抵近支援作战_BEG.txt
# ./plot/主线/慈悲灯塔/14-8_抵近支援作战_END.txt
# ./plot/主线/慈悲灯塔/14-9_应对饱和打击_BEG.txt
# ./plot/主线/慈悲灯塔/14-9_应对饱和打击_END.txt
# ./plot/主线/慈悲灯塔/14-10_自光辉中奔涌_BEG.txt
# ./plot/主线/慈悲灯塔/14-10_自光辉中奔涌_END.txt
# ./plot/主线/慈悲灯塔/14-11_所谓“英雄”_BEG.txt
# ./plot/主线/慈悲灯塔/14-11_所谓“英雄”_END.txt
# ./plot/主线/慈悲灯塔/14-12_使徒_BEG.txt
# ./plot/主线/慈悲灯塔/14-12_使徒_END.txt
# ./plot/主线/慈悲灯塔/14-13_自原点中降临_NBT.txt
# ./plot/主线/慈悲灯塔/14-14_高空拒阻行动_BEG.txt
# ./plot/主线/慈悲灯塔/14-15_突破外围防线_END.txt
# ./plot/主线/慈悲灯塔/14-16_抢占舷侧区域_BEG.txt
# ./plot/主线/慈悲灯塔/14-16_抢占舷侧区域_END.txt
# ./plot/主线/慈悲灯塔/14-17_核心舱攻防战_BEG.txt
# ./plot/主线/慈悲灯塔/14-18_在炽燃间咆哮_BEG.txt
# ./plot/主线/慈悲灯塔/14-18_在炽燃间咆哮_END.txt
# ./plot/主线/慈悲灯塔/14-19_晶簇之内_BEG.txt
# ./plot/主线/慈悲灯塔/14-19_晶簇之内_END.txt
# ./plot/主线/慈悲灯塔/14-20_列王行迹_BEG.txt
# ./plot/主线/慈悲灯塔/14-20_列王行迹_END.txt
# ./plot/主线/慈悲灯塔/14-21_万千愿景_BEG.txt
# ./plot/主线/慈悲灯塔/14-21_万千愿景_END.txt
# ./plot/主线/慈悲灯塔/14-22_在哀愁绽放的时刻_BEG.txt
# ./plot/主线/慈悲灯塔/14-22_在哀愁绽放的时刻_END.txt
# ./plot/主线/慈悲灯塔/14-23_良夜将死_NBT.txt
# ./plot/主线/慈悲灯塔/EG-6_慈悲遗愿_NBT.txt
# ./plot/剧情/特殊/APF-2020_NBT.txt
# ./plot/剧情/特殊/多维合作_剧情.txt
# ./plot/剧情/特殊/SL01_ENTRY.txt
# ./plot/刻俄柏的灰蕈迷境/集成战略/RO-BEG_NBT.txt
# ./plot/刻俄柏的灰蕈迷境/集成战略/RO-END-1_NBT.txt
# ./plot/刻俄柏的灰蕈迷境/集成战略/RO-END-2_NBT.txt
# ./plot/刻俄柏的灰蕈迷境/集成战略/RO-END-3_NBT.txt
# ./plot/沙中之火/生息演算/RA_ENTRY.txt
# ./plot/沙中之火/生息演算/RA-END-1_NBT.txt
# ./plot/沙中之火/生息演算/RA-END-2_NBT.txt
# ./plot/沙中之火/生息演算/RA-END-3_NBT.txt
# ./plot/支线/骑兵与猎人/GT-1_日正当中_BEG.txt
# ./plot/支线/骑兵与猎人/GT-1_日正当中_END.txt
# ./plot/支线/骑兵与猎人/GT-2_察言观色_BEG.txt
# ./plot/支线/骑兵与猎人/GT-2_察言观色_END.txt
# ./plot/支线/骑兵与猎人/GT-3_意外之旅_BEG.txt
# ./plot/支线/骑兵与猎人/GT-3_意外之旅_END.txt
# ./plot/支线/骑兵与猎人/GT-4_污点证人_BEG.txt
# ./plot/支线/骑兵与猎人/GT-4_污点证人_END.txt
# ./plot/支线/骑兵与猎人/GT-5_各抒己见_BEG.txt
# ./plot/支线/骑兵与猎人/GT-5_各抒己见_END.txt
# ./plot/支线/骑兵与猎人/GT-6_黄金三角_BEG.txt
# ./plot/支线/骑兵与猎人/GT-6_黄金三角_END.txt
# ./plot/支线/骑兵与猎人/GT-EX-1_大地惊雷_END.txt
# ./plot/支线/骑兵与猎人/GT-EX-3_与狼共舞_END.txt
# ./plot/支线/骑兵与猎人/GT-HX-1_碧血金沙_END.txt
# ./plot/支线/骑兵与猎人/GT-HX-3_西部往事_END.txt
# ./plot/支线/火蓝之心/火蓝之心_剧情.txt
# ./plot/支线/火蓝之心/OF-ST1_摇滚起来_NBT.txt
# ./plot/支线/火蓝之心/OF-1_火山制造_BEG.txt
# ./plot/支线/火蓝之心/OF-1_火山制造_END.txt
# ./plot/支线/火蓝之心/OF-ST2_冲破藩篱_NBT.txt
# ./plot/支线/火蓝之心/OF-2_演出继续_BEG.txt
# ./plot/支线/火蓝之心/OF-2_演出继续_END.txt
# ./plot/支线/火蓝之心/OF-3_竞走赛_BEG.txt
# ./plot/支线/火蓝之心/OF-3_竞走赛_END.txt
# ./plot/支线/火蓝之心/OF-4_他是将军_BEG.txt
# ./plot/支线/火蓝之心/OF-4_他是将军_END.txt
# ./plot/支线/火蓝之心/OF-ST3_压力之下_NBT.txt
# ./plot/支线/火蓝之心/OF-5_别阻止我_BEG.txt
# ./plot/支线/火蓝之心/OF-5_别阻止我_END.txt
# ./plot/支线/火蓝之心/OF-6_杀手女皇_BEG.txt
# ./plot/支线/火蓝之心/OF-6_杀手女皇_END.txt
# ./plot/支线/火蓝之心/OF-ST4_爱某个人_NBT.txt
# ./plot/支线/火蓝之心/OF-7_一锤定音_BEG.txt
# ./plot/支线/火蓝之心/OF-7_一锤定音_END.txt
# ./plot/支线/火蓝之心/OF-8_汐斯塔狂想曲_BEG.txt
# ./plot/支线/火蓝之心/OF-8_汐斯塔狂想曲_END.txt
# ./plot/支线/火蓝之心/OF-ST5_此生挚爱_NBT.txt
# ./plot/支线/火蓝之心/OF-ST6_邂逅潮声_NBT.txt
# ./plot/支线/火蓝之心/OF-EX1_预热活动_END.txt
# ./plot/支线/火蓝之心/OF-EX3_采访环节_END.txt
# ./plot/支线/火蓝之心/OF-EX6_完美落幕_END.txt
# ./plot/支线/喧闹法则/喧闹法则_剧情.txt
# ./plot/支线/喧闹法则/CB-1_6:44P.M._BEG.txt
# ./plot/支线/喧闹法则/CB-1_6:44P.M._END.txt
# ./plot/支线/喧闹法则/CB-2_7:15P.M._BEG.txt
# ./plot/支线/喧闹法则/CB-2_7:15P.M._END.txt
# ./plot/支线/喧闹法则/CB-3_7:22P.M._BEG.txt
# ./plot/支线/喧闹法则/CB-3_7:22P.M._END.txt
# ./plot/支线/喧闹法则/CB-4_7:59P.M._BEG.txt
# ./plot/支线/喧闹法则/CB-4_7:59P.M._END.txt
# ./plot/支线/喧闹法则/CB-5_8:31P.M._BEG.txt
# ./plot/支线/喧闹法则/CB-5_8:31P.M._END.txt
# ./plot/支线/喧闹法则/CB-ST1_晚风轻拂_NBT.txt
# ./plot/支线/喧闹法则/CB-6_10:26P.M._BEG.txt
# ./plot/支线/喧闹法则/CB-6_10:26P.M._END.txt
# ./plot/支线/喧闹法则/CB-7_11:08P.M._BEG.txt
# ./plot/支线/喧闹法则/CB-7_11:08P.M._END.txt
# ./plot/支线/喧闹法则/CB-8_11:41P.M._BEG.txt
# ./plot/支线/喧闹法则/CB-8_11:41P.M._END.txt
# ./plot/支线/喧闹法则/CB-ST2_午夜龙门_NBT.txt
# ./plot/支线/喧闹法则/CB-9_0:01A.M._BEG.txt
# ./plot/支线/喧闹法则/CB-9_0:01A.M._END.txt
# ./plot/支线/喧闹法则/CB-10_1:11A.M._BEG.txt
# ./plot/支线/喧闹法则/CB-10_1:11A.M._END.txt
# ./plot/支线/喧闹法则/CB-ST3_破晓时分_NBT.txt
# ./plot/支线/喧闹法则/CB-EX1_群架诀窍_END.txt
# ./plot/支线/喧闹法则/CB-EX2_南辕北辙_END.txt
# ./plot/支线/喧闹法则/CB-EX3_林中小屋_END.txt
# ./plot/支线/生于黑夜/DM-1_埋藏_BEG.txt
# ./plot/支线/生于黑夜/DM-1_埋藏_END.txt
# ./plot/支线/生于黑夜/DM-2_偶然_BEG.txt
# ./plot/支线/生于黑夜/DM-2_偶然_END.txt
# ./plot/支线/生于黑夜/DM-3_挤压_BEG.txt
# ./plot/支线/生于黑夜/DM-5_旗帜_END.txt
# ./plot/支线/生于黑夜/DM-6_远遁_BEG.txt
# ./plot/支线/生于黑夜/DM-6_远遁_END.txt
# ./plot/支线/生于黑夜/DM-7_龟裂_BEG.txt
# ./plot/支线/生于黑夜/DM-7_龟裂_END.txt
# ./plot/支线/生于黑夜/DM-8_离散_BEG.txt
# ./plot/支线/生于黑夜/DM-8_离散_END.txt
# ./plot/支线/生于黑夜/DM-ST-1_求生_NBT.txt
# ./plot/支线/沃伦姆德的薄暮/TW-ST-1_老栎树下_NBT.txt
# ./plot/支线/沃伦姆德的薄暮/TW-1_缄默不言_BEG.txt
# ./plot/支线/沃伦姆德的薄暮/TW-1_缄默不言_END.txt
# ./plot/支线/沃伦姆德的薄暮/TW-2_叛乱前哨_BEG.txt
# ./plot/支线/沃伦姆德的薄暮/TW-2_叛乱前哨_END.txt
# ./plot/支线/沃伦姆德的薄暮/TW-3_高塔烟火_BEG.txt
# ./plot/支线/沃伦姆德的薄暮/TW-3_高塔烟火_END.txt
# ./plot/支线/沃伦姆德的薄暮/TW-4_复仇之魂_BEG.txt
# ./plot/支线/沃伦姆德的薄暮/TW-4_复仇之魂_END.txt
# ./plot/支线/沃伦姆德的薄暮/TW-5_冬灵挽歌_BEG.txt
# ./plot/支线/沃伦姆德的薄暮/TW-5_冬灵挽歌_END.txt
# ./plot/支线/沃伦姆德的薄暮/TW-6_怒意漫延_BEG.txt
# ./plot/支线/沃伦姆德的薄暮/TW-6_怒意漫延_END.txt
# ./plot/支线/沃伦姆德的薄暮/TW-7_群峦崩塌_BEG.txt
# ./plot/支线/沃伦姆德的薄暮/TW-7_群峦崩塌_END.txt
# ./plot/支线/沃伦姆德的薄暮/TW-8_月光沉沦_BEG.txt
# ./plot/支线/沃伦姆德的薄暮/TW-8_月光沉沦_END.txt
# ./plot/支线/沃伦姆德的薄暮/TW-ST-2_余烬之上_NBT.txt
# ./plot/支线/沃伦姆德的薄暮/TW-S-1_三座巨像_END.txt
# ./plot/支线/沃伦姆德的薄暮/TW-S-2_一束哀悼_END.txt
# ./plot/支线/密林悍将归来/RI-1_高空坠物_BEG.txt
# ./plot/支线/密林悍将归来/RI-1_高空坠物_END.txt
# ./plot/支线/密林悍将归来/RI-2_粗细有别_BEG.txt
# ./plot/支线/密林悍将归来/RI-2_粗细有别_END.txt
# ./plot/支线/密林悍将归来/RI-3_往昔_BEG.txt
# ./plot/支线/密林悍将归来/RI-3_往昔_END.txt
# ./plot/支线/密林悍将归来/RI-4_机兽咆哮_BEG.txt
# ./plot/支线/密林悍将归来/RI-4_机兽咆哮_END.txt
# ./plot/支线/密林悍将归来/RI-ST-1_悍将之心_NBT.txt
# ./plot/支线/密林悍将归来/RI-5_各有所长_BEG.txt
# ./plot/支线/密林悍将归来/RI-5_各有所长_END.txt
# ./plot/支线/密林悍将归来/RI-6_邂逅_BEG.txt
# ./plot/支线/密林悍将归来/RI-6_邂逅_END.txt
# ./plot/支线/密林悍将归来/RI-ST-2_休息时间_NBT.txt
# ./plot/支线/密林悍将归来/RI-7_有客先来_BEG.txt
# ./plot/支线/密林悍将归来/RI-7_有客先来_END.txt
# ./plot/支线/密林悍将归来/RI-8_嘉维尔之拳_BEG.txt
# ./plot/支线/密林悍将归来/RI-8_嘉维尔之拳_END.txt
# ./plot/支线/密林悍将归来/RI-9_走出密林_BEG.txt
# ./plot/支线/密林悍将归来/RI-9_走出密林_END.txt
# ./plot/支线/密林悍将归来/RI-EX-1_声东击西_END.txt
# ./plot/支线/玛莉娅·临光/MN-ST-1_亮相_NBT.txt
# ./plot/支线/玛莉娅·临光/MN-1_艾伦精选_BEG.txt
# ./plot/支线/玛莉娅·临光/MN-1_艾伦精选_END.txt
# ./plot/支线/玛莉娅·临光/MN-2_呼啸守卫_BEG.txt
# ./plot/支线/玛莉娅·临光/MN-2_呼啸守卫_END.txt
# ./plot/支线/玛莉娅·临光/MN-3_玫瑰报业_BEG.txt
# ./plot/支线/玛莉娅·临光/MN-3_玫瑰报业_END.txt
# ./plot/支线/玛莉娅·临光/MN-4_辉煌盾工业_BEG.txt
# ./plot/支线/玛莉娅·临光/MN-4_辉煌盾工业_END.txt
# ./plot/支线/玛莉娅·临光/MN-5_斯沃玛视频_BEG.txt
# ./plot/支线/玛莉娅·临光/MN-5_斯沃玛视频_END.txt
# ./plot/支线/玛莉娅·临光/MN-6_蓝耳酒窖_BEG.txt
# ./plot/支线/玛莉娅·临光/MN-6_蓝耳酒窖_END.txt
# ./plot/支线/玛莉娅·临光/MN-7_梅什科集团_BEG.txt
# ./plot/支线/玛莉娅·临光/MN-7_梅什科集团_END.txt
# ./plot/支线/玛莉娅·临光/MN-ST-2_酒杯_NBT.txt
# ./plot/支线/玛莉娅·临光/MN-8_商业联合_BEG.txt
# ./plot/支线/玛莉娅·临光/MN-8_商业联合_END.txt
# ./plot/支线/玛莉娅·临光/MN-ST-3_缄默启程_NBT.txt
# ./plot/支线/孤岛风云/MB-1_密会_BEG.txt
# ./plot/支线/孤岛风云/MB-1_密会_END.txt
# ./plot/支线/孤岛风云/MB-2_另一个视角_BEG.txt
# ./plot/支线/孤岛风云/MB-2_另一个视角_END.txt
# ./plot/支线/孤岛风云/MB-3_首次遇袭_BEG.txt
# ./plot/支线/孤岛风云/MB-3_首次遇袭_END.txt
# ./plot/支线/孤岛风云/MB-ST-1_邀请_NBT.txt
# ./plot/支线/孤岛风云/MB-4_勇敢，莽撞_BEG.txt
# ./plot/支线/孤岛风云/MB-4_勇敢，莽撞_END.txt
# ./plot/支线/孤岛风云/MB-5_危险交易_BEG.txt
# ./plot/支线/孤岛风云/MB-5_危险交易_END.txt
# ./plot/支线/孤岛风云/MB-6_制定计划_BEG.txt
# ./plot/支线/孤岛风云/MB-6_制定计划_END.txt
# ./plot/支线/孤岛风云/MB-7_背叛_BEG.txt
# ./plot/支线/孤岛风云/MB-7_背叛_END.txt
# ./plot/支线/孤岛风云/MB-8_激战之末_BEG.txt
# ./plot/支线/孤岛风云/MB-8_激战之末_END.txt
# ./plot/支线/孤岛风云/MB-ST-2_正确的代价_NBT.txt
# ./plot/支线/画中人/WR-ST-1_一钳之恩_NBT.txt
# ./plot/支线/画中人/WR-1_初醒_BEG.txt
# ./plot/支线/画中人/WR-1_初醒_END.txt
# ./plot/支线/画中人/WR-2_墨魉_BEG.txt
# ./plot/支线/画中人/WR-2_墨魉_END.txt
# ./plot/支线/画中人/WR-4_掌柜_BEG.txt
# ./plot/支线/画中人/WR-4_掌柜_END.txt
# ./plot/支线/画中人/WR-5_拙山_BEG.txt
# ./plot/支线/画中人/WR-5_拙山_END.txt
# ./plot/支线/画中人/WR-ST-2_一日之祸_NBT.txt
# ./plot/支线/画中人/WR-6_画中_BEG.txt
# ./plot/支线/画中人/WR-6_画中_END.txt
# ./plot/支线/画中人/WR-8_大梦_BEG.txt
# ./plot/支线/画中人/WR-8_大梦_END.txt
# ./plot/支线/画中人/WR-10_夕_BEG.txt
# ./plot/支线/画中人/WR-10_夕_END.txt
# ./plot/支线/画中人/WR-ST-3_一问之答_NBT.txt
# ./plot/支线/源石尘行动/OD-ST-1_拉马克行动_NBT.txt
# ./plot/支线/源石尘行动/OD-1_外勤记录_BEG.txt
# ./plot/支线/源石尘行动/OD-1_外勤记录_END.txt
# ./plot/支线/源石尘行动/OD-2_扩大防守范围_BEG.txt
# ./plot/支线/源石尘行动/OD-2_扩大防守范围_END.txt
# ./plot/支线/源石尘行动/OD-3_安全屋攻防战_BEG.txt
# ./plot/支线/源石尘行动/OD-3_安全屋攻防战_END.txt
# ./plot/支线/源石尘行动/OD-5_物资回收计划_BEG.txt
# ./plot/支线/源石尘行动/OD-5_物资回收计划_END.txt
# ./plot/支线/源石尘行动/OD-6_领主宅邸攻防战_BEG.txt
# ./plot/支线/源石尘行动/OD-6_领主宅邸攻防战_END.txt
# ./plot/支线/源石尘行动/OD-ST-2_一场葬礼_NBT.txt
# ./plot/支线/源石尘行动/OD-7_地堡防线_BEG.txt
# ./plot/支线/源石尘行动/OD-7_地堡防线_END.txt
# ./plot/支线/源石尘行动/OD-8_渗透作战_BEG.txt
# ./plot/支线/源石尘行动/OD-8_渗透作战_END.txt
# ./plot/支线/源石尘行动/OD-ST-3_行走于大地之上_NBT.txt
# ./plot/支线/遗尘漫步/WD-1_赤角小镇之围_BEG.txt
# ./plot/支线/遗尘漫步/WD-1_赤角小镇之围_END.txt
# ./plot/支线/遗尘漫步/WD-2_绿洲惊雷_BEG.txt
# ./plot/支线/遗尘漫步/WD-2_绿洲惊雷_END.txt
# ./plot/支线/遗尘漫步/WD-3_仙人掌沙丘_BEG.txt
# ./plot/支线/遗尘漫步/WD-3_仙人掌沙丘_END.txt
# ./plot/支线/遗尘漫步/WD-ST-1_松心百合_NBT.txt
# ./plot/支线/遗尘漫步/WD-5_沁礁之地_BEG.txt
# ./plot/支线/遗尘漫步/WD-5_沁礁之地_END.txt
# ./plot/支线/遗尘漫步/WD-7_家园_BEG.txt
# ./plot/支线/遗尘漫步/WD-7_家园_END.txt
# ./plot/支线/遗尘漫步/WD-8_大雪将至_BEG.txt
# ./plot/支线/遗尘漫步/WD-8_大雪将至_END.txt
# ./plot/支线/遗尘漫步/WD-ST-2_异乡来客_NBT.txt
# ./plot/支线/覆潮之下/SV-1_闯入者_BEG.txt
# ./plot/支线/覆潮之下/SV-1_闯入者_END.txt
# ./plot/支线/覆潮之下/SV-2_歌手_BEG.txt
# ./plot/支线/覆潮之下/SV-2_歌手_END.txt
# ./plot/支线/覆潮之下/SV-3_外来者_BEG.txt
# ./plot/支线/覆潮之下/SV-3_外来者_END.txt
# ./plot/支线/覆潮之下/SV-4_海洋_BEG.txt
# ./plot/支线/覆潮之下/SV-5_遭弃者_END.txt
# ./plot/支线/覆潮之下/SV-6_厌食_BEG.txt
# ./plot/支线/覆潮之下/SV-6_厌食_END.txt
# ./plot/支线/覆潮之下/SV-7_守护者_BEG.txt
# ./plot/支线/覆潮之下/SV-7_守护者_END.txt
# ./plot/支线/覆潮之下/SV-ST-1_唤醒噩梦_NBT.txt
# ./plot/支线/覆潮之下/SV-8_亲族_BEG.txt
# ./plot/支线/覆潮之下/SV-8_亲族_END.txt
# ./plot/支线/覆潮之下/SV-9_笃信者_BEG.txt
# ./plot/支线/覆潮之下/SV-9_笃信者_END.txt
# ./plot/支线/覆潮之下/SV-ST-2_侥幸离去_NBT.txt
# ./plot/支线/多索雷斯假日/DH-ST-1_不期而遇_NBT.txt
# ./plot/支线/多索雷斯假日/DH-TR-1_初来乍到_END.txt
# ./plot/支线/多索雷斯假日/DH-1_意外入选_BEG.txt
# ./plot/支线/多索雷斯假日/DH-1_意外入选_END.txt
# ./plot/支线/多索雷斯假日/DH-2_首轮竞赛_BEG.txt
# ./plot/支线/多索雷斯假日/DH-2_首轮竞赛_END.txt
# ./plot/支线/多索雷斯假日/DH-3_拔铳相助_BEG.txt
# ./plot/支线/多索雷斯假日/DH-3_拔铳相助_END.txt
# ./plot/支线/多索雷斯假日/DH-ST-2_中场休息_NBT.txt
# ./plot/支线/多索雷斯假日/DH-4_铁人三项_BEG.txt
# ./plot/支线/多索雷斯假日/DH-4_铁人三项_END.txt
# ./plot/支线/多索雷斯假日/DH-5_曲径求胜_BEG.txt
# ./plot/支线/多索雷斯假日/DH-5_曲径求胜_END.txt
# ./plot/支线/多索雷斯假日/DH-6_紧追猛赶_BEG.txt
# ./plot/支线/多索雷斯假日/DH-6_紧追猛赶_END.txt
# ./plot/支线/多索雷斯假日/DH-ST-3_请君入瓮_NBT.txt
# ./plot/支线/多索雷斯假日/DH-7_沙滩阻击_BEG.txt
# ./plot/支线/多索雷斯假日/DH-8_抢滩登陆_END.txt
# ./plot/支线/多索雷斯假日/DH-9_鼠胆龙威_BEG.txt
# ./plot/支线/多索雷斯假日/DH-9_鼠胆龙威_END.txt
# ./plot/支线/多索雷斯假日/DH-ST-4_海浪照常拍岸_NBT.txt
# ./plot/支线/长夜临光/NL-ST-1_欣欣向荣_NBT.txt
# ./plot/支线/长夜临光/NL-1_金盏花_BEG.txt
# ./plot/支线/长夜临光/NL-1_金盏花_END.txt
# ./plot/支线/长夜临光/NL-2_垂死的刺_BEG.txt
# ./plot/支线/长夜临光/NL-2_垂死的刺_END.txt
# ./plot/支线/长夜临光/NL-3_筹备着_BEG.txt
# ./plot/支线/长夜临光/NL-3_筹备着_END.txt
# ./plot/支线/长夜临光/NL-4_诗的容貌_BEG.txt
# ./plot/支线/长夜临光/NL-4_诗的容貌_END.txt
# ./plot/支线/长夜临光/NL-ST-2_权与力_NBT.txt
# ./plot/支线/长夜临光/NL-5_人言可畏_BEG.txt
# ./plot/支线/长夜临光/NL-5_人言可畏_END.txt
# ./plot/支线/长夜临光/NL-6_被包围者_BEG.txt
# ./plot/支线/长夜临光/NL-6_被包围者_END.txt
# ./plot/支线/长夜临光/NL-ST-3_酣眠的城市_NBT.txt
# ./plot/支线/长夜临光/NL-7_梦的余韵_BEG.txt
# ./plot/支线/长夜临光/NL-7_梦的余韵_END.txt
# ./plot/支线/长夜临光/NL-8_最后的怯薛_BEG.txt
# ./plot/支线/长夜临光/NL-8_最后的怯薛_END.txt
# ./plot/支线/长夜临光/NL-9_叹息_BEG.txt
# ./plot/支线/长夜临光/NL-9_叹息_END.txt
# ./plot/支线/长夜临光/NL-10_耀骑士_BEG.txt
# ./plot/支线/长夜临光/NL-10_耀骑士_END.txt
# ./plot/支线/长夜临光/NL-ST-4_未知与未来_NBT.txt
# ./plot/支线/风雪过境/BI-1_不欢而聚_BEG.txt
# ./plot/支线/风雪过境/BI-1_不欢而聚_END.txt
# ./plot/支线/风雪过境/BI-ST-1_入乡随俗_NBT.txt
# ./plot/支线/风雪过境/BI-2_息事宁人_BEG.txt
# ./plot/支线/风雪过境/BI-2_息事宁人_END.txt
# ./plot/支线/风雪过境/BI-3_人心难测_BEG.txt
# ./plot/支线/风雪过境/BI-3_人心难测_END.txt
# ./plot/支线/风雪过境/BI-ST-2_山雪欲来_NBT.txt
# ./plot/支线/风雪过境/BI-4_立雪求道_BEG.txt
# ./plot/支线/风雪过境/BI-4_立雪求道_END.txt
# ./plot/支线/风雪过境/BI-5_猎场_BEG.txt
# ./plot/支线/风雪过境/BI-5_猎场_END.txt
# ./plot/支线/风雪过境/BI-ST-3_一着不慎_NBT.txt
# ./plot/支线/风雪过境/BI-6_歧路_BEG.txt
# ./plot/支线/风雪过境/BI-6_歧路_END.txt
# ./plot/支线/风雪过境/BI-7_破冰_BEG.txt
# ./plot/支线/风雪过境/BI-7_破冰_END.txt
# ./plot/支线/风雪过境/BI-8_将军_BEG.txt
# ./plot/支线/风雪过境/BI-8_将军_END.txt
# ./plot/支线/风雪过境/BI-ST-4_封盘_NBT.txt
# ./plot/支线/将进酒/IW-ST-1_客将至_NBT.txt
# ./plot/支线/将进酒/IW-1_化物_BEG.txt
# ./plot/支线/将进酒/IW-1_化物_END.txt
# ./plot/支线/将进酒/IW-2_无寻处_BEG.txt
# ./plot/支线/将进酒/IW-2_无寻处_END.txt
# ./plot/支线/将进酒/IW-3_光与影_BEG.txt
# ./plot/支线/将进酒/IW-3_光与影_END.txt
# ./plot/支线/将进酒/IW-4_秉烛_BEG.txt
# ./plot/支线/将进酒/IW-4_秉烛_END.txt
# ./plot/支线/将进酒/IW-ST-2_万物有灵_NBT.txt
# ./plot/支线/将进酒/IW-5_货与人_BEG.txt
# ./plot/支线/将进酒/IW-5_货与人_END.txt
# ./plot/支线/将进酒/IW-6_传说_BEG.txt
# ./plot/支线/将进酒/IW-6_传说_END.txt
# ./plot/支线/将进酒/IW-7_乱局_BEG.txt
# ./plot/支线/将进酒/IW-7_乱局_END.txt
# ./plot/支线/将进酒/IW-9_岁相_BEG.txt
# ./plot/支线/将进酒/IW-9_岁相_END.txt
# ./plot/支线/将进酒/IW-ST-3_再弈_NBT.txt
# ./plot/支线/吾导先路/GA-ST-1_风云际会_NBT.txt
# ./plot/支线/吾导先路/GA-1_灯下黑_BEG.txt
# ./plot/支线/吾导先路/GA-1_灯下黑_END.txt
# ./plot/支线/吾导先路/GA-2_散步时光_BEG.txt
# ./plot/支线/吾导先路/GA-2_散步时光_END.txt
# ./plot/支线/吾导先路/GA-3_混血儿_BEG.txt
# ./plot/支线/吾导先路/GA-3_混血儿_END.txt
# ./plot/支线/吾导先路/GA-4_安魂教堂_BEG.txt
# ./plot/支线/吾导先路/GA-4_安魂教堂_END.txt
# ./plot/支线/吾导先路/GA-5_葬礼_BEG.txt
# ./plot/支线/吾导先路/GA-5_葬礼_END.txt
# ./plot/支线/吾导先路/GA-6_安魂曲_BEG.txt
# ./plot/支线/吾导先路/GA-6_安魂曲_END.txt
# ./plot/支线/吾导先路/GA-7_光与影_BEG.txt
# ./plot/支线/吾导先路/GA-7_光与影_END.txt
# ./plot/支线/吾导先路/GA-8_影与灰_BEG.txt
# ./plot/支线/吾导先路/GA-8_影与灰_END.txt
# ./plot/支线/吾导先路/GA-ST-2_鸢尾花_NBT.txt
# ./plot/支线/愚人号/SN-ST-1_古井_NBT.txt
# ./plot/支线/愚人号/SN-1_中心广场_BEG.txt
# ./plot/支线/愚人号/SN-1_中心广场_END.txt
# ./plot/支线/愚人号/SN-ST-2_海滨小道_NBT.txt
# ./plot/支线/愚人号/SN-2_广场南路_END.txt
# ./plot/支线/愚人号/SN-ST-3_空旷的大街_NBT.txt
# ./plot/支线/愚人号/SN-3_安静的步道_END.txt
# ./plot/支线/愚人号/SN-ST-4_临海长街_NBT.txt
# ./plot/支线/愚人号/SN-ST-5_登陆点_NBT.txt
# ./plot/支线/愚人号/SN-4_灯塔入口_END.txt
# ./plot/支线/愚人号/SN-5_灯塔控制室_BEG.txt
# ./plot/支线/愚人号/SN-5_灯塔控制室_END.txt
# ./plot/支线/愚人号/SN-6_中央通道_BEG.txt
# ./plot/支线/愚人号/SN-ST-6_下层大厅_NBT.txt
# ./plot/支线/愚人号/SN-ST-7_宴会厅_NBT.txt
# ./plot/支线/愚人号/SN-7_黄金回廊_END.txt
# ./plot/支线/愚人号/SN-ST-8_指挥大厅_NBT.txt
# ./plot/支线/愚人号/SN-ST-9_主舰桥_NBT.txt
# ./plot/支线/愚人号/SN-8_观测所_END.txt
# ./plot/支线/愚人号/SN-ST-10_甲板室_NBT.txt
# ./plot/支线/愚人号/SN-ST-11_主桅杆_NBT.txt
# ./plot/支线/愚人号/SN-10_礼仪广场_BEG.txt
# ./plot/支线/愚人号/SN-10_礼仪广场_END.txt
# ./plot/支线/愚人号/SN-ST-12_格兰法洛_NBT.txt
# ./plot/支线/尘影余音/LE-ST-1_华丽大圆舞曲_NBT.txt
# ./plot/支线/尘影余音/LE-1_闲聊波尔卡_BEG.txt
# ./plot/支线/尘影余音/LE-1_闲聊波尔卡_END.txt
# ./plot/支线/尘影余音/LE-2_热情，或悲怆_BEG.txt
# ./plot/支线/尘影余音/LE-2_热情，或悲怆_END.txt
# ./plot/支线/尘影余音/LE-3_自由射手_BEG.txt
# ./plot/支线/尘影余音/LE-3_自由射手_END.txt
# ./plot/支线/尘影余音/LE-4_惊愕_BEG.txt
# ./plot/支线/尘影余音/LE-4_惊愕_END.txt
# ./plot/支线/尘影余音/LE-ST-2_春之祭_NBT.txt
# ./plot/支线/尘影余音/LE-5_月光_BEG.txt
# ./plot/支线/尘影余音/LE-5_月光_END.txt
# ./plot/支线/尘影余音/LE-6_骷髅之舞_BEG.txt
# ./plot/支线/尘影余音/LE-6_骷髅之舞_END.txt
# ./plot/支线/尘影余音/LE-7_升华之夜_BEG.txt
# ./plot/支线/尘影余音/LE-7_升华之夜_END.txt
# ./plot/支线/尘影余音/LE-8_命运_BEG.txt
# ./plot/支线/尘影余音/LE-8_命运_END.txt
# ./plot/支线/尘影余音/LE-ST-3_自新大陆_NBT.txt
# ./plot/支线/绿野幻梦/DV-ST-1_逆行_NBT.txt
# ./plot/支线/绿野幻梦/DV-1_特里蒙街道_BEG.txt
# ./plot/支线/绿野幻梦/DV-1_特里蒙街道_END.txt
# ./plot/支线/绿野幻梦/DV-2_拓荒者小屋_BEG.txt
# ./plot/支线/绿野幻梦/DV-2_拓荒者小屋_END.txt
# ./plot/支线/绿野幻梦/DV-3_动力装甲_BEG.txt
# ./plot/支线/绿野幻梦/DV-3_动力装甲_END.txt
# ./plot/支线/绿野幻梦/DV-4_无人的小巷_BEG.txt
# ./plot/支线/绿野幻梦/DV-4_无人的小巷_END.txt
# ./plot/支线/绿野幻梦/DV-5_多萝西的承诺_BEG.txt
# ./plot/支线/绿野幻梦/DV-S-1_困心_NBT.txt
# ./plot/支线/绿野幻梦/DV-5_多萝西的承诺_END.txt
# ./plot/支线/绿野幻梦/DV-6_挣脱美梦_BEG.txt
# ./plot/支线/绿野幻梦/DV-6_挣脱美梦_END.txt
# ./plot/支线/绿野幻梦/DV-7_疯狂的信号_BEG.txt
# ./plot/支线/绿野幻梦/DV-S-2_衡虑_NBT.txt
# ./plot/支线/绿野幻梦/DV-7_疯狂的信号_END.txt
# ./plot/支线/绿野幻梦/DV-8_连接内心_BEG.txt
# ./plot/支线/绿野幻梦/DV-8_连接内心_END.txt
# ./plot/支线/绿野幻梦/DV-ST-2_启程_NBT.txt
# ./plot/支线/理想城：长夏狂欢季/IC-ST-1_旅行前夕_NBT.txt
# ./plot/支线/理想城：长夏狂欢季/IC-1_沉浸式游览_BEG.txt
# ./plot/支线/理想城：长夏狂欢季/IC-1_沉浸式游览_END.txt
# ./plot/支线/理想城：长夏狂欢季/IC-2_下坠_BEG.txt
# ./plot/支线/理想城：长夏狂欢季/IC-2_下坠_END.txt
# ./plot/支线/理想城：长夏狂欢季/IC-3_奇谈怪论_BEG.txt
# ./plot/支线/理想城：长夏狂欢季/IC-3_奇谈怪论_END.txt
# ./plot/支线/理想城：长夏狂欢季/IC-4_“大水坑”_BEG.txt
# ./plot/支线/理想城：长夏狂欢季/IC-4_“大水坑”_END.txt
# ./plot/支线/理想城：长夏狂欢季/IC-5_加速冲线_BEG.txt
# ./plot/支线/理想城：长夏狂欢季/IC-5_加速冲线_END.txt
# ./plot/支线/理想城：长夏狂欢季/IC-6_战逃反应_BEG.txt
# ./plot/支线/理想城：长夏狂欢季/IC-6_战逃反应_END.txt
# ./plot/支线/理想城：长夏狂欢季/IC-7_生活之道_BEG.txt
# ./plot/支线/理想城：长夏狂欢季/IC-7_生活之道_END.txt
# ./plot/支线/理想城：长夏狂欢季/IC-8_金属气味_BEG.txt
# ./plot/支线/理想城：长夏狂欢季/IC-9_穹顶之上_END.txt
# ./plot/支线/理想城：长夏狂欢季/IC-ST-2_失乐园_NBT.txt
# ./plot/支线/叙拉古人/IS-ST-1_沉疴_NBT.txt
# ./plot/支线/叙拉古人/IS-1_雨落无声_BEG.txt
# ./plot/支线/叙拉古人/IS-1_雨落无声_END.txt
# ./plot/支线/叙拉古人/IS-2_荣誉之人_BEG.txt
# ./plot/支线/叙拉古人/IS-2_荣誉之人_END.txt
# ./plot/支线/叙拉古人/IS-3_万箭所指_BEG.txt
# ./plot/支线/叙拉古人/IS-3_万箭所指_END.txt
# ./plot/支线/叙拉古人/IS-4_苦夜惊雷_BEG.txt
# ./plot/支线/叙拉古人/IS-4_苦夜惊雷_END.txt
# ./plot/支线/叙拉古人/IS-ST-2_切开_NBT.txt
# ./plot/支线/叙拉古人/IS-5_恒久法则_BEG.txt
# ./plot/支线/叙拉古人/IS-5_恒久法则_END.txt
# ./plot/支线/叙拉古人/IS-6_旧日碾轧_BEG.txt
# ./plot/支线/叙拉古人/IS-6_旧日碾轧_END.txt
# ./plot/支线/叙拉古人/IS-7_何以忘却_BEG.txt
# ./plot/支线/叙拉古人/IS-7_何以忘却_END.txt
# ./plot/支线/叙拉古人/IS-8_危如累卵_BEG.txt
# ./plot/支线/叙拉古人/IS-8_危如累卵_END.txt
# ./plot/支线/叙拉古人/IS-ST-3_剜刺_NBT.txt
# ./plot/支线/叙拉古人/IS-9_文明的谎言_BEG.txt
# ./plot/支线/叙拉古人/IS-9_文明的谎言_END.txt
# ./plot/支线/叙拉古人/IS-10_“狼之主”_BEG.txt
# ./plot/支线/叙拉古人/IS-10_“狼之主”_END.txt
# ./plot/支线/叙拉古人/IS-ST-4_缝合_NBT.txt
# ./plot/支线/照我以火/FC-ST-1_荒地钟声_NBT.txt
# ./plot/支线/照我以火/FC-1_逃离与追逐_BEG.txt
# ./plot/支线/照我以火/FC-1_逃离与追逐_END.txt
# ./plot/支线/照我以火/FC-2_不幸重逢_BEG.txt
# ./plot/支线/照我以火/FC-2_不幸重逢_END.txt
# ./plot/支线/照我以火/FC-3_引燃草垛_BEG.txt
# ./plot/支线/照我以火/FC-3_引燃草垛_END.txt
# ./plot/支线/照我以火/FC-4_热灼梦_BEG.txt
# ./plot/支线/照我以火/FC-4_热灼梦_END.txt
# ./plot/支线/照我以火/FC-5_祝福的歌谣_BEG.txt
# ./plot/支线/照我以火/FC-5_祝福的歌谣_END.txt
# ./plot/支线/照我以火/FC-6_无人知晓_END.txt
# ./plot/支线/照我以火/FC-7_生灵火花_BEG.txt
# ./plot/支线/照我以火/FC-7_生灵火花_END.txt
# ./plot/支线/照我以火/FC-ST-2_自灰烬之中_NBT.txt
# ./plot/支线/照我以火/FC-8_她的影子_BEG.txt
# ./plot/支线/照我以火/FC-8_她的影子_END.txt
# ./plot/支线/照我以火/FC-ST-3_一声呜咽_NBT.txt
# ./plot/支线/登临意/WB-ST-1_忽梦少年事_NBT.txt
# ./plot/支线/登临意/WB-1_塞上春来_BEG.txt
# ./plot/支线/登临意/WB-1_塞上春来_END.txt
# ./plot/支线/登临意/WB-2_沙海黄尘_BEG.txt
# ./plot/支线/登临意/WB-2_沙海黄尘_END.txt
# ./plot/支线/登临意/WB-3_树犹如此_BEG.txt
# ./plot/支线/登临意/WB-3_树犹如此_END.txt
# ./plot/支线/登临意/WB-4_不念往昔_BEG.txt
# ./plot/支线/登临意/WB-4_不念往昔_END.txt
# ./plot/支线/登临意/WB-ST-2_信我所信_NBT.txt
# ./plot/支线/登临意/WB-5_风雨欲来_BEG.txt
# ./plot/支线/登临意/WB-6_瑟瑟秋华_END.txt
# ./plot/支线/登临意/WB-7_“屏风卫”_BEG.txt
# ./plot/支线/登临意/WB-7_“屏风卫”_END.txt
# ./plot/支线/登临意/WB-8_旷古之晤_BEG.txt
# ./plot/支线/登临意/WB-8_旷古之晤_END.txt
# ./plot/支线/登临意/WB-9_“冬藏”_BEG.txt
# ./plot/支线/登临意/WB-9_“冬藏”_END.txt
# ./plot/支线/登临意/WB-ST-3_粘劫收后_NBT.txt
# ./plot/支线/落叶逐火/CF-ST-1_噩梦_NBT.txt
# ./plot/支线/落叶逐火/CF-TR-1_来袭！天空王者！_BEG.txt
# ./plot/支线/落叶逐火/CF-TR-1_来袭！天空王者！_END.txt
# ./plot/支线/落叶逐火/CF-2_坚硬磐石_BEG.txt
# ./plot/支线/落叶逐火/CF-2_坚硬磐石_END.txt
# ./plot/支线/落叶逐火/CF-3_迎头痛击_BEG.txt
# ./plot/支线/落叶逐火/CF-4_破空的飞羽_END.txt
# ./plot/支线/落叶逐火/CF-ST-2_林昏焰明_NBT.txt
# ./plot/支线/落叶逐火/CF-5_野蛮肇事者_BEG.txt
# ./plot/支线/落叶逐火/CF-5_野蛮肇事者_END.txt
# ./plot/支线/落叶逐火/CF-6_禁飞区_BEG.txt
# ./plot/支线/落叶逐火/CF-6_禁飞区_END.txt
# ./plot/支线/落叶逐火/CF-7_锥心之刺_BEG.txt
# ./plot/支线/落叶逐火/CF-7_锥心之刺_END.txt
# ./plot/支线/落叶逐火/CF-8_奸诈者必自食恶果_BEG.txt
# ./plot/支线/落叶逐火/CF-8_奸诈者必自食恶果_END.txt
# ./plot/支线/落叶逐火/CF-9_决战！燃烧的狩魂！_BEG.txt
# ./plot/支线/落叶逐火/CF-9_决战！燃烧的狩魂！_END.txt
# ./plot/支线/落叶逐火/CF-ST-3_晨曦_NBT.txt
# ./plot/支线/孤星/CW-ST-1_阴云密布_NBT.txt
# ./plot/支线/孤星/CW-1_迷雾重重_BEG.txt
# ./plot/支线/孤星/CW-1_迷雾重重_END.txt
# ./plot/支线/孤星/CW-2_无迹可寻_BEG.txt
# ./plot/支线/孤星/CW-2_无迹可寻_END.txt
# ./plot/支线/孤星/CW-3_台前幕后_BEG.txt
# ./plot/支线/孤星/CW-3_台前幕后_END.txt
# ./plot/支线/孤星/CW-ST-2_一波未平_NBT.txt
# ./plot/支线/孤星/CW-4_一波又起_BEG.txt
# ./plot/支线/孤星/CW-4_一波又起_END.txt
# ./plot/支线/孤星/CW-5_柳暗花明_BEG.txt
# ./plot/支线/孤星/CW-5_柳暗花明_END.txt
# ./plot/支线/孤星/CW-6_群英荟萃_BEG.txt
# ./plot/支线/孤星/CW-6_群英荟萃_END.txt
# ./plot/支线/孤星/CW-7_空中楼阁_BEG.txt
# ./plot/支线/孤星/CW-7_空中楼阁_END.txt
# ./plot/支线/孤星/CW-8_过去与现在的交会_BEG.txt
# ./plot/支线/孤星/CW-8_过去与现在的交会_END.txt
# ./plot/支线/孤星/CW-9_恩怨纠葛_BEG.txt
# ./plot/支线/孤星/CW-9_恩怨纠葛_END.txt
# ./plot/支线/孤星/CW-10_散于星辰之间_BEG.txt
# ./plot/支线/孤星/CW-10_散于星辰之间_END.txt
# ./plot/支线/孤星/CW-ST-3_留下的人_NBT.txt
# ./plot/支线/孤星/CW-ST-4_推开未来之门_NBT.txt
# ./plot/支线/空想花庭/HE-ST-1_奉上冠冕_NBT.txt
# ./plot/支线/空想花庭/HE-1_我有一个荣美家乡_BEG.txt
# ./plot/支线/空想花庭/HE-1_我有一个荣美家乡_END.txt
# ./plot/支线/空想花庭/HE-2_生命运河_BEG.txt
# ./plot/支线/空想花庭/HE-2_生命运河_END.txt
# ./plot/支线/空想花庭/HE-3_岂可空手回天府？_BEG.txt
# ./plot/支线/空想花庭/HE-3_岂可空手回天府？_END.txt
# ./plot/支线/空想花庭/HE-4_我曾舍命为你_BEG.txt
# ./plot/支线/空想花庭/HE-4_我曾舍命为你_END.txt
# ./plot/支线/空想花庭/HE-5_主在圣殿中_BEG.txt
# ./plot/支线/空想花庭/HE-5_主在圣殿中_END.txt
# ./plot/支线/空想花庭/HE-6_夜半歌声_BEG.txt
# ./plot/支线/空想花庭/HE-6_夜半歌声_END.txt
# ./plot/支线/空想花庭/HE-ST-2_在花园里_NBT.txt
# ./plot/支线/空想花庭/HE-7_以爱相连_BEG.txt
# ./plot/支线/空想花庭/HE-7_以爱相连_END.txt
# ./plot/支线/空想花庭/HE-8_愿跟随主_BEG.txt
# ./plot/支线/空想花庭/HE-8_愿跟随主_END.txt
# ./plot/支线/空想花庭/HE-ST-3_慈光引导_NBT.txt
# ./plot/支线/火山旅梦/SL-ST-1_到站旁_NBT.txt
# ./plot/支线/火山旅梦/SL-1_你的耳朵长不长？_BEG.txt
# ./plot/支线/火山旅梦/SL-1_你的耳朵长不长？_END.txt
# ./plot/支线/火山旅梦/SL-2_小蓝孩_BEG.txt
# ./plot/支线/火山旅梦/SL-2_小蓝孩_END.txt
# ./plot/支线/火山旅梦/SL-3_手指之家_BEG.txt
# ./plot/支线/火山旅梦/SL-3_手指之家_END.txt
# ./plot/支线/火山旅梦/SL-4_一个水手出海了_BEG.txt
# ./plot/支线/火山旅梦/SL-4_一个水手出海了_END.txt
# ./plot/支线/火山旅梦/SL-5_我会唱一首彩虹_BEG.txt
# ./plot/支线/火山旅梦/SL-5_我会唱一首彩虹_END.txt
# ./plot/支线/火山旅梦/SL-ST-2_雨啊，雨啊，快离开_NBT.txt
# ./plot/支线/火山旅梦/SL-6_林中小木屋_BEG.txt
# ./plot/支线/火山旅梦/SL-6_林中小木屋_END.txt
# ./plot/支线/火山旅梦/SL-7_靠着我的肩膀哭泣_BEG.txt
# ./plot/支线/火山旅梦/SL-7_靠着我的肩膀哭泣_END.txt
# ./plot/支线/火山旅梦/SL-8_爱之歌_BEG.txt
# ./plot/支线/火山旅梦/SL-8_爱之歌_END.txt
# ./plot/支线/火山旅梦/SL-ST-3_晴天_NBT.txt
# ./plot/支线/不义之财/CV-ST-1_火线之中_NBT.txt
# ./plot/支线/不义之财/CV-1_孤独之地_BEG.txt
# ./plot/支线/不义之财/CV-1_孤独之地_END.txt
# ./plot/支线/不义之财/CV-2_双重保险_BEG.txt
# ./plot/支线/不义之财/CV-2_双重保险_END.txt
# ./plot/支线/不义之财/CV-3_圈套_BEG.txt
# ./plot/支线/不义之财/CV-3_圈套_END.txt
# ./plot/支线/不义之财/CV-4_缺席的人_BEG.txt
# ./plot/支线/不义之财/CV-4_缺席的人_END.txt
# ./plot/支线/不义之财/CV-ST-2_突然冲击_NBT.txt
# ./plot/支线/不义之财/CV-5_疑惑之影_BEG.txt
# ./plot/支线/不义之财/CV-5_疑惑之影_END.txt
# ./plot/支线/不义之财/CV-6_猎人之夜_BEG.txt
# ./plot/支线/不义之财/CV-6_猎人之夜_END.txt
# ./plot/支线/不义之财/CV-7_白热_BEG.txt
# ./plot/支线/不义之财/CV-7_白热_END.txt
# ./plot/支线/不义之财/CV-8_告别往昔_BEG.txt
# ./plot/支线/不义之财/CV-8_告别往昔_END.txt
# ./plot/支线/不义之财/CV-ST-3_法外之徒_NBT.txt
# ./plot/支线/崔林特尔梅之金/ZT-ST-1_前奏“意外归来”_NBT.txt
# ./plot/支线/崔林特尔梅之金/ZT-1_清唱“晴空之歌”_BEG.txt
# ./plot/支线/崔林特尔梅之金/ZT-1_清唱“晴空之歌”_END.txt
# ./plot/支线/崔林特尔梅之金/ZT-2_序曲“哨兵”_BEG.txt
# ./plot/支线/崔林特尔梅之金/ZT-2_序曲“哨兵”_END.txt
# ./plot/支线/崔林特尔梅之金/ZT-3_练习曲“奇遇”_BEG.txt
# ./plot/支线/崔林特尔梅之金/ZT-3_练习曲“奇遇”_END.txt
# ./plot/支线/崔林特尔梅之金/ZT-4_狂想曲“望想”_BEG.txt
# ./plot/支线/崔林特尔梅之金/ZT-4_狂想曲“望想”_END.txt
# ./plot/支线/崔林特尔梅之金/ZT-5_奏鸣曲“秋日”_BEG.txt
# ./plot/支线/崔林特尔梅之金/ZT-5_奏鸣曲“秋日”_END.txt
# ./plot/支线/崔林特尔梅之金/ZT-ST-2_间奏“未竟赋格”_NBT.txt
# ./plot/支线/崔林特尔梅之金/ZT-6_华尔兹“假面”_BEG.txt
# ./plot/支线/崔林特尔梅之金/ZT-6_华尔兹“假面”_END.txt
# ./plot/支线/崔林特尔梅之金/ZT-7_协奏曲“复活”_BEG.txt
# ./plot/支线/崔林特尔梅之金/ZT-7_协奏曲“复活”_END.txt
# ./plot/支线/崔林特尔梅之金/ZT-8_夜歌“未见的高塔”_BEG.txt
# ./plot/支线/崔林特尔梅之金/ZT-8_夜歌“未见的高塔”_END.txt
# ./plot/支线/崔林特尔梅之金/ZT-9_幻想曲“赠答”_BEG.txt
# ./plot/支线/崔林特尔梅之金/ZT-9_幻想曲“赠答”_END.txt
# ./plot/支线/崔林特尔梅之金/ZT-10_弥撒“君王”_BEG.txt
# ./plot/支线/崔林特尔梅之金/ZT-10_弥撒“君王”_END.txt
# ./plot/支线/崔林特尔梅之金/ZT-ST-3_尾奏“晚霞”_NBT.txt
# ./plot/支线/银心湖列车/RS-ST-1_候车大厅_NBT.txt
# ./plot/支线/银心湖列车/RS-1_注意事项_BEG.txt
# ./plot/支线/银心湖列车/RS-1_注意事项_END.txt
# ./plot/支线/银心湖列车/RS-2_同车异图_BEG.txt
# ./plot/支线/银心湖列车/RS-2_同车异图_END.txt
# ./plot/支线/银心湖列车/RS-3_临时停车_BEG.txt
# ./plot/支线/银心湖列车/RS-3_临时停车_END.txt
# ./plot/支线/银心湖列车/RS-4_重回正轨_BEG.txt
# ./plot/支线/银心湖列车/RS-4_重回正轨_END.txt
# ./plot/支线/银心湖列车/RS-ST-2_登山铁道_NBT.txt
# ./plot/支线/银心湖列车/RS-5_逃票？_BEG.txt
# ./plot/支线/银心湖列车/RS-5_逃票？_END.txt
# ./plot/支线/银心湖列车/RS-6_补票！_BEG.txt
# ./plot/支线/银心湖列车/RS-6_补票！_END.txt
# ./plot/支线/银心湖列车/RS-7_制动失灵_BEG.txt
# ./plot/支线/银心湖列车/RS-7_制动失灵_END.txt
# ./plot/支线/银心湖列车/RS-8_极限时速_BEG.txt
# ./plot/支线/银心湖列车/RS-8_极限时速_END.txt
# ./plot/支线/银心湖列车/RS-ST-3_终点站_NBT.txt
# ./plot/支线/怀黍离/HS-ST-1_禾下梦_NBT.txt
# ./plot/支线/怀黍离/HS-1_赴大荒_BEG.txt
# ./plot/支线/怀黍离/HS-1_赴大荒_END.txt
# ./plot/支线/怀黍离/HS-2_祭神农_BEG.txt
# ./plot/支线/怀黍离/HS-2_祭神农_END.txt
# ./plot/支线/怀黍离/HS-3_早芒种_BEG.txt
# ./plot/支线/怀黍离/HS-3_早芒种_END.txt
# ./plot/支线/怀黍离/HS-4_话桑麻_BEG.txt
# ./plot/支线/怀黍离/HS-4_话桑麻_END.txt
# ./plot/支线/怀黍离/HS-5_纺绫罗_BEG.txt
# ./plot/支线/怀黍离/HS-5_纺绫罗_END.txt
# ./plot/支线/怀黍离/HS-ST-2_织锦缎_NBT.txt
# ./plot/支线/怀黍离/HS-6_卷赤霞_BEG.txt
# ./plot/支线/怀黍离/HS-7_梦四时_END.txt
# ./plot/支线/怀黍离/HS-8_种因_BEG.txt
# ./plot/支线/怀黍离/HS-8_种因_END.txt
# ./plot/支线/怀黍离/HS-9_得果_BEG.txt
# ./plot/支线/怀黍离/HS-9_得果_END.txt
# ./plot/支线/怀黍离/HS-ST-3_彻风雨_NBT.txt
# ./plot/支线/水晶箭行动/CR-ST-1_特别参观通道_NBT.txt
# ./plot/支线/水晶箭行动/CR-1_城市主题展_BEG.txt
# ./plot/支线/水晶箭行动/CR-1_城市主题展_END.txt
# ./plot/支线/水晶箭行动/CR-2_不对称庭园_BEG.txt
# ./plot/支线/水晶箭行动/CR-2_不对称庭园_END.txt
# ./plot/支线/水晶箭行动/CR-3_假面舞池_BEG.txt
# ./plot/支线/水晶箭行动/CR-3_假面舞池_END.txt
# ./plot/支线/水晶箭行动/CR-4_非传统艺术空间_BEG.txt
# ./plot/支线/水晶箭行动/CR-4_非传统艺术空间_END.txt
# ./plot/支线/水晶箭行动/CR-5_消防通道_BEG.txt
# ./plot/支线/水晶箭行动/CR-5_消防通道_END.txt
# ./plot/支线/水晶箭行动/CR-6_反艺术运动_BEG.txt
# ./plot/支线/水晶箭行动/CR-6_反艺术运动_END.txt
# ./plot/支线/水晶箭行动/CR-ST-2_策展人会客厅_NBT.txt
# ./plot/支线/水晶箭行动/CR-7_安全出口_BEG.txt
# ./plot/支线/水晶箭行动/CR-7_安全出口_END.txt
# ./plot/支线/水晶箭行动/CR-8_一跃而下_BEG.txt
# ./plot/支线/水晶箭行动/CR-8_一跃而下_END.txt
# ./plot/支线/水晶箭行动/CR-ST-3_艺术馆餐厅_NBT.txt
# ./plot/支线/巴别塔/BB-ST-1_未完成的告别_NBT.txt
# ./plot/支线/巴别塔/BB-1_宏伟愿景_BEG.txt
# ./plot/支线/巴别塔/BB-1_宏伟愿景_END.txt
# ./plot/支线/巴别塔/BB-2_命途何在_BEG.txt
# ./plot/支线/巴别塔/BB-2_命途何在_END.txt
# ./plot/支线/巴别塔/BB-3_无声破裂_BEG.txt
# ./plot/支线/巴别塔/BB-3_无声破裂_END.txt
# ./plot/支线/巴别塔/BB-ST-2_在疲惫中苏醒_NBT.txt
# ./plot/支线/巴别塔/BB-4_悠长的旅途_BEG.txt
# ./plot/支线/巴别塔/BB-4_悠长的旅途_END.txt
# ./plot/支线/巴别塔/BB-5_激变烽烟_BEG.txt
# ./plot/支线/巴别塔/BB-5_激变烽烟_END.txt
# ./plot/支线/巴别塔/BB-6_灯火闪烁不定_BEG.txt
# ./plot/支线/巴别塔/BB-6_灯火闪烁不定_END.txt
# ./plot/支线/巴别塔/BB-7_阴影显现_BEG.txt
# ./plot/支线/巴别塔/BB-7_阴影显现_END.txt
# ./plot/支线/巴别塔/BB-8_终局倒计时_BEG.txt
# ./plot/支线/巴别塔/BB-8_终局倒计时_END.txt
# ./plot/支线/巴别塔/BB-9_尘埃落定_BEG.txt
# ./plot/支线/巴别塔/BB-9_尘埃落定_END.txt
# ./plot/支线/巴别塔/BB-10_再见，再见_BEG.txt
# ./plot/支线/巴别塔/BB-10_再见，再见_END.txt
# ./plot/支线/巴别塔/BB-ST-3_灵魂尽头_NBT.txt
# ./plot/支线/生路/BP-ST-1_浪潮守望者_NBT.txt
# ./plot/支线/生路/BP-1_第一次接触_BEG.txt
# ./plot/支线/生路/BP-1_第一次接触_END.txt
# ./plot/支线/生路/BP-2_评议式迎接_BEG.txt
# ./plot/支线/生路/BP-2_评议式迎接_END.txt
# ./plot/支线/生路/BP-3_如海雪纷散_BEG.txt
# ./plot/支线/生路/BP-3_如海雪纷散_END.txt
# ./plot/支线/生路/BP-4_牺牲与代价_BEG.txt
# ./plot/支线/生路/BP-4_牺牲与代价_END.txt
# ./plot/支线/生路/BP-5_不治的命运_BEG.txt
# ./plot/支线/生路/BP-5_不治的命运_END.txt
# ./plot/支线/生路/BP-6_阿戈尔失格_BEG.txt
# ./plot/支线/生路/BP-6_阿戈尔失格_END.txt
# ./plot/支线/生路/BP-ST-2_如海流倒灌_NBT.txt
# ./plot/支线/生路/BP-7_从历史中来_BEG.txt
# ./plot/支线/生路/BP-7_从历史中来_END.txt
# ./plot/支线/生路/BP-8_“何谓存续？”_BEG.txt
# ./plot/支线/生路/BP-8_“何谓存续？”_END.txt
# ./plot/支线/生路/BP-ST-3_歧路者与同行者_NBT.txt
# ./plot/剧情/战地秘闻/SW-ST1_无名氏的战争_NBT.txt
# ./plot/剧情/战地秘闻/SW-ST2_破局者_NBT.txt
# ./plot/剧情/战地秘闻/SW-ST3_射击训练_NBT.txt
# ./plot/剧情/战地秘闻/SW-ST4_存续公正_NBT.txt
# ./plot/剧情/战地秘闻/SW-ST5_课后作业_NBT.txt
# ./plot/剧情/战地秘闻/SW-ST6_北极星_NBT.txt
# ./plot/剧情/战地秘闻/SW-ST7_和光同尘_NBT.txt
# ./plot/剧情/洪炉示岁/AF-ST1_洪炉示岁·迎春_NBT.txt
# ./plot/剧情/洪炉示岁/AF-ST2_洪炉示岁·贺岁_NBT.txt
# ./plot/剧情/洪炉示岁/AF-ST3_洪炉示岁·拜年_NBT.txt
# ./plot/剧情/午间逸话/SA-ST1_来办联欢会吧_NBT.txt
# ./plot/剧情/午间逸话/SA-ST2_日记本_NBT.txt
# ./plot/剧情/午间逸话/SA-ST3_今日厨房_NBT.txt
# ./plot/剧情/午间逸话/SA-ST4_流浪者的归宿_NBT.txt
# ./plot/剧情/午间逸话/SA-ST5_自讨苦吃_NBT.txt
# ./plot/剧情/午间逸话/SA-ST6_向前走_NBT.txt
# ./plot/剧情/乌萨斯的孩子们/SV-ST1_习惯_NBT.txt
# ./plot/剧情/乌萨斯的孩子们/SV-ST2_被选择的_NBT.txt
# ./plot/剧情/乌萨斯的孩子们/SV-ST3_在梦中相遇_NBT.txt
# ./plot/剧情/乌萨斯的孩子们/SV-ST4_表里不一_NBT.txt
# ./plot/剧情/乌萨斯的孩子们/SV-ST5_胡言秘语_NBT.txt
# ./plot/剧情/乌萨斯的孩子们/SV-ST6_一切照常_NBT.txt
# ./plot/剧情/乌萨斯的孩子们/SV-ST7_在春天之前_NBT.txt
# ./plot/剧情/踏寻往昔之风/FA-ST1_归处_NBT.txt
# ./plot/剧情/踏寻往昔之风/FA-ST2_域外同族_NBT.txt
# ./plot/剧情/踏寻往昔之风/FA-ST3_不知返_NBT.txt
# ./plot/剧情/踏寻往昔之风/FA-ST4_回首_NBT.txt
# ./plot/剧情/踏寻往昔之风/FA-ST5_四月的歌_NBT.txt
# ./plot/剧情/踏寻往昔之风/FA-ST6_交错光影_NBT.txt
# ./plot/剧情/踏寻往昔之风/FA-ST7_天空的故事_NBT.txt
# ./plot/剧情/此地之外/BH-ST1_无续集_NBT.txt
# ./plot/剧情/此地之外/BH-ST2_荒野路漫漫_NBT.txt
# ./plot/剧情/此地之外/BH-ST3_童话永存_NBT.txt
# ./plot/剧情/此地之外/BH-ST4_信仰号街车_NBT.txt
# ./plot/剧情/此地之外/BH-ST5_盲盒旅途_NBT.txt
# ./plot/剧情/此地之外/BH-ST6_剑与天秤_NBT.txt
# ./plot/剧情/此地之外/BH-ST7_为更好的自己_NBT.txt
# ./plot/剧情/灯火序曲/PL-ST1_粉碎大地_NBT.txt
# ./plot/剧情/灯火序曲/PL-ST2_烁烁星火_NBT.txt
# ./plot/剧情/灯火序曲/PL-ST3_真假怪谈_NBT.txt
# ./plot/剧情/灯火序曲/PL-ST4_遗落灯塔_NBT.txt
# ./plot/剧情/灯火序曲/PL-ST5_异类_NBT.txt
# ./plot/剧情/灯火序曲/PL-ST6_信_NBT.txt
# ./plot/剧情/如我所见/VI-ST1_我不曾怀揣希望_NBT.txt
# ./plot/剧情/如我所见/VI-ST2_我不会全部遗忘_NBT.txt
# ./plot/剧情/如我所见/VI-ST3_我不知是否值得_NBT.txt
# ./plot/剧情/如我所见/VI-ST4_我所思不止于此_NBT.txt
# ./plot/剧情/如我所见/VI-ST5_我无惧前路何往_NBT.txt
# ./plot/剧情/如我所见/VI-ST6_我与最后的赌注_NBT.txt
# ./plot/剧情/红松林/PS-ST1_红松_NBT.txt
# ./plot/剧情/红松林/PS-ST2_落灰_NBT.txt
# ./plot/剧情/红松林/PS-ST3_我也要大干一场_NBT.txt
# ./plot/剧情/红松林/PS-ST4_只影孤身_NBT.txt
# ./plot/剧情/红松林/PS-ST5_骑士之道_NBT.txt
# ./plot/剧情/红松林/PS-ST6_大人物_NBT.txt
# ./plot/剧情/红松林/PS-ST7_随风飘荡_NBT.txt
# ./plot/剧情/阴云火花/TB-ST1_或许有时_NBT.txt
# ./plot/剧情/阴云火花/TB-ST2_我如浮萍_NBT.txt
# ./plot/剧情/阴云火花/TB-ST3_终将同行_NBT.txt
# ./plot/剧情/阴云火花/TB-ST4_孤行骑警_NBT.txt
# ./plot/剧情/阴云火花/TB-ST5_必有所偿_NBT.txt
# ./plot/剧情/阴云火花/TB-ST6_叮咚作响_NBT.txt
# ./plot/剧情/未尽篇章/TC-ST1_布朗陶_NBT.txt
# ./plot/剧情/未尽篇章/TC-ST2_后会有期_NBT.txt
# ./plot/剧情/未尽篇章/TC-ST3_狼与狼群_NBT.txt
# ./plot/剧情/未尽篇章/TC-ST4_再见罗伊_NBT.txt
# ./plot/剧情/未尽篇章/TC-ST5_和而不同_NBT.txt
# ./plot/剧情/未尽篇章/TC-ST6_真实故事_NBT.txt
# ./plot/剧情/日暮寻路/AW-ST1_荒舍_NBT.txt
# ./plot/剧情/日暮寻路/AW-ST2_只见星辰_NBT.txt
# ./plot/剧情/日暮寻路/AW-ST3_我曾凝望_NBT.txt
# ./plot/剧情/日暮寻路/AW-ST4_不得安宁_NBT.txt
# ./plot/剧情/日暮寻路/AW-ST5_日落已久_NBT.txt
# ./plot/剧情/日暮寻路/AW-ST6_空盔甲_NBT.txt
# ./plot/剧情/日暮寻路/AW-ST7_告别词_NBT.txt
# ./plot/剧情/好久不见/BW-ST1_向左向右_NBT.txt
# ./plot/剧情/好久不见/BW-ST2_隔墙有你_NBT.txt
# ./plot/剧情/好久不见/BW-ST3_扬尼与我_NBT.txt
# ./plot/剧情/好久不见/BW-ST4_告别时刻_NBT.txt
# ./plot/剧情/好久不见/BW-ST5_一次重逢_NBT.txt
# ./plot/剧情/好久不见/BW-ST6_别太紧张_NBT.txt
# ./plot/剧情/春分/DC-ST1_近乡情怯_NBT.txt
# ./plot/剧情/春分/DC-ST2_中庭旅谷_NBT.txt
# ./plot/剧情/春分/DC-ST3_不问鬼神_NBT.txt
# ./plot/剧情/春分/DC-ST4_出入平安_NBT.txt
# ./plot/剧情/春分/DC-ST5_无名之辈_NBT.txt
# ./plot/剧情/春分/DC-ST6_独见寒山_NBT.txt
# ./plot/剧情/眠于树影之中/FD-ST1_沉于冰寒_NBT.txt
# ./plot/剧情/眠于树影之中/FD-ST2_冰原的女儿_NBT.txt
# ./plot/剧情/眠于树影之中/FD-ST3_树影幢幢_NBT.txt
# ./plot/剧情/眠于树影之中/FD-ST4_自然的启示_NBT.txt
# ./plot/剧情/眠于树影之中/FD-ST5_归乡_NBT.txt
# ./plot/剧情/眠于树影之中/FD-ST6_终有一日_NBT.txt
# ./plot/剧情/眠于树影之中/FD-ST7_未见之景_NBT.txt
# ./plot/剧情/去咧嘴谷/TG-ST1_盖不住的锅盖_NBT.txt
# ./plot/剧情/去咧嘴谷/TG-ST2_不回头的车辙_NBT.txt
# ./plot/剧情/去咧嘴谷/TG-ST3_狂奔的瓶树_NBT.txt
# ./plot/剧情/去咧嘴谷/TG-ST4_落定的锤子_NBT.txt
# ./plot/剧情/去咧嘴谷/TG-ST5_咧嘴的矿井_NBT.txt
# ./plot/剧情/去咧嘴谷/TG-ST6_被踩住的影子_NBT.txt
# ./plot/剧情/特殊/隐藏剧情_剧情.txt
# ./plot/剧情/特殊/采购中心_剧情.txt
# ./plot/剧情/特殊/EP09_ENTRY.txt
# ./plot/剧情/特殊/EP10_ENTRY.txt
# ./plot/剧情/特殊/EP11_ENTRY.txt
# ./plot/剧情/特殊/EP12_ENTRY.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 23
#      21         exception.append(i)
#      22 print("./plot/"+i["folder"]+i["filename"]+".txt")
# ---> 23 time.sleep(1)
#
# KeyboardInterrupt:

# %%
import tqdm
for i in tqdm.tqdm(plot_names):
    write_files(i["folder"]+i["filename"])
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 3578/3578 [02:10<00:00, 27.43it/s]

# %%
exception
# Out:
# []

# %%
import os
plots = []
for path, folder, files in os.walk("./plot/"):
    for i in files:
        if i[-4:] == ".txt":
            plots.append(path.replace("./plot/","") +"/"+ i[:-4])
plots

# %%
#获取公网IP地址
import requests
def get_public_ip():
    response = requests.get("http://httpbin.org/ip")
    data = response.json()
    ip = data['origin']
    return ip

# %%
get_public_ip()
# Out:
# '111.201.148.179'

# %%
import requests
x = requests.get("http://172.17.0.4:8000/docs")
x
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/miniconda3/envs/study/lib/python3.9/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/miniconda3/envs/study/lib/python3.9/site-packages/urllib3/util/connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~/miniconda3/envs/study/lib/python3.9/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# TimeoutError: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/miniconda3/envs/study/lib/python3.9/site-packages/urllib3/connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#
# File ~/miniconda3/envs/study/lib/python3.9/site-packages/urllib3/connectionpool.py:416, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     415     else:
# --> 416         conn.request(method, url, **httplib_request_kw)
#     418 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     419 # legitimately able to close the connection after sending a valid response.
#     420 # With this behaviour, the received response is still readable.
#
# File ~/miniconda3/envs/study/lib/python3.9/site-packages/urllib3/connection.py:244, in HTTPConnection.request(self, method, url, body, headers)
#     243     headers["User-Agent"] = _get_default_user_agent()
# --> 244 super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#
# File ~/miniconda3/envs/study/lib/python3.9/http/client.py:1285, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1284 """Send a complete request to the server."""
# -> 1285 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~/miniconda3/envs/study/lib/python3.9/http/client.py:1331, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1330     body = _encode(body, 'body')
# -> 1331 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~/miniconda3/envs/study/lib/python3.9/http/client.py:1280, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1279     raise CannotSendHeader()
# -> 1280 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~/miniconda3/envs/study/lib/python3.9/http/client.py:1040, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1039 del self._buffer[:]
# -> 1040 self.send(msg)
#    1042 if message_body is not None:
#    1043
#    1044     # create a consistent interface to message_body
#
# File ~/miniconda3/envs/study/lib/python3.9/http/client.py:980, in HTTPConnection.send(self, data)
#     979 if self.auto_open:
# --> 980     self.connect()
#     981 else:
#
# File ~/miniconda3/envs/study/lib/python3.9/site-packages/urllib3/connection.py:205, in HTTPConnection.connect(self)
#     204 def connect(self):
# --> 205     conn = self._new_conn()
#     206     self._prepare_conn(conn)
#
# File ~/miniconda3/envs/study/lib/python3.9/site-packages/urllib3/connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f4c60471940>: Failed to establish a new connection: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/miniconda3/envs/study/lib/python3.9/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~/miniconda3/envs/study/lib/python3.9/site-packages/urllib3/connectionpool.py:799, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     797     e = ProtocolError("Connection aborted.", e)
# --> 799 retries = retries.increment(
#     800     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     801 )
#     802 retries.sleep()
#
# File ~/miniconda3/envs/study/lib/python3.9/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='172.17.0.4', port=8000): Max retries exceeded with url: /docs (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4c60471940>: Failed to establish a new connection: [Errno 110] Connection timed out'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[1], line 2
#       1 import requests
# ----> 2 x = requests.get("http://172.17.0.4:8000/docs")
#       3 x
#
# File ~/miniconda3/envs/study/lib/python3.9/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniconda3/envs/study/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/envs/study/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/envs/study/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/study/lib/python3.9/site-packages/requests/adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#     522     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPConnectionPool(host='172.17.0.4', port=8000): Max retries exceeded with url: /docs (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4c60471940>: Failed to establish a new connection: [Errno 110] Connection timed out'))
