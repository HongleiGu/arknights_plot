# %% [markdown]
# # api

# %%
from typing import Union
import os
import uvicorn
import copy
import urllib
from io import BytesIO
from fastapi import FastAPI#, Response
import nest_asyncio
# from transformers import AutoModelForCausalLM, AutoTokenizer
# import torch
import json
import random
app = FastAPI()
from typing import Optional
from pydantic import BaseModel
#第二步导入相应的模块
import urllib
from fastapi.middleware.cors import CORSMiddleware
app.add_middleware(
    CORSMiddleware,
    allow_origins=["*"],
    allow_credentials=True,
    allow_methods=["*"],
    allow_headers=["*"],
)

default_content_position = 14

document = {}
# plot = {}

def valid_plot(x):
    if x.split(".")[-1] == "ipynb":
        return False
    if x.split(".")[-1] == "json":
        return False
    if x[0] == ".":
        return False
    return True


@app.get("/list_files")
def list_files(filepath):
    filepath = urllib.parse.unquote(filepath)
    print(filepath)
    filelist = list(filter(valid_plot, os.listdir("./plot"+filepath)))
    rtrn = []
    for i in filelist:
        if i == ".ipynb_checkpoints":
            continue
        if i == ".git":
            continue
        if i == "__pycache__":
            continue
        if i == "Untitled.ipynb":
            continue
        if "." in i:
            rtrn.append({"filename": i, "type": "file"})
        else:
            rtrn.append({"filename": i, "type": "folder"})
    print(rtrn)
    return rtrn
        
@app.get("/get_pdf_pages")
def get_num_pages(filename):
    """
    获取文件总页码
    :param file_path: 文件路径
    :return:
    """
    reader = PdfReader(filename + ".pdf")
    # 不解密可能会报错：PyPDF2.utils.PdfReadError: File has not been decrypted
    if reader.is_encrypted:
        reader.decrypt('')
    return len(reader.pages)

@app.get("/get_files")
def get_files(filename):
#     print(filename)
    filename = filename.split("#")[0]
    filename = urllib.parse.unquote(filename)
    filename = filename.replace("plot.txt","").replace(".txt","")
#     filename = filename.
    with open("./database.json", "r", encoding="UTF-8") as file:
        document[filename] = json.load(file)[filename]
    for i in range(len(document[filename]["plot"])):
        document[filename]["plot"][i]["id"] = i
    return document[filename]["plot"]
#     rtrn = []
#     index = 0
#     with open("./" + filename + ".txt", "r") as file:
#         lines = file.readlines()
#     for i in lines:
#         if i.strip() != "":
#             content = i.strip()[default_content_position:]
#             role = i.strip()[:default_content_position].strip()
#             rtrn.append({"content": content, "role": role,  "id":index})
#             index += 1
#     return rtrn

# @app.get("/get_all_comments")
# def get_all_comments():
#     with open("./database.json", "r", encoding="UTF-8") as f:
#         temp_document = json.load(f)
#     temp_comment = []
#     for i in temp_document.keys():
#         for j in range(len(temp_document[i]["comments"])):
#             print(temp_document[i]["comments"])
#             print(j)
#             print(temp_document[i]["comments"][j]["filename"])
#             temp_document[i]["comments"][j]["filename"] = i
#             temp_comment.append(temp_document[i]["comments"][j])
#     del temp_document
#     return temp_comment
    

@app.get("/get_comments")
def get_comments(filename):
    global document
    filename = filename.split("#")[0]
#     with open("./" + filename + ".json", "r") as f:
    with open("./database.json","r",encoding="UTF-8") as f:
        document[filename]["comments"] = json.load(f)[filename]["comments"]
    for i in range(len(document[filename]["comments"])):
        document[filename]["comments"][i]["id"] = i
    print(document[filename]["comments"])
    return document[filename]["comments"]

@app.get("/update_comments")
def update_comments(filename):
    global document
    filename = filename.split("#")[0]
    return document[filename]["comments"]

@app.get("/add_comments")
def add_comments(comment, filename):
    global document
    filename = filename.split("#")[0]
    comment = json.loads(comment)
    print(comment)
    try:
        document[filename]["comments"].append(comment)
#         document[filename]["comments"].append({"filename":filename, "id":maxId,"position":position,"content":content, "type": str(type)})
    except: 
        document[filename]["comments"] = [comment]
    print(comment)
        
#         document[filename]["comments"] = [{"filename":filename,"id":maxId,"position":position,"content":content, "type": str(type)}]

@app.get("/save")
def save(filepath):
    global document
    filepath = filepath.split("#")[0]
#     with open(filepath + ".json", "w", encoding="utf-8") as f:
#         json.dump(document[filepath], f, ensure_ascii=False)
    with open("./database.json","r", encoding="UTF-8") as f:
        content = json.load(f)
    content[filepath] = document[filepath]
    with open("./database.json","w", encoding="UTF-8") as f:
        json.dump(content, f, ensure_ascii=False)
    with open("./database.json", "r", encoding="UTF-8") as file:
        document[filepath] = json.load(file)[filepath]
    
        
@app.get("/delete_comments")
def delete_comments(maxId, filename):
    global document
    filename = filename.split("#")[0]
    print(filename)
    for i in range(len(document[filename]["comments"])-1, -1, -1):
        if int(document[filename]["comments"][i]["id"]) == int(maxId):
            del document[filename]["comments"][i]
    print(document[filename]["comments"])
        
@app.get("/edit_comments")
def edit_comments(id, content, filename):
    global document
#     print(id)
    filename = filename.split("#")[0]
    for i in range(len(document[filename]["comments"])):
        print(document[filename]["comments"][i]["id"])
        print(int(document[filename]["comments"][i]["id"]) == int(id))
        if int(document[filename]["comments"][i]["id"]) == int(id):
            document[filename]["comments"][i]["content"] = content
    
# @app.get("/get_file_type")
# def get_file_type(path):
#     if os.path.exists(path + ".txt"):
#         return "txt"
#     elif os.path.exists(path + ".pdf"):
#         return "pdf"
#     return ""

# @app.get("/get_files_pdf")
# def get_files_pdf(filename):
#     reader = PdfReader(filename + ".pdf")
#     # 不解密可能会报错：PyPDF2.utils.PdfReadError: File has not been decrypted
#     if reader.is_encrypted:
#         reader.decrypt('')
# #     print

#     page = reader.pages[0]
#     pdf_bytes = BytesIO()
#     pdf_writer = PdfWriter()
#     pdf_writer.add_page(page)
#     pdf_writer.write(pdf_bytes)
#     pdf_bytes.seek(0)

    
# #     return 
#     response = Response(content=pdf_bytes.getvalue(), media_type="application/pdf")

# #     设置响应头，告诉浏览器以附件形式保存文件
# #     response.headers["Content-Disposition"] = f"attachment; filename={path}.pdf"

#     return response

@app.get("/add_answer")
def add_answer(target_filename, target_id, answer_filename, answer_id):
    if (target_filename == answer_filename and target_id == answer_id):
        return
    with open("./database.json", "r") as f:
        temp_document = json.load(f)
    print(temp_document[answer_filename]["comments"])
    print(answer_id)
    temp_solution = copy.deepcopy(temp_document[answer_filename]["comments"][int(answer_id)])
    temp_solution1 = copy.deepcopy(temp_document[target_filename]["comments"][int(target_id)])
    try:
        del temp_solution["solution"]
    except:
        print(1)
    try:
        del temp_solution1["solution"]
    except:
        print(1)
    try:
        if temp_solution not in temp_document[target_filename]["comments"][int(target_id)]["solution"]:
            temp_document[target_filename]["comments"][int(target_id)]["solution"].append(temp_solution)
    except:
        temp_document[target_filename]["comments"][int(target_id)]["solution"]=[temp_solution]
    try:
        if temp_solution1 not in temp_document[answer_filename]["comments"][int(answer_id)]["solution"]:
            temp_document[answer_filename]["comments"][int(answer_id)]["solution"].append(temp_solution1)
    except:
        temp_document[answer_filename]["comments"][int(answer_id)]["solution"]=[temp_solution1]
#     temp_document[answer_filename]["comments"][int(answer_id)]["solution"]=list(set(temp_document[answer_filename]["comments"][int(answer_id)]["solution"]))
    with open("./database.json", "w") as f:
        json.dump(temp_document, f, ensure_ascii=False)
    del temp_solution
    del temp_document

@app.get("/get_answer")
def get_answer(target_filename, target_id):
    with open("./database.json", "r") as f:
        temp_document = json.load(f)
        try:
            return temp_document[target_filename]["comments"][int(target_id)]["solution"]
        except:
            return []

@app.get("/delete_answer")
def delete_answer(target_filename, target_id, answer_filename, answer_id):
    with open("./database.json", "r") as f:
        temp_document = json.load(f)
    index = 0
    while temp_document[target_filename]["comments"][int(target_id)]["solution"][index]["filename"] != answer_filename and temp_document[target_filename]["comments"][int(target_id)]["solution"][index]["id"] != answer_id:
        index+=1
    del temp_document[target_filename]["comments"][int(target_id)]["solution"][index]
    index = 0
    while temp_document[answer_filename]["comments"][int(answer_id)]["solution"][index]["filename"] != target_filename and temp_document[answer_filename]["comments"][int(answer_id)]["solution"][index]["id"] != target_id:
        index+=1
    del temp_document[answer_filename]["comments"][int(answer_id)]["solution"][index]
    with open("./database.json", "w") as f:
        json.dump(temp_document, f, ensure_ascii=False)
        

if __name__ == '__main__':
    # 运行fastapi程序
    nest_asyncio.apply()
    uvicorn.run(app, host='127.0.0.1', port = 8000)
# Out:
# INFO:     Started server process [33484]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# /剧情/战地秘闻
# [{'filename': '1_无名氏的战争.txt', 'type': 'file'}, {'filename': '1_无名氏的战争plot.txt', 'type': 'file'}, {'filename': '2_破局者.txt', 'type': 'file'}, {'filename': '2_破局者plot.txt', 'type': 'file'}, {'filename': '3_射击训练.txt', 'type': 'file'}, {'filename': '3_射击训练plot.txt', 'type': 'file'}, {'filename': '4_存续公正.txt', 'type': 'file'}, {'filename': '4_存续公正plot.txt', 'type': 'file'}, {'filename': '5_课后作业.txt', 'type': 'file'}, {'filename': '5_课后作业plot.txt', 'type': 'file'}, {'filename': '6_北极星.txt', 'type': 'file'}, {'filename': '6_北极星plot.txt', 'type': 'file'}, {'filename': '7_和光同尘.txt', 'type': 'file'}, {'filename': '7_和光同尘plot.txt', 'type': 'file'}]
# INFO:     127.0.0.1:62390 - "GET /list_files?filepath=%2F%E5%89%A7%E6%83%85%2F%E6%88%98%E5%9C%B0%E7%A7%98%E9%97%BB HTTP/1.1" 200 OK
# INFO:     127.0.0.1:62390 - "GET /get_files?filename=%E5%89%A7%E6%83%85%2F%E6%88%98%E5%9C%B0%E7%A7%98%E9%97%BB%2F%E6%97%A0%E5%90%8D%E6%B0%8F%E7%9A%84%E6%88%98%E4%BA%89 HTTP/1.1" 200 OK
# []
# INFO:     127.0.0.1:62390 - "GET /get_comments?filename=%E5%89%A7%E6%83%85%2F%E6%88%98%E5%9C%B0%E7%A7%98%E9%97%BB%2F%E6%97%A0%E5%90%8D%E6%B0%8F%E7%9A%84%E6%88%98%E4%BA%89 HTTP/1.1" 200 OK
# /剧情/战地秘闻
# [{'filename': '1_无名氏的战争.txt', 'type': 'file'}, {'filename': '1_无名氏的战争plot.txt', 'type': 'file'}, {'filename': '2_破局者.txt', 'type': 'file'}, {'filename': '2_破局者plot.txt', 'type': 'file'}, {'filename': '3_射击训练.txt', 'type': 'file'}, {'filename': '3_射击训练plot.txt', 'type': 'file'}, {'filename': '4_存续公正.txt', 'type': 'file'}, {'filename': '4_存续公正plot.txt', 'type': 'file'}, {'filename': '5_课后作业.txt', 'type': 'file'}, {'filename': '5_课后作业plot.txt', 'type': 'file'}, {'filename': '6_北极星.txt', 'type': 'file'}, {'filename': '6_北极星plot.txt', 'type': 'file'}, {'filename': '7_和光同尘.txt', 'type': 'file'}, {'filename': '7_和光同尘plot.txt', 'type': 'file'}]
# INFO:     127.0.0.1:62398 - "GET /list_files?filepath=%2F%E5%89%A7%E6%83%85%2F%25E6%2588%2598%25E5%259C%25B0%25E7%25A7%2598%25E9%2597%25BB HTTP/1.1" 200 OK
# /支线/不义之财
# [{'filename': '10_CV-ST-2_突然冲击.txt', 'type': 'file'}, {'filename': '10_CV-ST-2_突然冲击plot.txt', 'type': 'file'}, {'filename': '11_CV-5_疑惑之影_行动前.txt', 'type': 'file'}, {'filename': '11_CV-5_疑惑之影_行动前plot.txt', 'type': 'file'}, {'filename': '12_CV-5_疑惑之影_行动后.txt', 'type': 'file'}, {'filename': '12_CV-5_疑惑之影_行动后plot.txt', 'type': 'file'}, {'filename': '13_CV-6_猎人之夜_行动前.txt', 'type': 'file'}, {'filename': '13_CV-6_猎人之夜_行动前plot.txt', 'type': 'file'}, {'filename': '14_CV-6_猎人之夜_行动后.txt', 'type': 'file'}, {'filename': '14_CV-6_猎人之夜_行动后plot.txt', 'type': 'file'}, {'filename': '15_CV-7_白热_行动前.txt', 'type': 'file'}, {'filename': '15_CV-7_白热_行动前plot.txt', 'type': 'file'}, {'filename': '16_CV-7_白热_行动后.txt', 'type': 'file'}, {'filename': '16_CV-7_白热_行动后plot.txt', 'type': 'file'}, {'filename': '17_CV-8_告别往昔_行动前.txt', 'type': 'file'}, {'filename': '17_CV-8_告别往昔_行动前plot.txt', 'type': 'file'}, {'filename': '18_CV-8_告别往昔_行动后.txt', 'type': 'file'}, {'filename': '18_CV-8_告别往昔_行动后plot.txt', 'type': 'file'}, {'filename': '19_CV-ST-3_法外之徒.txt', 'type': 'file'}, {'filename': '19_CV-ST-3_法外之徒plot.txt', 'type': 'file'}, {'filename': '1_CV-ST-1_火线之中.txt', 'type': 'file'}, {'filename': '1_CV-ST-1_火线之中plot.txt', 'type': 'file'}, {'filename': '2_CV-1_孤独之地_行动前.txt', 'type': 'file'}, {'filename': '2_CV-1_孤独之地_行动前plot.txt', 'type': 'file'}, {'filename': '3_CV-1_孤独之地_行动后.txt', 'type': 'file'}, {'filename': '3_CV-1_孤独之地_行动后plot.txt', 'type': 'file'}, {'filename': '4_CV-2_双重保险_行动前.txt', 'type': 'file'}, {'filename': '4_CV-2_双重保险_行动前plot.txt', 'type': 'file'}, {'filename': '5_CV-2_双重保险_行动后.txt', 'type': 'file'}, {'filename': '5_CV-2_双重保险_行动后plot.txt', 'type': 'file'}, {'filename': '6_CV-3_圈套_行动前.txt', 'type': 'file'}, {'filename': '6_CV-3_圈套_行动前plot.txt', 'type': 'file'}, {'filename': '7_CV-3_圈套_行动后.txt', 'type': 'file'}, {'filename': '7_CV-3_圈套_行动后plot.txt', 'type': 'file'}, {'filename': '8_CV-4_缺席的人_行动前.txt', 'type': 'file'}, {'filename': '8_CV-4_缺席的人_行动前plot.txt', 'type': 'file'}, {'filename': '9_CV-4_缺席的人_行动后.txt', 'type': 'file'}, {'filename': '9_CV-4_缺席的人_行动后plot.txt', 'type': 'file'}, {'filename': 'CV-ST-1_火线之中plot.txt', 'type': 'file'}]
# INFO:     127.0.0.1:62421 - "GET /list_files?filepath=%2F%E6%94%AF%E7%BA%BF%2F%E4%B8%8D%E4%B9%89%E4%B9%8B%E8%B4%A2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:62421 - "GET /get_files?filename=%E6%94%AF%E7%BA%BF%2F%E4%B8%8D%E4%B9%89%E4%B9%8B%E8%B4%A2%2FCV-ST-1_%E7%81%AB%E7%BA%BF%E4%B9%8B%E4%B8%AD HTTP/1.1" 200 OK
# [{'content': '嘶——这鬼天气怎么这么冷！我就不明白了！', 'filename': '支线/不义之财/CV-ST-1_火线之中', 'id': 0, 'position': 0, 'start': 0, 'end': 20}]
# INFO:     127.0.0.1:62421 - "GET /get_comments?filename=%E6%94%AF%E7%BA%BF%2F%E4%B8%8D%E4%B9%89%E4%B9%8B%E8%B4%A2%2FCV-ST-1_%E7%81%AB%E7%BA%BF%E4%B9%8B%E4%B8%AD HTTP/1.1" 200 OK
# 0
# False
# INFO:     127.0.0.1:62426 - "GET /edit_comments?id=1&content=%E5%98%B6%E2%80%94%E2%80%94%E8%BF%99%E9%AC%BC%E5%A4%A9%E6%B0%94%E6%80%8E%E4%B9%88%E8%BF%99%E4%B9%88%E5%86%B7%EF%BC%81&filename=%E6%94%AF%E7%BA%BF%2F%E4%B8%8D%E4%B9%89%E4%B9%8B%E8%B4%A2%2FCV-ST-1_%E7%81%AB%E7%BA%BF%E4%B9%8B%E4%B8%AD HTTP/1.1" 200 OK
# INFO:     127.0.0.1:62426 - "GET /get_files?filename=%E6%94%AF%E7%BA%BF%2F%E4%B8%8D%E4%B9%89%E4%B9%8B%E8%B4%A2%2FCV-ST-1_%E7%81%AB%E7%BA%BF%E4%B9%8B%E4%B8%AD HTTP/1.1" 200 OK
# [{'content': '嘶——这鬼天气怎么这么冷！我就不明白了！', 'filename': '支线/不义之财/CV-ST-1_火线之中', 'id': 0, 'position': 0, 'start': 0, 'end': 20}]
# {'content': '它怎么就能这么冷，能他妈这么冷！', 'filename': '支线/不义之财/CV-ST-1_火线之中', 'id': 0, 'position': 1, 'start': 0, 'end': 16}
# INFO:     127.0.0.1:61231 - "GET /add_comments?comment=%7B%22content%22:%22%E5%AE%83%E6%80%8E%E4%B9%88%E5%B0%B1%E8%83%BD%E8%BF%99%E4%B9%88%E5%86%B7%EF%BC%8C%E8%83%BD%E4%BB%96%E5%A6%88%E8%BF%99%E4%B9%88%E5%86%B7%EF%BC%81%22,%22filename%22:%22%E6%94%AF%E7%BA%BF%2F%E4%B8%8D%E4%B9%89%E4%B9%8B%E8%B4%A2%2FCV-ST-1_%E7%81%AB%E7%BA%BF%E4%B9%8B%E4%B8%AD%22,%22id%22:0,%22position%22:1,%22start%22:0,%22end%22:16%7D&filename=%E6%94%AF%E7%BA%BF%2F%E4%B8%8D%E4%B9%89%E4%B9%8B%E8%B4%A2%2FCV-ST-1_%E7%81%AB%E7%BA%BF%E4%B9%8B%E4%B8%AD%23margin0 HTTP/1.1" 200 OK
# 支线/不义之财/CV-ST-1_火线之中
# []
# INFO:     127.0.0.1:61231 - "GET /delete_comments?maxId=0&filename=%E6%94%AF%E7%BA%BF%2F%E4%B8%8D%E4%B9%89%E4%B9%8B%E8%B4%A2%2FCV-ST-1_%E7%81%AB%E7%BA%BF%E4%B9%8B%E4%B8%AD%23margin0 HTTP/1.1" 200 OK
# /特殊
# [{'filename': '主播U：全能系美少女', 'type': 'folder'}, {'filename': '剧情', 'type': 'folder'}, {'filename': '危机合约', 'type': 'folder'}, {'filename': '好得不能再好了！泰拉投资大师课', 'type': 'folder'}, {'filename': '泰拉 说唱之夜！', 'type': 'folder'}, {'filename': '狂弹要塞！罗德大兵集结', 'type': 'folder'}, {'filename': '荷谟伊智境', 'type': 'folder'}, {'filename': '长夜临光', 'type': 'folder'}]
# INFO:     127.0.0.1:61260 - "GET /list_files?filepath=%2F%E7%89%B9%E6%AE%8A HTTP/1.1" 200 OK
# /特殊
# [{'filename': '主播U：全能系美少女', 'type': 'folder'}, {'filename': '剧情', 'type': 'folder'}, {'filename': '危机合约', 'type': 'folder'}, {'filename': '好得不能再好了！泰拉投资大师课', 'type': 'folder'}, {'filename': '泰拉 说唱之夜！', 'type': 'folder'}, {'filename': '狂弹要塞！罗德大兵集结', 'type': 'folder'}, {'filename': '荷谟伊智境', 'type': 'folder'}, {'filename': '长夜临光', 'type': 'folder'}]
# INFO:     127.0.0.1:61296 - "GET /list_files?filepath=%2F%E7%89%B9%E6%AE%8A HTTP/1.1" 200 OK
# 沙中之火/生息演算
# INFO:     127.0.0.1:61813 - "GET /list_files?filepath=%E6%B2%99%E4%B8%AD%E4%B9%8B%E7%81%AB%2F%E7%94%9F%E6%81%AF%E6%BC%94%E7%AE%97 HTTP/1.1" 500 Internal Server Error
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\uvicorn\protocols\http\httptools_impl.py", line 435, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\uvicorn\middleware\proxy_headers.py", line 78, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\fastapi\applications.py", line 1054, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\applications.py", line 123, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\middleware\errors.py", line 186, in __call__
#     raise exc
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\middleware\cors.py", line 93, in __call__
#     await self.simple_response(scope, receive, send, request_headers=headers)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\middleware\cors.py", line 148, in simple_response
#     await self.app(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\middleware\exceptions.py", line 65, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\_exception_handler.py", line 64, in wrapped_app
#     raise exc
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\routing.py", line 756, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\routing.py", line 776, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\routing.py", line 297, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\routing.py", line 77, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\_exception_handler.py", line 64, in wrapped_app
#     raise exc
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\routing.py", line 72, in app
#     response = await func(request)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\fastapi\routing.py", line 278, in app
#     raw_response = await run_endpoint_function(
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\fastapi\routing.py", line 193, in run_endpoint_function
#     return await run_in_threadpool(dependant.call, **values)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\concurrency.py", line 42, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func, *args)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\anyio\to_thread.py", line 33, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\anyio\_backends\_asyncio.py", line 877, in run_sync_in_worker_thread
#     return await future
#   File "C:\Users\hongl\anaconda3\envs\study\lib\asyncio\futures.py", line 284, in __await__
#     yield self  # This tells Task to wait for completion.
#   File "C:\Users\hongl\anaconda3\envs\study\lib\asyncio\tasks.py", line 328, in __wakeup
#     future.result()
#   File "C:\Users\hongl\anaconda3\envs\study\lib\asyncio\futures.py", line 201, in result
#     raise self._exception
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\anyio\_backends\_asyncio.py", line 807, in run
#     result = context.run(func, *args)
#   File "C:\Users\hongl\AppData\Local\Temp\ipykernel_33484\1182687245.py", line 46, in list_files
#     filelist = list(filter(valid_plot, os.listdir("./plot"+filepath)))
# FileNotFoundError: [WinError 3] 系统找不到指定的路径。: './plot沙中之火/生息演算'
# 沙中之火/生息演算
# INFO:     127.0.0.1:62282 - "GET /list_files?filepath=%E6%B2%99%E4%B8%AD%E4%B9%8B%E7%81%AB%2F%E7%94%9F%E6%81%AF%E6%BC%94%E7%AE%97 HTTP/1.1" 500 Internal Server Error
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\uvicorn\protocols\http\httptools_impl.py", line 435, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\uvicorn\middleware\proxy_headers.py", line 78, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\fastapi\applications.py", line 1054, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\applications.py", line 123, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\middleware\errors.py", line 186, in __call__
#     raise exc
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\middleware\cors.py", line 93, in __call__
#     await self.simple_response(scope, receive, send, request_headers=headers)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\middleware\cors.py", line 148, in simple_response
#     await self.app(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\middleware\exceptions.py", line 65, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\_exception_handler.py", line 64, in wrapped_app
#     raise exc
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\routing.py", line 756, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\routing.py", line 776, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\routing.py", line 297, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\routing.py", line 77, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\_exception_handler.py", line 64, in wrapped_app
#     raise exc
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\routing.py", line 72, in app
#     response = await func(request)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\fastapi\routing.py", line 278, in app
#     raw_response = await run_endpoint_function(
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\fastapi\routing.py", line 193, in run_endpoint_function
#     return await run_in_threadpool(dependant.call, **values)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\concurrency.py", line 42, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func, *args)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\anyio\to_thread.py", line 33, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\anyio\_backends\_asyncio.py", line 877, in run_sync_in_worker_thread
#     return await future
#   File "C:\Users\hongl\anaconda3\envs\study\lib\asyncio\futures.py", line 284, in __await__
#     yield self  # This tells Task to wait for completion.
#   File "C:\Users\hongl\anaconda3\envs\study\lib\asyncio\tasks.py", line 328, in __wakeup
#     future.result()
#   File "C:\Users\hongl\anaconda3\envs\study\lib\asyncio\futures.py", line 201, in result
#     raise self._exception
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\anyio\_backends\_asyncio.py", line 807, in run
#     result = context.run(func, *args)
#   File "C:\Users\hongl\AppData\Local\Temp\ipykernel_33484\1182687245.py", line 46, in list_files
#     filelist = list(filter(valid_plot, os.listdir("./plot"+filepath)))
# FileNotFoundError: [WinError 3] 系统找不到指定的路径。: './plot沙中之火/生息演算'
# 生息演算
# INFO:     127.0.0.1:62301 - "GET /list_files?filepath=%E7%94%9F%E6%81%AF%E6%BC%94%E7%AE%97 HTTP/1.1" 500 Internal Server Error
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\uvicorn\protocols\http\httptools_impl.py", line 435, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\uvicorn\middleware\proxy_headers.py", line 78, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\fastapi\applications.py", line 1054, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\applications.py", line 123, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\middleware\errors.py", line 186, in __call__
#     raise exc
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\middleware\cors.py", line 93, in __call__
#     await self.simple_response(scope, receive, send, request_headers=headers)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\middleware\cors.py", line 148, in simple_response
#     await self.app(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\middleware\exceptions.py", line 65, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\_exception_handler.py", line 64, in wrapped_app
#     raise exc
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\routing.py", line 756, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\routing.py", line 776, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\routing.py", line 297, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\routing.py", line 77, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\_exception_handler.py", line 64, in wrapped_app
#     raise exc
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\routing.py", line 72, in app
#     response = await func(request)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\fastapi\routing.py", line 278, in app
#     raw_response = await run_endpoint_function(
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\fastapi\routing.py", line 193, in run_endpoint_function
#     return await run_in_threadpool(dependant.call, **values)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\concurrency.py", line 42, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func, *args)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\anyio\to_thread.py", line 33, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\anyio\_backends\_asyncio.py", line 877, in run_sync_in_worker_thread
#     return await future
#   File "C:\Users\hongl\anaconda3\envs\study\lib\asyncio\futures.py", line 284, in __await__
#     yield self  # This tells Task to wait for completion.
#   File "C:\Users\hongl\anaconda3\envs\study\lib\asyncio\tasks.py", line 328, in __wakeup
#     future.result()
#   File "C:\Users\hongl\anaconda3\envs\study\lib\asyncio\futures.py", line 201, in result
#     raise self._exception
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\anyio\_backends\_asyncio.py", line 807, in run
#     result = context.run(func, *args)
#   File "C:\Users\hongl\AppData\Local\Temp\ipykernel_33484\1182687245.py", line 46, in list_files
#     filelist = list(filter(valid_plot, os.listdir("./plot"+filepath)))
# FileNotFoundError: [WinError 3] 系统找不到指定的路径。: './plot生息演算'
# 生息演算
# INFO:     127.0.0.1:62312 - "GET /list_files?filepath=%E7%94%9F%E6%81%AF%E6%BC%94%E7%AE%97 HTTP/1.1" 500 Internal Server Error
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\uvicorn\protocols\http\httptools_impl.py", line 435, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\uvicorn\middleware\proxy_headers.py", line 78, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\fastapi\applications.py", line 1054, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\applications.py", line 123, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\middleware\errors.py", line 186, in __call__
#     raise exc
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\middleware\cors.py", line 93, in __call__
#     await self.simple_response(scope, receive, send, request_headers=headers)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\middleware\cors.py", line 148, in simple_response
#     await self.app(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\middleware\exceptions.py", line 65, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\_exception_handler.py", line 64, in wrapped_app
#     raise exc
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\routing.py", line 756, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\routing.py", line 776, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\routing.py", line 297, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\routing.py", line 77, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\_exception_handler.py", line 64, in wrapped_app
#     raise exc
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\routing.py", line 72, in app
#     response = await func(request)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\fastapi\routing.py", line 278, in app
#     raw_response = await run_endpoint_function(
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\fastapi\routing.py", line 193, in run_endpoint_function
#     return await run_in_threadpool(dependant.call, **values)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\starlette\concurrency.py", line 42, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func, *args)
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\anyio\to_thread.py", line 33, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\anyio\_backends\_asyncio.py", line 877, in run_sync_in_worker_thread
#     return await future
#   File "C:\Users\hongl\anaconda3\envs\study\lib\asyncio\futures.py", line 284, in __await__
#     yield self  # This tells Task to wait for completion.
#   File "C:\Users\hongl\anaconda3\envs\study\lib\asyncio\tasks.py", line 328, in __wakeup
#     future.result()
#   File "C:\Users\hongl\anaconda3\envs\study\lib\asyncio\futures.py", line 201, in result
#     raise self._exception
#   File "C:\Users\hongl\anaconda3\envs\study\lib\site-packages\anyio\_backends\_asyncio.py", line 807, in run
#     result = context.run(func, *args)
#   File "C:\Users\hongl\AppData\Local\Temp\ipykernel_33484\1182687245.py", line 46, in list_files
#     filelist = list(filter(valid_plot, os.listdir("./plot"+filepath)))
# FileNotFoundError: [WinError 3] 系统找不到指定的路径。: './plot生息演算'
# /生息演算
# [{'filename': '沙中之火', 'type': 'folder'}, {'filename': '沙洲遗闻', 'type': 'folder'}]
# INFO:     127.0.0.1:62358 - "GET /list_files?filepath=%2F%E7%94%9F%E6%81%AF%E6%BC%94%E7%AE%97 HTTP/1.1" 200 OK
# /生息演算
# [{'filename': '沙中之火', 'type': 'folder'}, {'filename': '沙洲遗闻', 'type': 'folder'}]
# INFO:     127.0.0.1:62412 - "GET /list_files?filepath=%2F%E7%94%9F%E6%81%AF%E6%BC%94%E7%AE%97 HTTP/1.1" 200 OK
# /生息演算
# [{'filename': '沙中之火', 'type': 'folder'}, {'filename': '沙洲遗闻', 'type': 'folder'}]
# INFO:     127.0.0.1:62441 - "GET /list_files?filepath=%2F%E7%94%9F%E6%81%AF%E6%BC%94%E7%AE%97 HTTP/1.1" 200 OK
# /生息演算
# [{'filename': '沙中之火', 'type': 'folder'}, {'filename': '沙洲遗闻', 'type': 'folder'}]
# INFO:     127.0.0.1:62451 - "GET /list_files?filepath=%2F%E7%94%9F%E6%81%AF%E6%BC%94%E7%AE%97 HTTP/1.1" 200 OK
# /生息演算
# [{'filename': '沙中之火', 'type': 'folder'}, {'filename': '沙洲遗闻', 'type': 'folder'}]
# INFO:     127.0.0.1:62778 - "GET /list_files?filepath=%2F%E7%94%9F%E6%81%AF%E6%BC%94%E7%AE%97 HTTP/1.1" 200 OK
# /生息演算
# [{'filename': '沙中之火', 'type': 'folder'}, {'filename': '沙洲遗闻', 'type': 'folder'}]
# INFO:     127.0.0.1:62803 - "GET /list_files?filepath=%2F%E7%94%9F%E6%81%AF%E6%BC%94%E7%AE%97 HTTP/1.1" 200 OK
# /生息演算
# [{'filename': '沙中之火', 'type': 'folder'}, {'filename': '沙洲遗闻', 'type': 'folder'}]
# INFO:     127.0.0.1:62816 - "GET /list_files?filepath=%2F%E7%94%9F%E6%81%AF%E6%BC%94%E7%AE%97 HTTP/1.1" 200 OK
# /生息演算
# [{'filename': '沙中之火', 'type': 'folder'}, {'filename': '沙洲遗闻', 'type': 'folder'}]
# INFO:     127.0.0.1:62816 - "GET /list_files?filepath=%2F%E7%94%9F%E6%81%AF%E6%BC%94%E7%AE%97 HTTP/1.1" 200 OK

# %% [markdown]
# # 爬虫:

# %%
import requests
from bs4 import BeautifulSoup
import urllib
all_plot_url = "https://prts.wiki/w/%E5%89%A7%E6%83%85%E4%B8%80%E8%A7%88"
res = requests.get(all_plot_url)
soup = BeautifulSoup(res.text, "html.parser")
mainDiv = soup.find_all("div", class_='nomobile')
mainDiv = mainDiv[-1]
tables = mainDiv.find_all("table", recursive=False)
string = "https://prts.wiki/index.php?title={name}&action=edit"
all_plot = []
hashmap = {}
for i in tables:
    tbody = i.find_all("tbody", recursive=False)[0]
#     print(tbody.find_all("tr", recursive=False))
    tr = tbody.find_all("tr", recursive=False)[0]
#     print(tr)
    td = tr.find_all("td",recursive=False)[0]
    table = td.find_all("table",recursive=False)[0]
    tbody = table.find_all("tbody",recursive=False)[0]
    trs = tbody.find_all("tr",recursive=False)
    for i in trs:
        title = i.find_all("th",class_="navbox-group",recursive=False)
        if title == None or title == []:
            continue
        title = title[0].text
        td = i.find_all("td",recursive=False)[0]
        table = td.find_all("table",recursive=False)[0]
        tbody = table.find_all("tbody",recursive=False)[0]
        trs = tbody.find_all("tr",recursive=False)
        for tr in trs:
            th = tr.find_all("th",recursive=False)
            if th == []:
                continue
            th = th[0]
            chapter = th.text
            td = tr.find_all("td",recursive=False)[0]
            div = td.find_all("div",recursive=False)[0]
            lis = div.find_all("li",recursive=False)
            for i in lis:
                a = i.find_all("a",recursive=False)[0]
                if title=="集成战略" or title=="特殊":
                    if title+"/"+chapter not in hashmap.keys():
                        hashmap[title+"/"+chapter] = 0
                    hashmap[title+"/"+chapter] += 1
                    all_plot.append({"filename":"./plot/"+title+"/"+chapter+"/"+str(hashmap[title+"/"+chapter])+"_"+a.text.replace(" ","_"), "href":urllib.parse.unquote(string.format(name=a.get("href")[3:]))})
                else:
                    if chapter+"/"+title not in hashmap.keys():
                        hashmap[chapter+"/"+title] = 0
                    hashmap[chapter+"/"+title] += 1
#                     print("./plot/"+chapter+"/"+title+"/"+str(hashmap[chapter+"/"+title])+"_"+a.text.replace(" ","_"), urllib.parse.unquote(string.format(name=a.get("href")[3:])))
                    all_plot.append({"filename":"./plot/"+chapter+"/"+title+"/"+str(hashmap[chapter+"/"+title])+"_"+a.text.replace(" ","_"), "href": urllib.parse.unquote(string.format(name=a.get("href")[3:]))})

all_plot

# %%
import requests
from bs4 import BeautifulSoup
import urllib
all_plot_url = "https://prts.wiki/w/%E6%B3%B0%E6%8B%89%E5%A4%A7%E5%85%B8:%E8%A7%92%E8%89%B2/%E5%85%B6%E4%BB%96"
res = requests.get(all_plot_url)
soup = BeautifulSoup(res.text, "html.parser")
mainDiv = soup.find_all("div", class_='mw-parser-output')
tables = mainDiv[0].find_all("table",recursive=False)
for table in tables:
    tbody = table.find("tbody")
    name = tbody.find_all("tr",recursive=False)[0].find("th").text
    print(name)
    with open(f"./plot/人物简介/{name.strip()}.txt", "w") as file:
        for tr in tbody.find_all("tr", recursive = False):
            th = tr.find("th")
            td = tr.find("td")
            if th:
                if th.text.strip() == name.strip():
                    continue
                file.write("#" + th.text.strip())
                file.write(": ")
            else:
                file.write("    "+td.prettify().replace("<br/>","\n").replace("<p>","").replace("</p>","").split(">")[1].split("<")[0])
                file.write("\n")
# Out:
# 博士
#
# 可露希尔
#
# Medic
#
# Ace
#
# PRTS
#
# Scout
#
# 安托
#
# Pith
#
# Logos
#
# 碧银
#
# 普瑞赛斯
#
# 弃械
#
# Stormeye
#
# Misery
#
# Outcast
#
# Touch
#
# Sharp
#
# Mechanist
#
# Mantra
#
# 弑君者
#
# 梅菲斯特
#
# 浮士德
#
# 塔露拉
#
# 米莎
#
# 碎骨
#
# 霜星
#
# 大鲍勃
#
# 爱国者
#
# Guard
#
# 加勒斯
#
# 依拉
#
# 魏彦吾
#
# 阿发
#
# 鼠王
#
# 董阿伯
#
# 解真
#
# 太合
#
# 九
#
# 文月
#
# 黎
#
# 说书人
#
# 阿然
#
# 郑掌柜
#
# 老船夫
#
# 梁洵
#
# 宁小姐
#
# 杜小姐
#
# 挑山人
#
# 太傅
#
# 塔季娅娜
#
# 海伦
#
# 格罗瓦兹尔
#
# 叶克多
#
# 科西切
#
# 薇卡
#
# 阿丽娜
#
# 莉莉娅
#
# 伊斯拉姆·维特
#
# 万尼亚大公
#
# 费奥多尔
#
# 特雷西斯
#
# 伊内丝
#
# 赫德雷
#
# 特蕾西娅
#
# 加尔森
#
# 曼弗雷德
#
# 血魔大君
#
# 食腐者之王
#
# 可萝尔
#
# 老骑士
#
# 老工匠
#
# 大嘴莫布
#
# 光头马丁
#
# 恰尔内
#
# 马克维茨
#
# 塑料骑士
#
# 锈铜骑士
#
# 左手骑士
#
# 腐败骑士
#
# 凋零骑士
#
# 罗伊
#
# 莫妮克
#
# 麦基
#
# 罗素
#
# 托兰
#
# 逐魇骑士
#
# 杜克
#
# 莱姆
#
# 血骑士
#
# 巴顿
#
# 杜玛
#
# 杰斯顿
#
# 坎诺特
#
# Dijkstra
#
# 玛丽
#
# 桑尼
#
# 克里夫
#
# 伍德洛
#
# 坎黛拉
#
# 潘乔
#
# 克洛宁
#
# 赫尔曼
#
# 芭芭拉
#
# 迪伦马特
#
# 蕾缪安
#
# 费莉亚·拉珀尔塔
#
# 塞茜莉亚
#
# 奥伦
#
# 薇尔丽芙
#
# 伊万杰利斯塔十一世
#
# 帕蒂亚
#
# 安多恩
#
# 斯特凡诺·托雷格罗萨
#
# 阿尔图罗
#
# 卡彭
#
# 甘比诺
#
# 阿尔贝托·萨卢佐
#
# 乔万娜·罗塞蒂
#
# 贝纳尔多·贝洛内
#
# 德米特里·切塔尔多
#
# 阿格尼尔
#
# 伊比利亚主教
#
# 安东尼奥
#
# 何塞
#
# 老何塞
#
# 安妮塔
#
# 大审判官
#
# 蒂亚戈
#
# 圣徒卡门
#
# 阿方索
#
# 加西亚
#
# 朵拉
#
# 爱德华
#
# 文森特伯爵
#
# 三角铁
#
# 路易斯·凯利
#
# 希尔
#
# 克雷格
#
# 汉密尔顿
#
# 西尔莎
#
# 麦克马丁
#
# 西莫·威廉姆斯
#
# 塔佳娜
#
# 塞弗林
#
# 毕德曼
#
# 托尔
#
# 别格勒
#
# 爷爷
#
# 白垩
#
# 格特鲁德
#
# 乌尔苏拉
#
# 拉赫曼
#
# 珂拉·洛文斯坦
#
# 布兰特·赖纳
#
# 沃尔纳·冯·霍赫贝格
#
# 弗里达·希曼
#
# 洛里斯·博尔丁
#
# 尤利娅·许勒尔
#
# 扬·许勒尔
#
# 弗莱蒙特
#
# 赫尔昏佐伦
#
# 格哈德·霍夫曼
#
# 依娜姆
#
# 大祭司
#
# 图拉
#
# 德鲁奇
#
# 米亚罗
#
# 皮加尔
#
# 老伊辛
#
# 菈塔托丝
#
# 休露丝
#
# 尤卡坦
#
# 阿克托斯
#
# 瓦莱丝
#
# 古罗
#
# 大长老
#
# 莫希
#
# 耶奇·地心
#
# 卡奇·叙光
#
# 克罗绮·砖石
#
# 黛柯绮·银币
#
# 缪尔赛思
#
# 克丽斯腾·莱特
#
# 斐尔迪南·克鲁尼
#
# 阿伦茨·帕尔维斯
#
# 管家
#
# 欧厄尔
#
# 大帝
#
# 伊斯
#
# 切斯特
#
# 蔓德拉
#
# 阿赫茉妮
#
# 费斯特
#
# 克洛维希娅
#
# 战士比尔
#
# 阿勒黛·坎伯兰
#
# 昆图斯
#
# 阿玛雅
#
# Aya
#
# Alty
#
# Dan
#
# Frost
#
# D.D.D.

# %%
written = []

# %%
import requests
from bs4 import BeautifulSoup
import urllib
all_plot_url = "https://prts.wiki/w/%E5%B9%B2%E5%91%98%E7%BC%96%E5%8F%B7%E4%B8%80%E8%A7%88"
res = requests.get(all_plot_url)
soup = BeautifulSoup(res.text, "html.parser")
mainDiv = soup.find_all("div", class_='mw-parser-output')
cnt = 0
for i in mainDiv[0].find_all("a"):
    url = f"https://prts.wiki/w/{i.get('title')}"
    profile = requests.get(url)
    profile = BeautifulSoup(profile.text, "html.parser")
    div = profile.find("div", class_="mw-parser-output")
    div = div.find_all("table", class_="wikitable", recursive=False)
    for j in div:
        if j.text.strip()[:8] == "————人员档案":
            div = j
            break
    tbody = div.find("tbody", recursive=False)
    trs = tbody.find_all("tr", recursive=False)
    # print(trs)
    # break
    # print(trs)
    cnt = 0
    print(i.get("title"))
    written.append(i.get("title"))
    with open(f"./plot/人物简介/干员/{i.get('title')}.txt", "w", encoding="UTF-8") as file:
        for j in trs[1:]:
            # print(j)
            # print
            cnt += 1
            if cnt % 3 == 1:
                file.write("#" + j.text.strip() + "\n")
            elif cnt % 3 == 0:
                file.write("\n\n" + j.text.strip() + "\n\n")
            else:
                continue
# Out:
# 阿米娅
# 郁金香
# 杜宾
# 末药
# 红豆
# 华法琳
# 苏苏洛
# 桃金娘
# 傀影
# 灰喉
# 史尔特尔
# 假日威龙陈
# 温蒂
# 格雷伊
# 夏栎
# 红云
# 霜叶
# 坚雷
# 铸铁
# 格劳克斯
# 月禾
# 伊桑
# 极境
# 微风
# 亚叶
# 褐果
# 炎客
# 柏喙
# 酸糖
# 卡达
# 晓歌
# 刻刀
# 鸿雪
# 泡泡
# 蜜蜡
# 巫恋
# 刻俄柏
# 波登可
# 慑砂
# 泥岩
# 清流
# 罗小黑
# 稀音
# 絮雨
# 暴雨
# 杰克
# 奥达
# 休谟斯
# 铃兰
# 明椒
# 妮芙
# 渡桥
# 12F
# 凯尔希
# 维什戴尔
# 博士
# W
# 伊内丝
# 赫德雷
# 魔王
# 逻各斯
# 术髓
# 触痕
# 锋刃
# 风暴眼
# 煌
# 迷迭香
# Lancet-2
# Castle-3
# THRM-EX
# Friston-3
# PhonoR-0
# 夜刀
# 巡林者
# 黑角
# 杜林
# 芬
# 克洛丝
# 芙蓉
# 米格鲁
# 炎熔
# 玫兰莎
# 史都华德
# 安赛尔
# 安德切尔
# 卡缇
# 梓兰
# 月见夜
# 空爆
# 斑点
# 泡普卡
# 阿斯卡纶
# 红
# 清道夫
# 炎狱炎熔
# 寒芒克洛丝
# 濯尘芙蓉
# 历阵锐枪芬
# 百炼嘉维尔
# 承曦格雷伊
# 乌尔比安
# 斯卡蒂
# 幽灵鲨
# 蓝毒
# 深海色
# 歌蕾蒂娅
# 深巡
# 海霓
# 赫拉格
# 芙兰卡
# 雷蛇
# 杰西卡
# 香草
# 杏仁
# 涤火杰西卡
# 龙舌兰
# 羽毛笔
# 跃跃
# 露托
# 布丁
# 山
# 卡夫卡
# 罗宾
# 松果
# 罗比菈塔
# 蚀清
# 豆苗
# 石英
# 掠风
# 玫拉
# 冰酿
# 锡人
# 霍尔海雅
# 浊心斯卡蒂
# 归溟幽灵鲨
# 焰影苇草
# 和弦
# 闪灵
# 临光
# 夜莺
# 推进之王
# 摩根
# 因陀罗
# 达格达
# 缠丸
# 宴
# 赤冬
# 绮良
# 水月
# 风丸
# 嵯峨
# 苇草
# 棘刺
# 安哲拉
# 深靛
# 艾丽妮
# 流明
# 海沫
# 艾丝黛尔
# 蛇屠箱
# 嘉维尔
# 耶拉
# 银灰
# 灵知
# 角峰
# 讯使
# 初雪
# 崖心
# 锏
# 极光
# 耀骑士临光
# 白金
# 砾
# 鞭刃
# 玛恩纳
# 瑕光
# 但书
# 焰尾
# 灰毫
# 远牙
# 野鬃
# 正义骑士号
# 魏彦吾
# 文月
# 陈
# 星熊
# 诗怀雅
# 白雪
# 阿消
# 槐琥
# 孑
# 拜松
# 雪雉
# 老鲤
# 吽
# 阿
# 林
# 琳琅诗怀雅
# 地灵
# 艾雅法拉
# 卡涅利安
# 黑键
# 车尔尼
# 止颂
# 纯烬艾雅法拉
# 薇薇安娜
# 深律
# 折光
# 送葬人
# 安比尔
# 翎羽
# 芳汀
# 空弦
# 见行者
# 菲亚梅塔
# 空构
# 隐现
# 塑心
# 圣约送葬人
# 莫斯提马
# 泰拉大陆调查团
# 麒麟R夜刀
# 火龙S黑角
# 断罪者
# 火神
# 调香师
# 帕拉斯
# 埃拉托
# 年
# 夕
# 令
# 重岳
# 黍
# 德克萨斯
# 能天使
# 可颂
# 空
# 缄默德克萨斯
# 暴行
# 暗索
# 莱恩哈特
# 断崖
# 石棉
# 蜜莓
# 四月
# 火哨
# 洋灰
# 夜半
# 温米
# 莱伊
# 赫默
# 塞雷娅
# 伊芙利特
# 白面鸮
# 梅尔
# 麦哲伦
# 多萝西
# 星源
# 缪尔赛思
# 淬羽赫默
# 星极
# 灰烬
# 闪击
# 霜华
# 战车
# 艾拉
# 医生
# 双月
# 导火索
# 风笛
# 狮蝎
# 森蚺
# 特米米
# 燧石
# 异客
# 图耶
# 至简
# 铅踝
# 红隼
# 佩佩
# 娜仁图亚
# 莎草
# 衡沙
# 远山
# 寒檀
# 雪绒
# 凛视
# 提丰
# 天火
# 拉普兰德
# 安洁莉娜
# 普罗旺斯
# 贾维
# 布洛卡
# 奥斯塔
# 斥罪
# 伺夜
# 子月
# 阿罗玛
# 锡兰
# 黑
# 苍苔
# 青枳
# 守林人
# 流星
# 陨星
# U-Official
# 猎蜂
# 苦艾
# 凛冬
# 真理
# 古米
# 早露
# 烈夏
# 梅
# 夜烟
# 夜魔
# 慕斯
# 格拉尼
# 暮落
# 薄绿
# 澄闪
# 琴柳
# 熔泉
# 爱丽丝
# 贝娜
# 号角
# 白铁
# 洛洛
# 海蒂
# 谜图
# 戴菲恩
# 刺玫
# 维荻
# 哈洛德
# 食铁兽
# 桑葚
# 惊蛰
# 左乐
# 九色鹿
# 乌有
# 万顷
# 小满
# 截云
# 铎铃
# 仇白

# %%
# !mkdir plot\人物简介\干员

# %%
exception = []
for i in all_plot:
#     if i["filename"].split("/")[2] != "剧情":
#         continue
    print(i)
    paths = i["filename"].split("/")
    for j in range(1,len(paths)):
        path = "/".join(paths[:j])
        if not os.path.exists(path):
            os.mkdir(path)
    with open(i["filename"]+".txt","w") as f:
        res = requests.get(i["href"])
        soup = BeautifulSoup(res.text, "html.parser")
        try:
            f.write(soup.find("textarea").text)
        except:
            exception.append(i["filename"])
    print(i["filename"])

# %%
import os
import json
import re
total_plot = {}
def parse_sentence(text):
    sentence_pattern = r'\[name="([^"]+)"\](.+)'    
    decision_pattern = r'\[Decision\(options="([^"]+)",values="([^"]+)"\)\]'
    preference_pattern = r'\[Predicate\(references="([^"]+)"'
    subtitle_pattern = r'\(text="([^"]+)"\] (.+)'
#     print(text)
    if re.match(sentence_pattern, text):
        match = re.match(sentence_pattern, text)
        character_name = match.group(1)
        sentence = match.group(2)
        return character_name, [sentence]
    elif re.match(decision_pattern, text):
        match = re.match(decision_pattern, text)
        options = match.group(1).split(";")
        values = match.group(2).split(";")
        return "  选择", [f"{i[0]} (分支{i[1]})" for i in list(zip(options, values))]
    elif re.match(preference_pattern, text):
        match = re.match(preference_pattern, text)
        return f"分支{match.group(1)}", [""]
    elif re.match(subtitle_pattern, text):
        match = re.match(subtitle_pattern, text)
        return "旁白", [match.group(1)]
def write_files(filename):
    write_txt = open(filename.replace(".txt","plot.txt"), "w")
    write_json = open(filename.replace(".txt",".json"),"w")
    temp_dict = []
#     filename = 
    name = "/".join(filename.replace(".txt","").replace("./plot/","").split("/")[:-1]) +"/"+ "_".join(filename.replace(".txt","").replace("./plot/","").split("/")[-1].split("_")[1:])
#     print(name)
    total_plot[name] = {}
    total_plot[name]["plot"] = []
    total_plot[name]["comments"] = []
    with open(filename, "r", encoding="UTF-8") as f:
        lines = f.readlines()
        for line in lines:
            sentence = parse_sentence(line)
#             print(sentence)
            if not sentence:
                continue
            role, sentence = sentence
            role += ":"
            for i in sentence:
                temp_dict.append({"role":role,"content":i})
                while len(role) < 20:
                    role += " "
                write_txt.write(role)
                write_txt.write(i)
                write_txt.write("\n")
                role = ""
            total_plot[name]["plot"] = temp_dict
    json.dump(temp_dict, write_json, ensure_ascii=False)
    write_txt.close()
    write_json.close()
# write_files("./plot/支线/不义之财/1_CV-ST-1_火线之中.txt")          
for path, folder, file in os.walk("./plot"):
    print(path)
    for i in file:
        if ".txt" not in i or "plot" in i:
            continue
        temp_path = path +"/"+ i
        write_files(temp_path)
